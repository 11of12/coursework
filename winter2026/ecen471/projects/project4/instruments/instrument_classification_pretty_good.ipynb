# %% [markdown]
# # Separate the Training and Test Data

# %%
import torch
import pickle

# %%
from torch.utils.data import Dataset, random_split

class InstrumentDataset(Dataset):
    def __init__(self, X, y, labels):
        self.X = X
        self.y = y
        self.labels = labels

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        X_i = torch.tensor(self.X[idx].reshape((1, self.X.shape[1], self.X.shape[2])), dtype=torch.float32)
        y_i = torch.tensor(self.y[idx], dtype=torch.long)
        return X_i, y_i

data = pickle.load(open('processed_data.pkl', 'rb'))
X = data["X"]
y = data["y"]
labels_map = data["labels_map"]

num_mfcc = X.shape[1]
num_time_steps = X.shape[2]

generator = torch.Generator().manual_seed(42)
dataset = InstrumentDataset(X=X, y=y, labels=labels_map.keys())    

num_training_points = round(0.8*y.shape[0])
num_validation_points = round(0.2*y.shape[0])
training_dataset, validation_dataset = random_split(dataset, lengths=[num_training_points, num_validation_points], generator=generator)

# %%
from torch.utils.data import DataLoader
batch_size = 128
train_dataloader = DataLoader(training_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=True)

# %%
for X, y in train_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    print(y)
# Out:
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 4,  4, 12, 13,  9,  5, 11, 11,  1,  7, 13,  3,  0,  1, 12,  4,  5,  4,
#          3,  0,  0,  0,  0,  1,  1,  1, 10,  3,  4, 13,  4,  4,  1,  0, 12, 13,
#          0, 13,  9,  4,  0,  0,  0,  5,  5,  4,  0, 11,  5,  0,  9,  9,  5,  0,
#          4,  9,  0,  6,  4,  5, 12,  4,  0,  8,  8, 11, 11, 10,  3,  4,  0,  0,
#          5,  2,  5, 10,  0,  5, 11, 13, 11,  8,  7,  9,  1,  1,  0,  3,  9,  1,
#          8,  0,  0,  0,  1,  0,  0, 10,  5,  4,  5,  0, 13, 11,  9,  3,  0,  0,
#          0,  4, 12,  6,  0,  3,  5,  5,  3,  8, 12,  5,  2,  9, 13,  1,  7,  4,
#          0,  4])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 5,  7,  1,  0,  0,  5,  0,  0, 10,  9,  0,  5, 10,  1,  9,  4,  9,  1,
#          8,  9,  5, 13,  0,  4,  9,  9, 12,  9,  2,  9,  8,  0,  0,  0,  7,  0,
#          3,  4,  1, 12,  2,  0, 12,  2,  0,  1,  9,  1,  0,  1,  0,  8,  0,  5,
#         10,  0,  0,  5,  0,  2,  0,  3,  9,  5,  3,  4,  6,  3,  0,  7,  2,  8,
#          5, 10, 12, 13, 10,  4,  3,  7,  9,  5,  9,  8,  7,  5,  1,  8,  9,  6,
#         10,  1,  0, 12, 13,  0,  1,  9,  0,  6,  9, 10,  5,  0,  4,  9,  3, 10,
#         12,  9,  6, 11,  0,  7,  3, 11,  1,  0,  5,  1,  9,  4, 10, 12,  1,  2,
#          5,  4])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([11,  0,  0,  0,  9,  1,  5, 12,  9,  5,  5,  3,  6,  0, 10,  5,  7,  9,
#          2, 10,  0,  1, 11, 13, 11,  0,  7, 13, 11, 13, 12,  8,  9,  0,  5, 12,
#          4, 13,  2,  0,  0,  0,  0,  0,  0,  8,  0, 10,  9,  2, 11,  0,  5,  0,
#         10,  4,  4, 10, 13,  9,  0,  5,  0, 12,  5,  6,  0,  4,  0,  0,  5,  5,
#          7,  1,  3,  1,  8,  1,  4,  4,  5,  7,  5,  0,  7,  4,  6,  8,  8, 13,
#         13,  0,  0,  0,  0,  5, 13,  1,  9, 11,  4, 12,  2,  9,  0,  0, 13,  8,
#         11,  4,  9,  5,  2, 11,  0,  1, 12,  5,  4,  1,  0,  1, 13,  0, 13,  5,
#         12,  1])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 0,  4,  7,  5,  0, 12,  0,  4,  0,  9,  1,  5,  6,  4,  1,  1,  4, 11,
#          0,  0,  0,  2, 13,  9,  0,  4, 12,  9,  0,  0,  9,  4,  3,  7,  9, 10,
#         11,  0,  9,  1, 11,  5,  4,  5,  0,  1,  9,  7,  3,  5, 13,  0,  0,  6,
#          0,  5,  5,  0,  6,  3,  1,  5,  0,  0,  6,  5,  0, 11,  7,  4,  5,  0,
#          1, 10, 10,  8,  2,  7,  6,  1,  7,  9, 11,  9,  1,  0, 10,  9,  6,  0,
#          1,  9,  1,  9,  7, 12, 12,  0,  5,  4,  5,  0, 13,  1,  0,  5,  4,  4,
#          0,  0,  0,  1,  2,  4,  0,  5,  1,  3,  9,  5, 13,  5, 12, 11, 10,  4,
#          5,  0])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 0,  6,  0,  5,  8,  7, 13, 10,  6,  0,  8,  4,  1,  5,  1,  5,  9,  9,
#          7,  0,  4,  1,  5,  7,  0,  8,  0,  9,  0,  0,  0,  9,  6,  0, 11,  2,
#          4,  8,  0,  5,  8,  1,  5,  9,  8,  9,  5,  8,  9,  5,  4, 12,  5, 11,
#          0,  0,  1,  5, 13,  0,  4,  5,  9,  0,  0,  1,  9,  1, 11,  2,  5, 10,
#          0,  0,  6,  0,  0,  7,  4,  1,  2,  0,  9,  4,  0,  5,  1,  9,  0,  3,
#          7,  1,  5,  3,  9,  5,  9,  3,  4,  2,  7,  4,  1,  5,  1,  9,  0,  6,
#          5,  0,  9,  1,  4, 11,  9,  1,  9,  3,  0,  0,  0,  9,  4, 12,  4,  5,
#          0,  5])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 1, 13,  0,  1,  5,  0, 11,  1,  0,  4,  1,  5, 10,  7,  9,  7, 10,  6,
#         12,  1,  0, 12,  0, 13,  7,  8,  6,  3,  3,  8,  6,  1,  1,  1, 13,  0,
#          2, 10,  0, 13,  9, 12,  0,  1,  0,  1,  9,  5, 11,  0,  0,  1,  4, 11,
#          0,  4, 13,  9,  0,  0,  3, 12,  4,  1,  6,  5,  5,  5, 12,  0,  4,  3,
#          9, 11,  8,  4,  9,  4,  7,  2,  1,  4,  2,  4,  3, 12,  6, 10,  7,  5,
#         13,  1, 13,  0, 12,  5,  0,  0,  2, 11,  2,  4,  2,  9,  4,  1,  8,  9,
#         11,  4,  5,  0, 10, 13,  4,  7,  5,  1,  4,  8,  1,  9, 13,  9,  1, 10,
#          1,  5])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([13,  9,  0,  1, 10,  5,  0,  0,  6,  9,  0,  3,  5,  4,  9,  0, 11,  1,
#          4,  1,  0,  8,  5,  4,  6,  1,  9,  3,  9,  4,  5,  0,  0,  0,  0,  7,
#          1, 12, 10,  3,  9,  1,  5,  5,  0,  0,  0,  0,  0,  0,  9, 10,  1,  0,
#          8,  8, 11,  9,  7,  8,  0,  0,  0,  3,  0,  0, 11,  0,  2, 12,  0,  5,
#          2,  5,  0,  6,  1,  1,  5,  4,  3, 13,  0,  0,  4,  9,  0,  4,  3,  5,
#          9,  9,  1,  7,  0,  7,  4,  1,  9,  4,  6,  8,  7,  3,  3, 13,  9, 12,
#          0,  5,  5,  0,  6, 11,  9,  3,  0,  1,  3,  5,  4,  1,  0, 12,  0,  0,
#         10,  3])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([13,  4,  2,  0,  9, 11,  7,  0,  6,  0,  3, 12, 11,  9, 10,  4,  1,  7,
#          5, 11, 10, 10, 12,  0,  5,  0,  7,  0,  0,  3,  1,  1,  8, 10,  0,  4,
#          0,  1,  0,  0,  5,  1, 12,  0, 13,  0,  5,  7,  5,  7,  1, 10,  5,  6,
#          6,  0,  5,  9,  4,  1,  1,  0,  1,  8,  2,  5,  9,  0,  0,  4,  8,  4,
#          0,  9,  9,  4,  8,  9,  6, 11,  4, 10,  1,  0, 11, 11,  6,  4, 10,  5,
#          4, 11,  5,  1,  7,  4,  0,  3, 13,  5, 11,  1,  6,  3,  0,  2,  4,  0,
#          1,  4,  0,  3,  0,  9, 13,  3,  0,  5,  1,  5,  5,  5,  4,  0,  3, 12,
#          0,  9])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 3, 13,  1,  4,  0, 10,  9,  9,  9, 10,  1,  1,  4, 11,  6, 11, 12, 12,
#         12,  0,  0,  4,  4,  4,  9,  0,  5,  9, 10,  1,  4, 12, 11,  4,  5,  0,
#          1,  0,  4,  2,  1,  7,  0,  4,  7,  9, 12,  0,  4,  9,  7,  1,  5, 11,
#          4, 11,  8,  4, 11, 13,  4,  0,  4,  1,  9,  9, 13,  0,  5,  0,  5,  9,
#          0,  3,  1,  0, 12,  8, 10,  0,  4,  4,  1, 13,  8,  5, 10,  8,  1,  5,
#          5,  0, 10,  4,  0, 10,  1,  2,  9,  8,  9,  9,  0,  1, 11, 13,  1,  5,
#          0,  8,  0,  2,  9,  0,  0,  1,  4, 11,  1, 13,  0,  1,  0,  1,  1,  1,
#         13,  0])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 4,  6, 11,  5,  0,  9,  0,  9,  5,  5,  9,  2, 12,  2,  5,  0,  9,  4,
#          3,  0,  2, 11,  9,  8,  4,  5,  3,  1,  0,  7,  7,  1, 11, 12,  0,  0,
#          3, 13,  9,  1,  0,  8,  9, 13, 11, 11,  5,  0, 13,  9,  9,  7,  4,  0,
#          4,  2,  5,  5,  6, 13,  0, 10,  9,  4,  2,  0, 13, 12, 12,  0,  1, 10,
#          9,  1,  9,  4,  9, 11,  4,  5,  4,  2,  4,  4,  8,  4, 12,  0,  1,  7,
#          0,  3,  4,  1,  5,  1,  0, 10,  0,  4,  0, 11,  0,  6,  1, 12,  2,  1,
#          9,  0,  1,  9,  0, 10,  1,  9,  4,  0,  4, 11,  9,  5,  0, 11,  5,  3,
#          0,  0])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 9,  5, 11,  1,  9,  2,  2,  0,  0, 10,  1,  4,  4,  6,  5, 13,  0,  7,
#          1,  7,  6,  0,  3,  4,  0,  4,  3,  5,  0,  4,  0,  0,  0,  7,  2,  4,
#          8,  5, 13,  9,  5,  7,  7, 10,  0,  9,  5,  0,  1, 12,  4,  5,  0,  4,
#          4,  3, 13,  1,  7, 12,  0,  0,  9,  6, 11,  0, 10,  9,  0,  0, 11,  6,
#          0, 10,  0,  2,  6,  1,  7,  0,  3,  0,  4,  5,  5, 11,  9, 12,  5, 10,
#          6,  9, 12,  1, 10,  0,  9,  8,  1,  0,  9,  1,  6,  4, 10,  5,  4,  0,
#          2,  0,  5,  3,  5,  0,  9,  0,  0,  9,  3,  7,  0,  0,  6,  5,  5,  1,
#          5,  0])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 4,  2,  0,  4,  6,  4,  7, 10,  8,  1,  0,  5,  5,  1,  3,  1,  4,  1,
#          4,  0,  1,  5,  0,  4, 13, 12,  0,  0,  0,  2,  1, 12,  0,  4,  0,  4,
#          2,  0,  5,  4,  5,  2,  5,  0,  4,  0, 13,  9,  9,  0,  0,  3, 10,  0,
#          5,  0,  5,  5,  0,  0,  0,  2,  4,  4,  6,  0,  1, 13,  1,  6,  5,  9,
#          0,  1,  0,  5,  8,  0,  9,  0,  5,  5,  0, 13,  9, 10, 11,  0, 10,  7,
#          0,  0,  0,  1, 11,  2,  5,  7,  4,  0, 13,  2, 12,  5, 10, 11,  6, 13,
#          0,  9,  6,  0,  0, 12,  6,  0,  5,  9,  0, 11, 11, 11, 11,  0,  5,  5,
#          0, 10])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 3,  1,  0, 11, 12, 10, 11,  0,  4,  1,  0,  0,  0,  4,  5, 13, 10,  1,
#          4,  7,  2, 10,  0,  9,  0,  2,  6,  9,  4,  9,  9,  0,  0,  0,  0,  6,
#          1,  4,  4, 13,  0, 12,  0,  3,  2,  4, 12,  5,  0,  1,  0,  5,  0,  9,
#         12,  6,  1,  0,  4,  3,  0,  1,  5,  0,  1,  0,  0, 12,  4,  1, 10,  1,
#          0,  4,  0, 12,  9,  4,  5,  9,  2, 12, 11,  1, 12,  9,  4,  5,  9,  0,
#         12,  0,  7,  1,  4,  1,  2,  1,  2,  8, 10,  7,  0, 12,  5,  9,  0, 13,
#         13,  5,  8,  6,  1, 10,  0,  8,  0, 13, 12,  4, 11,  0, 10,  9,  4,  7,
#         12, 11])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 4,  4,  4,  4,  9,  4,  0,  2,  0,  0,  1,  5,  0, 13, 12,  4,  5,  1,
#          0,  0, 11,  0,  9,  0,  9,  8,  3,  0,  4,  1,  5,  2,  4,  0,  0,  7,
#          0,  5,  5,  9,  4,  5,  4,  1, 12,  5,  0,  5,  0,  2,  3,  7, 13,  9,
#          4,  4,  0,  9,  5,  9, 10,  0,  0,  2,  9,  1,  0,  0,  5,  3,  0,  5,
#          4,  4, 11,  1,  5, 12,  2,  5,  2,  8,  9,  4,  0, 10,  1,  2,  4, 11,
#         10,  5,  4,  5, 10,  0,  0,  0,  0,  1,  4,  5,  6,  0, 13,  5,  1,  9,
#          0,  1, 10,  9,  4,  9,  0, 10,  0,  0,  5,  0,  4,  0,  5,  0,  0,  2,
#          0,  6])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 7,  8,  5,  4, 12,  9, 13,  1,  0,  0,  5,  1,  7,  0,  0,  0,  5,  0,
#         13,  3,  7, 11,  1,  9,  1,  7,  0,  0,  0,  4,  0,  0,  5,  1,  6,  8,
#          0,  1,  9,  5,  2,  5,  0,  1,  4,  3,  4,  0, 10, 11,  8, 13,  0,  0,
#          0,  4, 13,  8,  5,  0,  5,  4,  1,  1,  4,  9,  9,  0,  0,  1,  0,  6,
#          9,  0,  2,  6,  9,  4,  9,  5,  0, 11,  5,  9,  5, 10,  9,  0,  0,  5,
#          4,  8,  0,  0,  2,  9,  0,  5,  7,  5,  8,  7,  5,  3,  2,  4,  0,  5,
#          1,  0,  1,  1,  0,  0,  1,  0,  0,  9,  9, 12, 10,  4,  0,  0,  9,  9,
#          2, 13])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 4,  1,  8, 11,  1,  0, 13,  0,  0,  8, 12,  2,  5,  1,  1,  5,  5,  9,
#         11,  4,  2,  7, 10,  1,  6, 13,  5,  5,  5, 11,  0, 11,  0,  1,  0,  1,
#          5,  0,  4,  9, 13,  4,  6, 12,  4,  0,  4,  0, 13, 12, 10,  9,  0,  1,
#          1,  7,  1,  0,  1,  6,  1,  4,  4,  9,  6, 11,  0,  0,  4,  9,  1,  1,
#          2,  7, 11,  9, 12,  0, 10,  6,  4,  4,  7,  2,  7, 12,  9, 11,  3,  1,
#          5,  5,  8,  4,  5,  7, 11,  0, 13,  0,  0,  2,  0,  0,  4,  0,  0, 12,
#          0,  4, 12, 12,  5,  4,  9, 12,  2,  0,  5,  2,  3, 13,  5,  2, 13,  4,
#          2, 11])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 9,  0, 12,  5,  6,  3,  2,  1,  5,  0, 13, 11, 10,  0,  0,  1,  1,  7,
#          4, 10,  1, 11, 11,  4, 10,  0, 13,  0, 12,  3,  4, 10,  2,  9,  0,  0,
#          0,  4, 10,  3, 12,  0,  1, 13,  1,  5,  0, 10,  4,  8, 13,  9,  5,  4,
#          8,  4,  0,  0,  0, 10, 11,  4,  9,  5,  5,  1,  0, 11,  4, 13,  9,  4,
#         12,  0,  9,  0,  9,  8,  0,  0, 12, 11,  9,  1, 12,  0,  1,  4,  6,  1,
#          0, 13,  2,  1,  0, 10,  0,  9,  9,  5,  9, 12,  4,  4,  6,  9,  9,  6,
#          4,  8,  0,  9,  9,  0,  2,  5,  9,  2,  5,  4,  0,  2,  9,  0,  0,  9,
#          0,  1])
# Shape of X [N, C, H, W]: torch.Size([128, 1, 32, 32])
# Shape of y: torch.Size([128]) torch.int64
# tensor([ 2,  6,  5,  1,  2,  0,  3,  4,  9,  5,  0,  5,  5,  1,  5,  0,  0,  4,
#          0,  7, 10,  0,  7,  9, 10,  0,  0, 10,  7,  1,  5,  9,  0, 10,  0,  4,
#          0,  0, 10,  0,  5,  0,  2, 11, 10,  1,  0,  1,  6, 11, 11,  5,  5,  7,
#         10,  5,  4,  0,  8,  1, 11,  4,  9, 10,  7,  5,  8, 11,  6,  2,  0, 10,
#          0, 12,  0,  0,  0,  0,  0,  3,  7,  3,  9,  5, 11,  9, 11,  6,  2,  1,
#          4,  0,  9,  0,  8,  5, 12,  0,  7, 12,  1,  5, 12,  5, 12,  4,  0,  6,
#         11,  0, 13,  5,  8,  3,  2,  0, 10,  7, 11,  0,  9, 10,  1,  4,  0,  4,
#          5,  4])
# Shape of X [N, C, H, W]: torch.Size([26, 1, 32, 32])
# Shape of y: torch.Size([26]) torch.int64
# tensor([ 9,  4,  1,  9,  1, 10,  0,  1,  9, 13,  5,  4,  4, 13,  5,  1, 12,  4,
#         12,  0,  1, 11,  4,  0,  0,  5])

# %%
from torch import nn

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
import torch.nn.functional as F

# Define model
# class NeuralNetwork(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.conv1 = nn.Conv2d(1, 6, 5)
#         self.pool = nn.MaxPool2d(2, 2)
#         self.conv2 = nn.Conv2d(6, 16, 5)
#         self.fc1 = nn.Linear(16 * 5 * 5, 120)
#         self.fc2 = nn.Linear(120, 84)
#         self.fc3 = nn.Linear(84, len(labels_map.keys()))
#         # self.flatten = nn.Flatten()
#         # self.linear_relu_stack = nn.Sequential(
#         #     # nn.Conv2d(1, 6, 5),
#         #     nn.Linear(num_mfcc*num_time_steps, 512),
#         #     nn.ReLU(),
#         #     nn.Linear(512, 512),
#         #     nn.ReLU(),
#         #     nn.Linear(512, len(labels_map.keys()))
#         # )

#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))
#         x = self.pool(F.relu(self.conv2(x)))
#         x = torch.flatten(x, 1) # flatten all dimensions except batch
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = self.fc3(x)
#         return x
#         # x = self.flatten(x)
#         # logits = self.linear_relu_stack(x)
#         # return logits

import torch
import torch.nn as nn
import torch.nn.functional as F

r_in = 0.8
r_hidden = 0.5

class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.dropout0 = nn.Dropout(1-r_in)
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.dropout1 = nn.Dropout(1 - r_hidden)
        # self.conv2 = nn.Conv2d(6, 6, 5)
        # self.dropout2 = nn.Dropout(1 - r_hidden)
        self.conv3 = nn.Conv2d(6, 16, 5)
        self.dropout2 = nn.Dropout(1 - r_hidden)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.dropout3 = nn.Dropout(1 - r_hidden)
        self.fc2 = nn.Linear(120, 84)
        self.dropout4 = nn.Dropout(1 - r_hidden)
        # self.fc3 = nn.Linear(84, 84)
        # self.dropout5 = nn.Dropout(1 - r_hidden)
        # self.fc4 = nn.Linear(84, 42)
        # self.dropout6 = nn.Dropout(1 - r_hidden)
        self.fc3 = nn.Linear(84, len(labels_map.keys()))

    def forward(self, input):
        x = F.relu(self.conv1(self.dropout0(input)))
        
        # x = F.max_pool2d(x, (2, 2))
        # x = F.relu(self.conv2(x))
        
        x = self.dropout1(x)
        x = F.max_pool2d(x, (2, 2))
        x = F.relu(self.conv3(x))

        x = self.dropout2(x)
        x = F.max_pool2d(x, 2)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        
        x = self.dropout3(x)
        x = F.relu(self.fc2(x))
        
        x = self.dropout4(x)
        output = self.fc3(x)
        # c1 = F.relu(self.conv1(input))
        # s2 = F.max_pool2d(c1, (2, 2))
        # c3 = F.relu(self.conv2(s2))
        # s4 = F.max_pool2d(c3, 2)
        # s4 = torch.flatten(s4, 1)
        # f5 = F.relu(self.fc1(s4))
        # f6 = F.relu(self.fc2(f5))
        # output = self.fc3(f6)
        return output


net = Net()
print(net)

model = Net().to(device)
print(model)
# Out:
# Using cpu device
# Net(
#   (dropout0): Dropout(p=0.19999999999999996, inplace=False)
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (conv3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (dropout3): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (dropout4): Dropout(p=0.5, inplace=False)
#   (fc3): Linear(in_features=84, out_features=14, bias=True)
# )
# Net(
#   (dropout0): Dropout(p=0.19999999999999996, inplace=False)
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (conv3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (dropout3): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (dropout4): Dropout(p=0.5, inplace=False)
#   (fc3): Linear(in_features=84, out_features=14, bias=True)
# )

# %%
train_dataloader

# %%
import torch.optim as optim

# criterion = nn.CrossEntropyLoss()
# optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# for epoch in range(2):  # loop over the dataset multiple times

#     running_loss = 0.0
#     for i, data in enumerate(train_dataloader, 0):
#         # get the inputs; data is a list of [inputs, labels]
#         inputs, labels = data

#         # zero the parameter gradients
#         optimizer.zero_grad()

#         # forward + backward + optimize
#         outputs = model(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()

#         # print statistics
#         running_loss += loss.item()
#         if i % 2000 == 1999:    # print every 2000 mini-batches
#             print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
#             running_loss = 0.0

# print('Finished Training')
import matplotlib.pyplot as plt

loss_fn = nn.CrossEntropyLoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3, momentum=0.4)

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    


def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return 1-correct

train_error = []
test_error = []
epochs = 60000
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test_error.append(test(test_dataloader, model, loss_fn))
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 7.606037  [  128/ 2330]
# Test Error:
#  Accuracy: 28.6%, Avg loss: 2.543368
#
# Epoch 2
# -------------------------------
# loss: 2.490501  [  128/ 2330]
# Test Error:
#  Accuracy: 28.6%, Avg loss: 2.468325
#
# Epoch 3
# -------------------------------
# loss: 2.432753  [  128/ 2330]
# Test Error:
#  Accuracy: 32.4%, Avg loss: 2.416655
#
# Epoch 4
# -------------------------------
# loss: 2.321445  [  128/ 2330]
# Test Error:
#  Accuracy: 40.7%, Avg loss: 2.329642
#
# Epoch 5
# -------------------------------
# loss: 2.263733  [  128/ 2330]
# Test Error:
#  Accuracy: 45.1%, Avg loss: 2.153696
#
# Epoch 6
# -------------------------------
# loss: 2.103109  [  128/ 2330]
# Test Error:
#  Accuracy: 52.1%, Avg loss: 2.046708
#
# Epoch 7
# -------------------------------
# loss: 1.866183  [  128/ 2330]
# Test Error:
#  Accuracy: 58.1%, Avg loss: 1.942512
#
# Epoch 8
# -------------------------------
# loss: 1.723423  [  128/ 2330]
# Test Error:
#  Accuracy: 61.4%, Avg loss: 1.984003
#
# Epoch 9
# -------------------------------
# loss: 1.624223  [  128/ 2330]
# Test Error:
#  Accuracy: 65.4%, Avg loss: 1.785341
#
# Epoch 10
# -------------------------------
# loss: 1.530425  [  128/ 2330]
# Test Error:
#  Accuracy: 64.3%, Avg loss: 1.719844
#
# Epoch 11
# -------------------------------
# loss: 1.335291  [  128/ 2330]
# Test Error:
#  Accuracy: 68.1%, Avg loss: 1.650775
#
# Epoch 12
# -------------------------------
# loss: 1.369590  [  128/ 2330]
# Test Error:
#  Accuracy: 70.3%, Avg loss: 1.563656
#
# Epoch 13
# -------------------------------
# loss: 1.386971  [  128/ 2330]
# Test Error:
#  Accuracy: 70.7%, Avg loss: 1.573625
#
# Epoch 14
# -------------------------------
# loss: 1.262158  [  128/ 2330]
# Test Error:
#  Accuracy: 71.5%, Avg loss: 1.533789
#
# Epoch 15
# -------------------------------
# loss: 1.224313  [  128/ 2330]
# Test Error:
#  Accuracy: 71.7%, Avg loss: 1.416704
#
# Epoch 16
# -------------------------------
# loss: 1.171438  [  128/ 2330]
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.427010
#
# Epoch 17
# -------------------------------
# loss: 1.317958  [  128/ 2330]
# Test Error:
#  Accuracy: 73.1%, Avg loss: 1.342986
#
# Epoch 18
# -------------------------------
# loss: 1.074528  [  128/ 2330]
# Test Error:
#  Accuracy: 72.6%, Avg loss: 1.326888
#
# Epoch 19
# -------------------------------
# loss: 1.157169  [  128/ 2330]
# Test Error:
#  Accuracy: 76.5%, Avg loss: 1.333218
#
# Epoch 20
# -------------------------------
# loss: 0.909008  [  128/ 2330]
# Test Error:
#  Accuracy: 67.8%, Avg loss: 1.627319
#
# Epoch 21
# -------------------------------
# loss: 1.317742  [  128/ 2330]
# Test Error:
#  Accuracy: 76.3%, Avg loss: 1.258447
#
# Epoch 22
# -------------------------------
# loss: 1.121765  [  128/ 2330]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 1.174664
#
# Epoch 23
# -------------------------------
# loss: 0.913833  [  128/ 2330]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 1.150491
#
# Epoch 24
# -------------------------------
# loss: 0.889698  [  128/ 2330]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 1.102026
#
# Epoch 25
# -------------------------------
# loss: 0.944861  [  128/ 2330]
# Test Error:
#  Accuracy: 82.0%, Avg loss: 1.113569
#
# Epoch 26
# -------------------------------
# loss: 1.061421  [  128/ 2330]
# Test Error:
#  Accuracy: 79.4%, Avg loss: 1.070819
#
# Epoch 27
# -------------------------------
# loss: 0.994176  [  128/ 2330]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 1.075666
#
# Epoch 28
# -------------------------------
# loss: 0.685915  [  128/ 2330]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 1.071870
#
# Epoch 29
# -------------------------------
# loss: 0.933300  [  128/ 2330]
# Test Error:
#  Accuracy: 80.6%, Avg loss: 1.034568
#
# Epoch 30
# -------------------------------
# loss: 0.898018  [  128/ 2330]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.992927
#
# Epoch 31
# -------------------------------
# loss: 0.688269  [  128/ 2330]
# Test Error:
#  Accuracy: 79.9%, Avg loss: 0.953491
#
# Epoch 32
# -------------------------------
# loss: 0.997862  [  128/ 2330]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.941297
#
# Epoch 33
# -------------------------------
# loss: 0.807509  [  128/ 2330]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 1.026024
#
# Epoch 34
# -------------------------------
# loss: 0.727567  [  128/ 2330]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.892878
#
# Epoch 35
# -------------------------------
# loss: 0.836941  [  128/ 2330]
# Test Error:
#  Accuracy: 81.5%, Avg loss: 0.853143
#
# Epoch 36
# -------------------------------
# loss: 0.800018  [  128/ 2330]
# Test Error:
#  Accuracy: 80.4%, Avg loss: 0.855035
#
# Epoch 37
# -------------------------------
# loss: 0.865034  [  128/ 2330]
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.883325
#
# Epoch 38
# -------------------------------
# loss: 0.790154  [  128/ 2330]
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.881300
#
# Epoch 39
# -------------------------------
# loss: 0.891865  [  128/ 2330]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.855754
#
# Epoch 40
# -------------------------------
# loss: 0.863035  [  128/ 2330]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.856642
#
# Epoch 41
# -------------------------------
# loss: 0.741245  [  128/ 2330]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.872416
#
# Epoch 42
# -------------------------------
# loss: 0.756522  [  128/ 2330]
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.837232
#
# Epoch 43
# -------------------------------
# loss: 0.680351  [  128/ 2330]
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.812203
#
# Epoch 44
# -------------------------------
# loss: 0.665541  [  128/ 2330]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.809254
#
# Epoch 45
# -------------------------------
# loss: 0.655548  [  128/ 2330]
# Test Error:
#  Accuracy: 81.5%, Avg loss: 0.771930
#
# Epoch 46
# -------------------------------
# loss: 0.667499  [  128/ 2330]
# Test Error:
#  Accuracy: 80.8%, Avg loss: 0.804536
#
# Epoch 47
# -------------------------------
# loss: 0.695133  [  128/ 2330]
# Test Error:
#  Accuracy: 81.3%, Avg loss: 0.815334
#
# Epoch 48
# -------------------------------
# loss: 0.611707  [  128/ 2330]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.789352
#
# Epoch 49
# -------------------------------
# loss: 0.741826  [  128/ 2330]
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.771447
#
# Epoch 50
# -------------------------------
# loss: 0.666810  [  128/ 2330]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.806542
#
# Epoch 51
# -------------------------------
# loss: 0.658950  [  128/ 2330]
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.736217
#
# Epoch 52
# -------------------------------
# loss: 0.718449  [  128/ 2330]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.766560
#
# Epoch 53
# -------------------------------
# loss: 0.800914  [  128/ 2330]
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.735039
#
# Epoch 54
# -------------------------------
# loss: 0.769179  [  128/ 2330]
# Test Error:
#  Accuracy: 83.4%, Avg loss: 0.744018
#
# Epoch 55
# -------------------------------
# loss: 0.645223  [  128/ 2330]
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.717332
#
# Epoch 56
# -------------------------------
# loss: 0.664080  [  128/ 2330]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.727288
#
# Epoch 57
# -------------------------------
# loss: 0.569203  [  128/ 2330]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.701923
#
# Epoch 58
# -------------------------------
# loss: 0.522134  [  128/ 2330]
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.751856
#
# Epoch 59
# -------------------------------
# loss: 0.644965  [  128/ 2330]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.695226
#
# Epoch 60
# -------------------------------
# loss: 0.630571  [  128/ 2330]
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.756015
#
# Epoch 61
# -------------------------------
# loss: 0.805988  [  128/ 2330]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.687482
#
# Epoch 62
# -------------------------------
# loss: 0.457660  [  128/ 2330]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.703846
#
# Epoch 63
# -------------------------------
# loss: 0.636583  [  128/ 2330]
# Test Error:
#  Accuracy: 85.6%, Avg loss: 0.675171
#
# Epoch 64
# -------------------------------
# loss: 0.583156  [  128/ 2330]
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.662873
#
# Epoch 65
# -------------------------------
# loss: 0.661246  [  128/ 2330]
# Test Error:
#  Accuracy: 84.7%, Avg loss: 0.664146
#
# Epoch 66
# -------------------------------
# loss: 0.616913  [  128/ 2330]
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.667779
#
# Epoch 67
# -------------------------------
# loss: 0.601160  [  128/ 2330]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.658461
#
# Epoch 68
# -------------------------------
# loss: 0.465315  [  128/ 2330]
# Test Error:
#  Accuracy: 84.7%, Avg loss: 0.650720
#
# Epoch 69
# -------------------------------
# loss: 0.547759  [  128/ 2330]
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.665711
#
# Epoch 70
# -------------------------------
# loss: 0.678250  [  128/ 2330]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.654961
#
# Epoch 71
# -------------------------------
# loss: 0.625046  [  128/ 2330]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.642329
#
# Epoch 72
# -------------------------------
# loss: 0.683708  [  128/ 2330]
# Test Error:
#  Accuracy: 83.5%, Avg loss: 0.650893
#
# Epoch 73
# -------------------------------
# loss: 0.684550  [  128/ 2330]
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.636784
#
# Epoch 74
# -------------------------------
# loss: 0.539409  [  128/ 2330]
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.640221
#
# Epoch 75
# -------------------------------
# loss: 0.593588  [  128/ 2330]
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.682726
#
# Epoch 76
# -------------------------------
# loss: 0.528589  [  128/ 2330]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.632883
#
# Epoch 77
# -------------------------------
# loss: 0.499356  [  128/ 2330]
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.644517
#
# Epoch 78
# -------------------------------
# loss: 0.608074  [  128/ 2330]
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.643305
#
# Epoch 79
# -------------------------------
# loss: 0.553013  [  128/ 2330]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.614712
#
# Epoch 80
# -------------------------------
# loss: 0.690940  [  128/ 2330]
# Test Error:
#  Accuracy: 86.3%, Avg loss: 0.620164
#
# Epoch 81
# -------------------------------
# loss: 0.568398  [  128/ 2330]
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.635005
#
# Epoch 82
# -------------------------------
# loss: 0.674284  [  128/ 2330]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.589908
#
# Epoch 83
# -------------------------------
# loss: 0.502486  [  128/ 2330]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.626454
#
# Epoch 84
# -------------------------------
# loss: 0.548917  [  128/ 2330]
# Test Error:
#  Accuracy: 83.5%, Avg loss: 0.606924
#
# Epoch 85
# -------------------------------
# loss: 0.571189  [  128/ 2330]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.642227
#
# Epoch 86
# -------------------------------
# loss: 0.630236  [  128/ 2330]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.601531
#
# Epoch 87
# -------------------------------
# loss: 0.617987  [  128/ 2330]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.602683
#
# Epoch 88
# -------------------------------
# loss: 0.659059  [  128/ 2330]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.611697
#
# Epoch 89
# -------------------------------
# loss: 0.419647  [  128/ 2330]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.599335
#
# Epoch 90
# -------------------------------
# loss: 0.523347  [  128/ 2330]
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.621497
#
# Epoch 91
# -------------------------------
# loss: 0.686611  [  128/ 2330]
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.580364
#
# Epoch 92
# -------------------------------
# loss: 0.604002  [  128/ 2330]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.577194
#
# Epoch 93
# -------------------------------
# loss: 0.520460  [  128/ 2330]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.593267
#
# Epoch 94
# -------------------------------
# loss: 0.484102  [  128/ 2330]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.586537
#
# Epoch 95
# -------------------------------
# loss: 0.432483  [  128/ 2330]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.559166
#
# Epoch 96
# -------------------------------
# loss: 0.537654  [  128/ 2330]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.547605
#
# Epoch 97
# -------------------------------
# loss: 0.518020  [  128/ 2330]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.582524
#
# Epoch 98
# -------------------------------
# loss: 0.440307  [  128/ 2330]
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.556277
#
# Epoch 99
# -------------------------------
# loss: 0.499951  [  128/ 2330]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.532656
#
# Epoch 100
# -------------------------------
# loss: 0.563301  [  128/ 2330]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.554258
#
# Epoch 101
# -------------------------------
# loss: 0.550761  [  128/ 2330]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.537646
#
# Epoch 102
# -------------------------------
# loss: 0.423035  [  128/ 2330]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.534561
#
# Epoch 103
# -------------------------------
# loss: 0.442480  [  128/ 2330]
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.520817
#
# Epoch 104
# -------------------------------
# loss: 0.418861  [  128/ 2330]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.550688
#
# Epoch 105
# -------------------------------
# loss: 0.485269  [  128/ 2330]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.536723
#
# Epoch 106
# -------------------------------
# loss: 0.479127  [  128/ 2330]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.554766
#
# Epoch 107
# -------------------------------
# loss: 0.413594  [  128/ 2330]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.533024
#
# Epoch 108
# -------------------------------
# loss: 0.589118  [  128/ 2330]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.528976
#
# Epoch 109
# -------------------------------
# loss: 0.628203  [  128/ 2330]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.540099
#
# Epoch 110
# -------------------------------
# loss: 0.413528  [  128/ 2330]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.542711
#
# Epoch 111
# -------------------------------
# loss: 0.580787  [  128/ 2330]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.526689
#
# Epoch 112
# -------------------------------
# loss: 0.547927  [  128/ 2330]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.519803
#
# Epoch 113
# -------------------------------
# loss: 0.330143  [  128/ 2330]
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.512499
#
# Epoch 114
# -------------------------------
# loss: 0.412352  [  128/ 2330]
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.520097
#
# Epoch 115
# -------------------------------
# loss: 0.408334  [  128/ 2330]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.506129
#
# Epoch 116
# -------------------------------
# loss: 0.455651  [  128/ 2330]
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.529495
#
# Epoch 117
# -------------------------------
# loss: 0.439924  [  128/ 2330]
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.510091
#
# Epoch 118
# -------------------------------
# loss: 0.516341  [  128/ 2330]
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.489707
#
# Epoch 119
# -------------------------------
# loss: 0.303722  [  128/ 2330]
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.509677
#
# Epoch 120
# -------------------------------
# loss: 0.509003  [  128/ 2330]
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.521518
#
# Epoch 121
# -------------------------------
# loss: 0.367285  [  128/ 2330]
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.501911
#
# Epoch 122
# -------------------------------
# loss: 0.420048  [  128/ 2330]
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.491354
#
# Epoch 123
# -------------------------------
# loss: 0.475986  [  128/ 2330]
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.487650
#
# Epoch 124
# -------------------------------
# loss: 0.439154  [  128/ 2330]
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.483931
#
# Epoch 125
# -------------------------------
# loss: 0.436885  [  128/ 2330]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.487851
#
# Epoch 126
# -------------------------------
# loss: 0.453872  [  128/ 2330]
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.471373
#
# Epoch 127
# -------------------------------
# loss: 0.438246  [  128/ 2330]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.487427
#
# Epoch 128
# -------------------------------
# loss: 0.536863  [  128/ 2330]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.495454
#
# Epoch 129
# -------------------------------
# loss: 0.445853  [  128/ 2330]
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.466589
#
# Epoch 130
# -------------------------------
# loss: 0.529220  [  128/ 2330]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.470782
#
# Epoch 131
# -------------------------------
# loss: 0.454306  [  128/ 2330]
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.465785
#
# Epoch 132
# -------------------------------
# loss: 0.364139  [  128/ 2330]
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.467350
#
# Epoch 133
# -------------------------------
# loss: 0.432973  [  128/ 2330]
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.491727
#
# Epoch 134
# -------------------------------
# loss: 0.540359  [  128/ 2330]
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.468643
#
# Epoch 135
# -------------------------------
# loss: 0.525135  [  128/ 2330]
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.489159
#
# Epoch 136
# -------------------------------
# loss: 0.441025  [  128/ 2330]
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.478888
#
# Epoch 137
# -------------------------------
# loss: 0.313045  [  128/ 2330]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.458837
#
# Epoch 138
# -------------------------------
# loss: 0.466696  [  128/ 2330]
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.465476
#
# Epoch 139
# -------------------------------
# loss: 0.372498  [  128/ 2330]
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.438932
#
# Epoch 140
# -------------------------------
# loss: 0.263295  [  128/ 2330]
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.454929
#
# Epoch 141
# -------------------------------
# loss: 0.442532  [  128/ 2330]
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.462972
#
# Epoch 142
# -------------------------------
# loss: 0.478198  [  128/ 2330]
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.472602
#
# Epoch 143
# -------------------------------
# loss: 0.526730  [  128/ 2330]
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.472189
#
# Epoch 144
# -------------------------------
# loss: 0.362942  [  128/ 2330]
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.446277
#
# Epoch 145
# -------------------------------
# loss: 0.269940  [  128/ 2330]
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.440451
#
# Epoch 146
# -------------------------------
# loss: 0.454977  [  128/ 2330]
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.447452
#
# Epoch 147
# -------------------------------
# loss: 0.443693  [  128/ 2330]
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.438934
#
# Epoch 148
# -------------------------------
# loss: 0.388759  [  128/ 2330]
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.424009
#
# Epoch 149
# -------------------------------
# loss: 0.376162  [  128/ 2330]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.416294
#
# Epoch 150
# -------------------------------
# loss: 0.500603  [  128/ 2330]
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.419754
#
# Epoch 151
# -------------------------------
# loss: 0.513642  [  128/ 2330]
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.455449
#
# Epoch 152
# -------------------------------
# loss: 0.321376  [  128/ 2330]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.467241
#
# Epoch 153
# -------------------------------
# loss: 0.524810  [  128/ 2330]
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.427737
#
# Epoch 154
# -------------------------------
# loss: 0.512546  [  128/ 2330]
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.452378
#
# Epoch 155
# -------------------------------
# loss: 0.555623  [  128/ 2330]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.439046
#
# Epoch 156
# -------------------------------
# loss: 0.317774  [  128/ 2330]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.433309
#
# Epoch 157
# -------------------------------
# loss: 0.446874  [  128/ 2330]
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.451780
#
# Epoch 158
# -------------------------------
# loss: 0.486143  [  128/ 2330]
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.426777
#
# Epoch 159
# -------------------------------
# loss: 0.440871  [  128/ 2330]
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.405916
#
# Epoch 160
# -------------------------------
# loss: 0.332279  [  128/ 2330]
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.390002
#
# Epoch 161
# -------------------------------
# loss: 0.470718  [  128/ 2330]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.403878
#
# Epoch 162
# -------------------------------
# loss: 0.367609  [  128/ 2330]
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.392654
#
# Epoch 163
# -------------------------------
# loss: 0.285884  [  128/ 2330]
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.413828
#
# Epoch 164
# -------------------------------
# loss: 0.321666  [  128/ 2330]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.402277
#
# Epoch 165
# -------------------------------
# loss: 0.375572  [  128/ 2330]
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.395879
#
# Epoch 166
# -------------------------------
# loss: 0.310289  [  128/ 2330]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.403423
#
# Epoch 167
# -------------------------------
# loss: 0.318334  [  128/ 2330]
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.415541
#
# Epoch 168
# -------------------------------
# loss: 0.321136  [  128/ 2330]
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.396731
#
# Epoch 169
# -------------------------------
# loss: 0.421041  [  128/ 2330]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.378224
#
# Epoch 170
# -------------------------------
# loss: 0.268661  [  128/ 2330]
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.388065
#
# Epoch 171
# -------------------------------
# loss: 0.376499  [  128/ 2330]
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.383508
#
# Epoch 172
# -------------------------------
# loss: 0.274002  [  128/ 2330]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.385333
#
# Epoch 173
# -------------------------------
# loss: 0.346215  [  128/ 2330]
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.367119
#
# Epoch 174
# -------------------------------
# loss: 0.505694  [  128/ 2330]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.382039
#
# Epoch 175
# -------------------------------
# loss: 0.320206  [  128/ 2330]
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.431201
#
# Epoch 176
# -------------------------------
# loss: 0.411026  [  128/ 2330]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.380898
#
# Epoch 177
# -------------------------------
# loss: 0.207507  [  128/ 2330]
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.370458
#
# Epoch 178
# -------------------------------
# loss: 0.447772  [  128/ 2330]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.365297
#
# Epoch 179
# -------------------------------
# loss: 0.393361  [  128/ 2330]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.374144
#
# Epoch 180
# -------------------------------
# loss: 0.219568  [  128/ 2330]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.358764
#
# Epoch 181
# -------------------------------
# loss: 0.361582  [  128/ 2330]
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.384857
#
# Epoch 182
# -------------------------------
# loss: 0.484996  [  128/ 2330]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.371930
#
# Epoch 183
# -------------------------------
# loss: 0.247126  [  128/ 2330]
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.390848
#
# Epoch 184
# -------------------------------
# loss: 0.541983  [  128/ 2330]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.346230
#
# Epoch 185
# -------------------------------
# loss: 0.253385  [  128/ 2330]
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.370450
#
# Epoch 186
# -------------------------------
# loss: 0.284165  [  128/ 2330]
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.357236
#
# Epoch 187
# -------------------------------
# loss: 0.257321  [  128/ 2330]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.364002
#
# Epoch 188
# -------------------------------
# loss: 0.397027  [  128/ 2330]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.368543
#
# Epoch 189
# -------------------------------
# loss: 0.336786  [  128/ 2330]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.361281
#
# Epoch 190
# -------------------------------
# loss: 0.334468  [  128/ 2330]
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.348470
#
# Epoch 191
# -------------------------------
# loss: 0.377517  [  128/ 2330]
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.358060
#
# Epoch 192
# -------------------------------
# loss: 0.250335  [  128/ 2330]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.395857
#
# Epoch 193
# -------------------------------
# loss: 0.393597  [  128/ 2330]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.350522
#
# Epoch 194
# -------------------------------
# loss: 0.323821  [  128/ 2330]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.360308
#
# Epoch 195
# -------------------------------
# loss: 0.285235  [  128/ 2330]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.345498
#
# Epoch 196
# -------------------------------
# loss: 0.512341  [  128/ 2330]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.348544
#
# Epoch 197
# -------------------------------
# loss: 0.378930  [  128/ 2330]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.321637
#
# Epoch 198
# -------------------------------
# loss: 0.291436  [  128/ 2330]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.327750
#
# Epoch 199
# -------------------------------
# loss: 0.305051  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.329885
#
# Epoch 200
# -------------------------------
# loss: 0.374271  [  128/ 2330]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.322215
#
# Epoch 201
# -------------------------------
# loss: 0.366610  [  128/ 2330]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.345483
#
# Epoch 202
# -------------------------------
# loss: 0.333119  [  128/ 2330]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.330802
#
# Epoch 203
# -------------------------------
# loss: 0.361745  [  128/ 2330]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.340889
#
# Epoch 204
# -------------------------------
# loss: 0.401984  [  128/ 2330]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.328031
#
# Epoch 205
# -------------------------------
# loss: 0.328222  [  128/ 2330]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.350634
#
# Epoch 206
# -------------------------------
# loss: 0.335022  [  128/ 2330]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.333356
#
# Epoch 207
# -------------------------------
# loss: 0.350389  [  128/ 2330]
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.347137
#
# Epoch 208
# -------------------------------
# loss: 0.359638  [  128/ 2330]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.329470
#
# Epoch 209
# -------------------------------
# loss: 0.359328  [  128/ 2330]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.321792
#
# Epoch 210
# -------------------------------
# loss: 0.221656  [  128/ 2330]
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.362172
#
# Epoch 211
# -------------------------------
# loss: 0.312762  [  128/ 2330]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.314993
#
# Epoch 212
# -------------------------------
# loss: 0.226017  [  128/ 2330]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.319638
#
# Epoch 213
# -------------------------------
# loss: 0.268784  [  128/ 2330]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.307144
#
# Epoch 214
# -------------------------------
# loss: 0.332584  [  128/ 2330]
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.325891
#
# Epoch 215
# -------------------------------
# loss: 0.319924  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.314940
#
# Epoch 216
# -------------------------------
# loss: 0.275662  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.331625
#
# Epoch 217
# -------------------------------
# loss: 0.276586  [  128/ 2330]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.308655
#
# Epoch 218
# -------------------------------
# loss: 0.192740  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.329620
#
# Epoch 219
# -------------------------------
# loss: 0.259725  [  128/ 2330]
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.302506
#
# Epoch 220
# -------------------------------
# loss: 0.348298  [  128/ 2330]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.328043
#
# Epoch 221
# -------------------------------
# loss: 0.274143  [  128/ 2330]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.290312
#
# Epoch 222
# -------------------------------
# loss: 0.330434  [  128/ 2330]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.298919
#
# Epoch 223
# -------------------------------
# loss: 0.304773  [  128/ 2330]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.300885
#
# Epoch 224
# -------------------------------
# loss: 0.448221  [  128/ 2330]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.300777
#
# Epoch 225
# -------------------------------
# loss: 0.267067  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.309544
#
# Epoch 226
# -------------------------------
# loss: 0.318562  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.286863
#
# Epoch 227
# -------------------------------
# loss: 0.177085  [  128/ 2330]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.305544
#
# Epoch 228
# -------------------------------
# loss: 0.251675  [  128/ 2330]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.305861
#
# Epoch 229
# -------------------------------
# loss: 0.334210  [  128/ 2330]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.310280
#
# Epoch 230
# -------------------------------
# loss: 0.247524  [  128/ 2330]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.317162
#
# Epoch 231
# -------------------------------
# loss: 0.384006  [  128/ 2330]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.337593
#
# Epoch 232
# -------------------------------
# loss: 0.298889  [  128/ 2330]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.316259
#
# Epoch 233
# -------------------------------
# loss: 0.190405  [  128/ 2330]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.341498
#
# Epoch 234
# -------------------------------
# loss: 0.278106  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.320987
#
# Epoch 235
# -------------------------------
# loss: 0.287973  [  128/ 2330]
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.350804
#
# Epoch 236
# -------------------------------
# loss: 0.254779  [  128/ 2330]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.310609
#
# Epoch 237
# -------------------------------
# loss: 0.318561  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.296590
#
# Epoch 238
# -------------------------------
# loss: 0.331176  [  128/ 2330]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.310026
#
# Epoch 239
# -------------------------------
# loss: 0.453339  [  128/ 2330]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.292279
#
# Epoch 240
# -------------------------------
# loss: 0.313195  [  128/ 2330]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.295803
#
# Epoch 241
# -------------------------------
# loss: 0.281983  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.330067
#
# Epoch 242
# -------------------------------
# loss: 0.323301  [  128/ 2330]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.283274
#
# Epoch 243
# -------------------------------
# loss: 0.190416  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.277248
#
# Epoch 244
# -------------------------------
# loss: 0.279128  [  128/ 2330]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.271659
#
# Epoch 245
# -------------------------------
# loss: 0.264320  [  128/ 2330]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.269879
#
# Epoch 246
# -------------------------------
# loss: 0.139513  [  128/ 2330]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.274243
#
# Epoch 247
# -------------------------------
# loss: 0.191861  [  128/ 2330]
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.287270
#
# Epoch 248
# -------------------------------
# loss: 0.295017  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.280922
#
# Epoch 249
# -------------------------------
# loss: 0.265490  [  128/ 2330]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.260726
#
# Epoch 250
# -------------------------------
# loss: 0.353665  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.262051
#
# Epoch 251
# -------------------------------
# loss: 0.235455  [  128/ 2330]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.263013
#
# Epoch 252
# -------------------------------
# loss: 0.201920  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.268053
#
# Epoch 253
# -------------------------------
# loss: 0.312292  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.279482
#
# Epoch 254
# -------------------------------
# loss: 0.328535  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.295901
#
# Epoch 255
# -------------------------------
# loss: 0.374558  [  128/ 2330]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.269804
#
# Epoch 256
# -------------------------------
# loss: 0.311526  [  128/ 2330]
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.269526
#
# Epoch 257
# -------------------------------
# loss: 0.171916  [  128/ 2330]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.274083
#
# Epoch 258
# -------------------------------
# loss: 0.422892  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.290427
#
# Epoch 259
# -------------------------------
# loss: 0.395380  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.272608
#
# Epoch 260
# -------------------------------
# loss: 0.379587  [  128/ 2330]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.267333
#
# Epoch 261
# -------------------------------
# loss: 0.270802  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.278427
#
# Epoch 262
# -------------------------------
# loss: 0.167263  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.251503
#
# Epoch 263
# -------------------------------
# loss: 0.251817  [  128/ 2330]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.260699
#
# Epoch 264
# -------------------------------
# loss: 0.191391  [  128/ 2330]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.246419
#
# Epoch 265
# -------------------------------
# loss: 0.245500  [  128/ 2330]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.262602
#
# Epoch 266
# -------------------------------
# loss: 0.165422  [  128/ 2330]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.266488
#
# Epoch 267
# -------------------------------
# loss: 0.238626  [  128/ 2330]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.263685
#
# Epoch 268
# -------------------------------
# loss: 0.286110  [  128/ 2330]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.263020
#
# Epoch 269
# -------------------------------
# loss: 0.231529  [  128/ 2330]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.268706
#
# Epoch 270
# -------------------------------
# loss: 0.230331  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.266739
#
# Epoch 271
# -------------------------------
# loss: 0.242006  [  128/ 2330]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.248356
#
# Epoch 272
# -------------------------------
# loss: 0.298305  [  128/ 2330]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.264112
#
# Epoch 273
# -------------------------------
# loss: 0.289856  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.257905
#
# Epoch 274
# -------------------------------
# loss: 0.199933  [  128/ 2330]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.253343
#
# Epoch 275
# -------------------------------
# loss: 0.249105  [  128/ 2330]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.239905
#
# Epoch 276
# -------------------------------
# loss: 0.143706  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.236825
#
# Epoch 277
# -------------------------------
# loss: 0.209782  [  128/ 2330]
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.244820
#
# Epoch 278
# -------------------------------
# loss: 0.331934  [  128/ 2330]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.231762
#
# Epoch 279
# -------------------------------
# loss: 0.284988  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.247932
#
# Epoch 280
# -------------------------------
# loss: 0.210208  [  128/ 2330]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.225743
#
# Epoch 281
# -------------------------------
# loss: 0.217709  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.241366
#
# Epoch 282
# -------------------------------
# loss: 0.211241  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.225455
#
# Epoch 283
# -------------------------------
# loss: 0.201520  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.234566
#
# Epoch 284
# -------------------------------
# loss: 0.346034  [  128/ 2330]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.233676
#
# Epoch 285
# -------------------------------
# loss: 0.231511  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.236471
#
# Epoch 286
# -------------------------------
# loss: 0.202158  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.241191
#
# Epoch 287
# -------------------------------
# loss: 0.183835  [  128/ 2330]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.273527
#
# Epoch 288
# -------------------------------
# loss: 0.270334  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.253845
#
# Epoch 289
# -------------------------------
# loss: 0.187351  [  128/ 2330]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.254033
#
# Epoch 290
# -------------------------------
# loss: 0.247030  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.228950
#
# Epoch 291
# -------------------------------
# loss: 0.155754  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.229678
#
# Epoch 292
# -------------------------------
# loss: 0.382080  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.228873
#
# Epoch 293
# -------------------------------
# loss: 0.234913  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.224022
#
# Epoch 294
# -------------------------------
# loss: 0.250514  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.225544
#
# Epoch 295
# -------------------------------
# loss: 0.167623  [  128/ 2330]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.273026
#
# Epoch 296
# -------------------------------
# loss: 0.288302  [  128/ 2330]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.254571
#
# Epoch 297
# -------------------------------
# loss: 0.229099  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.242293
#
# Epoch 298
# -------------------------------
# loss: 0.176536  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.240976
#
# Epoch 299
# -------------------------------
# loss: 0.201674  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.227829
#
# Epoch 300
# -------------------------------
# loss: 0.145153  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.224813
#
# Epoch 301
# -------------------------------
# loss: 0.144719  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.210385
#
# Epoch 302
# -------------------------------
# loss: 0.193969  [  128/ 2330]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.248967
#
# Epoch 303
# -------------------------------
# loss: 0.299964  [  128/ 2330]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.217171
#
# Epoch 304
# -------------------------------
# loss: 0.220539  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.234598
#
# Epoch 305
# -------------------------------
# loss: 0.318219  [  128/ 2330]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.221620
#
# Epoch 306
# -------------------------------
# loss: 0.284106  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.215504
#
# Epoch 307
# -------------------------------
# loss: 0.234504  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.238038
#
# Epoch 308
# -------------------------------
# loss: 0.206215  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.232126
#
# Epoch 309
# -------------------------------
# loss: 0.257332  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.207823
#
# Epoch 310
# -------------------------------
# loss: 0.362887  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.211071
#
# Epoch 311
# -------------------------------
# loss: 0.260553  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.242411
#
# Epoch 312
# -------------------------------
# loss: 0.226523  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.221221
#
# Epoch 313
# -------------------------------
# loss: 0.155714  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.286492
#
# Epoch 314
# -------------------------------
# loss: 0.301013  [  128/ 2330]
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.219665
#
# Epoch 315
# -------------------------------
# loss: 0.214842  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.228081
#
# Epoch 316
# -------------------------------
# loss: 0.202006  [  128/ 2330]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.215149
#
# Epoch 317
# -------------------------------
# loss: 0.216689  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.216071
#
# Epoch 318
# -------------------------------
# loss: 0.229977  [  128/ 2330]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.217542
#
# Epoch 319
# -------------------------------
# loss: 0.164245  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.225108
#
# Epoch 320
# -------------------------------
# loss: 0.252342  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.220418
#
# Epoch 321
# -------------------------------
# loss: 0.239915  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.213565
#
# Epoch 322
# -------------------------------
# loss: 0.217861  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.214784
#
# Epoch 323
# -------------------------------
# loss: 0.132352  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.207605
#
# Epoch 324
# -------------------------------
# loss: 0.253483  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.203426
#
# Epoch 325
# -------------------------------
# loss: 0.280900  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.221553
#
# Epoch 326
# -------------------------------
# loss: 0.184655  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.209564
#
# Epoch 327
# -------------------------------
# loss: 0.144548  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.216933
#
# Epoch 328
# -------------------------------
# loss: 0.267346  [  128/ 2330]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.251686
#
# Epoch 329
# -------------------------------
# loss: 0.382065  [  128/ 2330]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.214415
#
# Epoch 330
# -------------------------------
# loss: 0.171384  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.228950
#
# Epoch 331
# -------------------------------
# loss: 0.125256  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.217587
#
# Epoch 332
# -------------------------------
# loss: 0.164555  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.198958
#
# Epoch 333
# -------------------------------
# loss: 0.155187  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.204552
#
# Epoch 334
# -------------------------------
# loss: 0.237824  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.202186
#
# Epoch 335
# -------------------------------
# loss: 0.154310  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.211197
#
# Epoch 336
# -------------------------------
# loss: 0.191450  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.194514
#
# Epoch 337
# -------------------------------
# loss: 0.220750  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.200198
#
# Epoch 338
# -------------------------------
# loss: 0.211113  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.201720
#
# Epoch 339
# -------------------------------
# loss: 0.148763  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.190283
#
# Epoch 340
# -------------------------------
# loss: 0.138161  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.193871
#
# Epoch 341
# -------------------------------
# loss: 0.375754  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.207760
#
# Epoch 342
# -------------------------------
# loss: 0.301055  [  128/ 2330]
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.218411
#
# Epoch 343
# -------------------------------
# loss: 0.279521  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.218284
#
# Epoch 344
# -------------------------------
# loss: 0.173896  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.209894
#
# Epoch 345
# -------------------------------
# loss: 0.167849  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.195937
#
# Epoch 346
# -------------------------------
# loss: 0.133255  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.206142
#
# Epoch 347
# -------------------------------
# loss: 0.197056  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.205325
#
# Epoch 348
# -------------------------------
# loss: 0.297352  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.205584
#
# Epoch 349
# -------------------------------
# loss: 0.266967  [  128/ 2330]
# Test Error:
#  Accuracy: 98.1%, Avg loss: 0.201300
#
# Epoch 350
# -------------------------------
# loss: 0.214491  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.195786
#
# Epoch 351
# -------------------------------
# loss: 0.196369  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.203928
#
# Epoch 352
# -------------------------------
# loss: 0.243810  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.219320
#
# Epoch 353
# -------------------------------
# loss: 0.205423  [  128/ 2330]
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.198254
#
# Epoch 354
# -------------------------------
# loss: 0.278052  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.193414
#
# Epoch 355
# -------------------------------
# loss: 0.171778  [  128/ 2330]
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.197217
#
# Epoch 356
# -------------------------------
# loss: 0.215903  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.225984
#
# Epoch 357
# -------------------------------
# loss: 0.227035  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.191645
#
# Epoch 358
# -------------------------------
# loss: 0.180499  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.202114
#
# Epoch 359
# -------------------------------
# loss: 0.355751  [  128/ 2330]
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.203904
#
# Epoch 360
# -------------------------------
# loss: 0.200227  [  128/ 2330]
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.196318
#
# Epoch 361
# -------------------------------
# loss: 0.170971  [  128/ 2330]
# Test Error:
#  Accuracy: 98.1%, Avg loss: 0.188449
#
# Epoch 362
# -------------------------------
# loss: 0.266659  [  128/ 2330]
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.195976
#
# Epoch 363
# -------------------------------
# loss: 0.186805  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.173897
#
# Epoch 364
# -------------------------------
# loss: 0.167076  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.234207
#
# Epoch 365
# -------------------------------
# loss: 0.289320  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.223841
#
# Epoch 366
# -------------------------------
# loss: 0.173675  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.201844
#
# Epoch 367
# -------------------------------
# loss: 0.156444  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.197334
#
# Epoch 368
# -------------------------------
# loss: 0.267778  [  128/ 2330]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.192809
#
# Epoch 369
# -------------------------------
# loss: 0.136359  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.190725
#
# Epoch 370
# -------------------------------
# loss: 0.152923  [  128/ 2330]
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.228554
#
# Epoch 371
# -------------------------------
# loss: 0.232074  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.195591
#
# Epoch 372
# -------------------------------
# loss: 0.138539  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.185514
#
# Epoch 373
# -------------------------------
# loss: 0.188636  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.190059
#
# Epoch 374
# -------------------------------
# loss: 0.164937  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.185984
#
# Epoch 375
# -------------------------------
# loss: 0.315211  [  128/ 2330]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.195352
#
# Epoch 376
# -------------------------------
# loss: 0.143207  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.192653
#
# Epoch 377
# -------------------------------
# loss: 0.345156  [  128/ 2330]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.216856
#
# Epoch 378
# -------------------------------
# loss: 0.212637  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.193116
#
# Epoch 379
# -------------------------------
# loss: 0.206939  [  128/ 2330]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.230974
#
# Epoch 380
# -------------------------------
# loss: 0.292639  [  128/ 2330]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.176870
#
# Epoch 381
# -------------------------------
# loss: 0.177980  [  128/ 2330]
# Test Error:
#  Accuracy: 98.1%, Avg loss: 0.168698
#
# Epoch 382
# -------------------------------
# loss: 0.168769  [  128/ 2330]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.208175
#
# Epoch 383
# -------------------------------
# loss: 0.188329  [  128/ 2330]
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.184605
#
# Epoch 384
# -------------------------------
# loss: 0.238428  [  128/ 2330]
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.186563
#
# Epoch 385
# -------------------------------
# loss: 0.187509  [  128/ 2330]

# %%
import numpy as np
plt.plot(np.array(test_error))

# %%
map = {v:k for k, v in labels_map.items()}

count = 0
for X, y in train_dataloader:    
    for i in range(len(y)):
        count += 1
        pred = model(X)
        pred_index = torch.argmax(pred[i,:])
        true_index = y[i]

        pred = map[int(pred_index)]
        truth = map[int(true_index)]
        if not pred == truth:
            print(f"{pred} | {truth}")

print(count)
# Out:
# Trumpet in C | Flute
# Trumpet in C | Trombone
# Contrabass | Cello
# Accordion | Alto Saxophone
# Viola | Cello
# Trumpet in C | Flute
# Violin | Alto Saxophone
# Alto Saxophone | Trumpet in C
# Bassoon | Violin
# Clarinet in Bb | Flute
# Violin | Viola
# Violin | Trombone
# French Horn | Trombone
# Flute | Alto Saxophone
# Alto Saxophone | Oboe
# French Horn | Trombone
# Alto Saxophone | Clarinet in Bb
# French Horn | Bassoon
# Violin | Viola
# Bassoon | Flute
# Viola | Violin
# French Horn | Bass Tuba
# Bassoon | French Horn
# Alto Saxophone | Clarinet in Bb
# Trumpet in C | Alto Saxophone
# Bassoon | Alto Saxophone
# Viola | Violin
# Viola | Cello
# Clarinet in Bb | Contrabass
# Alto Saxophone | Trombone
# Cello | Accordion
# French Horn | Trombone
# Trumpet in C | Trombone
# Bass Tuba | French Horn
# Viola | Violin
# Bass Tuba | Trombone
# Oboe | Alto Saxophone
# Accordion | Clarinet in Bb
# Trumpet in C | Flute
# Alto Saxophone | Oboe
# Bass Tuba | French Horn
# Trumpet in C | Oboe
# Contrabass | Cello
# Cello | Contrabass
# French Horn | Trombone
# Clarinet in Bb | Oboe
# Trumpet in C | Flute
# Oboe | Alto Saxophone
# Bassoon | Trumpet in C
# French Horn | Bass Tuba
# French Horn | Trombone
# Alto Saxophone | Clarinet in Bb
# Clarinet in Bb | Flute
# Bassoon | Trombone
# Cello | Viola
# Alto Saxophone | Oboe
# Bass Tuba | French Horn
# French Horn | Bass Tuba
# Flute | Trumpet in C
# Alto Saxophone | Accordion
# Flute | Trumpet in C
# French Horn | Trombone
# Bass Tuba | French Horn
# Bassoon | French Horn
# Trumpet in C | Flute
# Trumpet in C | Trombone
# Trombone | Trumpet in C
# Flute | Trumpet in C
# French Horn | Trombone
# Trumpet in C | Flute
# Viola | Alto Saxophone
# 2330

# %%
map = {v:k for k, v in labels_map.items()}

count = 0
for X, y in test_dataloader:    
    for i in range(len(y)):
        count += 1
        pred = model(X)
        pred_index = torch.argmax(pred[i,:])
        true_index = y[i]

        pred = map[int(pred_index)]
        truth = map[int(true_index)]
        if not pred == truth:
            print(f"{pred} | {truth}")

print(count)
# Out:
# Cello | Viola
# Cello | Bass Tuba
# Violin | Viola
# Viola | Accordion
# Flute | Bassoon
# Clarinet in Bb | Oboe
# Alto Saxophone | Flute
# Trumpet in C | Flute
# Contrabass | Clarinet in Bb
# Accordion | Trombone
# Flute | Clarinet in Bb
# Bass Tuba | French Horn
# Viola | Violin
# Clarinet in Bb | Flute
# Trumpet in C | Alto Saxophone
# Alto Saxophone | Clarinet in Bb
# Bass Tuba | Bassoon
# Flute | Clarinet in Bb
# Clarinet in Bb | Flute
# French Horn | Trombone
# Flute | Cello
# Cello | Contrabass
# Oboe | Flute
# Violin | Accordion
# Viola | Violin
# Oboe | Alto Saxophone
# Trumpet in C | Alto Saxophone
# French Horn | Trombone
# Viola | Bassoon
# Clarinet in Bb | Oboe
# Bassoon | French Horn
# Accordion | Oboe
# 583

# %%
import matplotlib.pyplot as plt
# Display image and label.
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze()
label = train_labels[0]
plt.imshow(img, cmap="gray")
plt.show()
print(f"Label: {label}")
# Out:
# Feature batch shape: torch.Size([64, 1, 32, 32])
# Labels batch shape: torch.Size([64])
# Label: 3

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

from torch.utils.data import Dataset

class AudioDataset(DataSet):
    pass

train_dataloader = DataLoader(training_data, batch_size=64)
test_dataloader = DataLoader(test_data, batch_size=64)

class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(20, 64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.module(x)
    
model = MLP()

learning_rate = 1e-3
batch_size = 64
epochs = 5

# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       5 from torchvision.transforms import ToTensor
#       7 from torch.utils.data import Dataset
# ----> 9 class AudioDataset(DataSet):
#      10     pass
#      12 train_dataloader = DataLoader(training_data, batch_size=64)
#
# NameError: name 'DataSet' is not defined

# %% [markdown]
# I got the dataset from kaggle [here](https://www.kaggle.com/datasets/thedevastator/tinysol-isolated-musical-notes-from-14-musical-i).

# %% [markdown]
# I decided to reduce the dimensionality of the model for our use case
#
# https://reference.wolfram.com/language/ref/netencoder/Audio.html
#
# Using the tutorial above, I settled on using the AudioMFCC encoder, which has a corresponding function in a Python library
#
# https://docs.pytorch.org/audio/master/generated/torchaudio.transforms.MFCC.html

# %% [markdown]
# I couldn't get torchaudio working, so intead I am using a different library
# [text](https://python-speech-features.readthedocs.io/en/latest/#)

# %% [markdown]
# Here is a pytorch version of dropout
# [link](https://codesignal.com/learn/courses/improving-neural-networks-with-pytorch/lessons/adding-dropout-to-neural-networks-in-pytorch)

# %%
print(f"Model structure: {model}\n\n")

for name, param in model.named_parameters():
    print(f"Layer: {name} | Size: {param.size()} | Values : {param[:2]} \n")

# %%
from python_speech_features import mfcc
from python_speech_features import logfbank
import scipy.io.wavfile as wav

nfft = 4096

(rate,sig) = wav.read("Brass/Bass_Tuba/ordinario/BTb-ord-A1-ff-N-T19d.wav")
(rate,sig) = wav.read("Brass/Horn/ordinario/Hn-ord-A1-mf-N-N.wav")

mfcc_feat = mfcc(sig,rate, nfft=nfft, winlen=50e-3)
print(mfcc_feat[mfcc_feat.shape[0]//2,:])

nfft = 4096
(rate,sig) = wav.read("Brass/Horn/ordinario/Hn-ord-A1-mf-N-N.wav")
mfcc_feat = mfcc(sig,rate, nfft=nfft, winlen=50e-3 )
# fbank_feat = logfbank(sig,rate, nfft=nfft)

print(mfcc_feat[mfcc_feat.shape[0]//2,:])

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

def plot_mfcc(audio_path, ax, title):
    # Load the audio file
    y, sr = librosa.load(audio_path)

    # Extract MFCC features
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20, n_fft=1800)

    # Plot MFCCs
    # plt.figure(figsize=(10, 4))
    librosa.display.specshow(mfccs, x_axis='time', cmap='viridis', ax = ax)
    # ax.colorbar(format='%+2.0f dB')
    ax.set_title(title)
    ax.set_xlabel('Time')
    ax.set_ylabel('MFCC Coefficient')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Example usage
audio_file_path1 = "Winds/Bassoon/ordinario/Bn-ord-D#3-pp-N-N.wav"
# audio_file_path2 = "Brass/Bass_Tuba/ordinario/BTb-ord-D#3-mf-N-T25u.wav"
# audio_file_path1 = "Brass/Horn/ordinario/Hn-ord-A1-mf-N-N.wav"
audio_file_path2 = "Brass/Trombone/ordinario/Tbn-ord-D#3-ff-N-N.wav"
# audio_file_path1 = "Strings/Viola/ordinario/Va-ord-A#3-ff-3c-N.wav"
# audio_file_path2 = "Strings/Viola/ordinario/Va-ord-G5-ff-3c-N.wav"
plot_mfcc(audio_file_path1, ax1, "Basson playing D#3")
plot_mfcc(audio_file_path2, ax2, "Trombone playing D#3")

# %% [markdown]
# I found this [tutorial](https://www.geeksforgeeks.org/machine-learning/classification-using-sklearn-multi-layer-perceptron/) helpful

# %%
from sklearn.neural_network import MLPClassifier

MLPClassifier()

# %% [markdown]
# This [tutorial](https://www.geeksforgeeks.org/deep-learning/training-neural-networks-with-dropout-for-effective-regularization/)
#  goes over training with dropout with tensorflow
