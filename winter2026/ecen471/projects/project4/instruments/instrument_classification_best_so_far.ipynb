# %% [markdown]
# # Separate the Training and Test Data

# %%
import torch
import pickle

# %%
from torch.utils.data import Dataset, random_split

class InstrumentDataset(Dataset):
    def __init__(self, X, y, labels):
        self.X = X
        self.y = y
        self.labels = labels

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        X_i = torch.tensor(self.X[idx].reshape((1, self.X.shape[1], self.X.shape[2])), dtype=torch.float32)
        y_i = torch.tensor(self.y[idx], dtype=torch.long)
        return X_i, y_i

data = pickle.load(open('processed_data.pkl', 'rb'))
X = data["X"]
y = data["y"]
labels_map = data["labels_map"]

num_mfcc = X.shape[1]
num_time_steps = X.shape[2]

generator = torch.Generator().manual_seed(42)
dataset = InstrumentDataset(X=X, y=y, labels=labels_map.keys())    

num_training_points = round(0.8*y.shape[0])
num_validation_points = round(0.2*y.shape[0])
training_dataset, validation_dataset = random_split(dataset, lengths=[num_training_points, num_validation_points], generator=generator)

# %%
from torch.utils.data import DataLoader
batch_size = 256
train_dataloader = DataLoader(training_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=True)

# %%
for X, y in train_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    print(y)
# Out:
# Shape of X [N, C, H, W]: torch.Size([256, 1, 32, 32])
# Shape of y: torch.Size([256]) torch.int64
# tensor([ 4,  4,  8,  1,  6, 10,  7, 10, 10, 10,  8, 10, 10, 11,  9,  5, 12, 11,
#         10,  2,  8, 10, 10,  0, 10, 11, 10, 10, 10,  1,  7,  0, 13, 10, 11, 10,
#         10, 11, 12,  5,  2,  2, 13,  6, 10,  5, 10, 10,  8, 10, 11, 10, 11,  6,
#         12,  0, 13,  0,  9,  6, 10, 12,  2,  2, 12,  5, 11,  2, 10, 10,  4,  4,
#         12,  6, 10,  6,  6,  0,  9, 10,  2, 11,  9, 11, 10,  2,  8,  5, 11, 13,
#          2, 12, 13,  9, 11, 10,  0,  3,  1,  3,  2, 13,  8,  5, 10,  9, 11, 10,
#         10, 11,  2,  8,  6, 13, 11, 10,  4,  4,  8, 10,  5, 10,  4,  5, 11,  7,
#          5, 10,  5,  5,  9,  6,  2,  7,  8,  5, 13, 10,  0,  5, 11,  1, 10,  9,
#         12,  1, 10, 10,  5,  2, 11, 13,  0, 11,  3, 13,  8,  5,  4, 11, 11, 11,
#         13,  5,  8,  0, 10,  5,  0, 10,  4,  2,  8,  4, 10,  1, 11, 11,  2, 12,
#         10,  5,  6,  0, 13,  8, 12, 10, 13, 13,  9,  5, 10, 10,  3,  4,  5, 11,
#         10, 11, 12,  5, 12,  3, 10,  5, 11,  5,  2, 10, 10, 10,  2, 13,  0, 13,
#          0, 13, 10,  7, 11,  0, 10, 11, 11, 11,  7, 11,  0, 10, 13,  5,  1, 10,
#          9,  9,  9, 13,  5,  6, 11, 11, 13,  4, 12, 11,  4,  4, 10,  2, 13,  5,
#          1,  2,  6,  7])
# Shape of X [N, C, H, W]: torch.Size([256, 1, 32, 32])
# Shape of y: torch.Size([256]) torch.int64
# tensor([ 5, 10, 10,  1, 12, 10,  7,  9, 12, 11,  1,  8,  6, 13,  2, 13, 10, 11,
#          2, 10,  1,  0,  7,  4, 11,  4, 11, 10, 10, 13, 11,  6,  2,  8, 11, 11,
#          5, 11, 13, 13, 12,  4, 13, 13, 10,  4,  1, 10, 13,  8,  5,  7, 10,  1,
#          5,  2,  5,  1,  0,  5,  9,  3, 13,  7, 13,  2, 13,  9,  5, 10, 12,  3,
#          1, 11,  4, 13,  4, 11, 10,  8,  2, 10,  2, 13, 13,  6, 10,  2,  4, 13,
#          5,  8,  0,  5, 10,  2,  5, 13,  1, 13, 13,  8,  4,  7,  0,  2,  2,  0,
#          7, 11,  5, 11,  2, 10, 10, 10, 10,  2, 10,  5, 13, 13,  5,  5,  1, 13,
#          2, 10,  2,  5, 11, 12,  2, 11, 10,  3,  1, 10,  5,  2,  5, 11,  2,  9,
#         13,  5, 11, 11, 12, 11,  6,  5,  4,  2,  5, 11, 13,  2,  5,  2, 12, 10,
#          8, 10, 13,  0,  8,  2, 11,  5, 12, 13, 11,  8,  1,  0,  2,  1, 13,  4,
#         10,  3,  2,  5,  2,  1,  8,  2, 10, 10, 10,  4,  5, 13,  2,  3, 11,  4,
#         12,  0, 13,  5,  9, 13,  5,  3, 13, 10,  2,  9,  8, 13, 10,  4, 12, 10,
#         11,  3,  6, 10,  2, 11, 10, 10, 11,  2, 13, 11,  4,  2,  5, 13,  9, 13,
#          1, 10,  1,  9, 10,  1, 10,  2, 10,  2,  1, 10, 11,  5, 11, 13, 11,  8,
#          1, 13, 10,  6])
# Shape of X [N, C, H, W]: torch.Size([256, 1, 32, 32])
# Shape of y: torch.Size([256]) torch.int64
# tensor([11, 10,  6, 11,  2,  0, 10, 10, 10, 10,  7,  7, 13, 13,  7, 13,  5,  0,
#         13, 10,  4,  9, 10, 10, 10, 13,  9,  5, 11,  8, 11, 11, 10,  2,  5, 13,
#          6, 10,  0,  7,  9, 13, 12, 11, 11,  2, 10, 11,  7, 11, 13, 11,  8,  2,
#         10, 11, 11,  8, 11, 12,  4, 11,  6, 13,  2, 10,  3, 10, 10, 10, 10,  2,
#         12, 10,  9, 10, 11,  4,  1, 10, 11,  9,  8, 11,  5, 10, 10, 10, 13,  8,
#          7,  3,  5, 13, 11, 12,  8, 10, 10,  4,  5, 11,  5, 10, 11,  2,  9,  4,
#         10,  2, 10,  6, 13, 11,  6,  0,  9, 10, 10, 11,  5, 10,  5,  2, 13,  9,
#          5,  6, 11, 11,  2,  0, 10, 13,  9,  8,  9,  7,  2, 13, 13, 10,  9,  0,
#          9,  6,  7,  6,  9,  0, 10, 13, 13, 12,  2,  1,  7, 11,  0, 10, 13, 10,
#         13, 10, 10, 10,  2,  2, 13, 12, 10, 10,  8,  7,  2, 10,  2,  5,  0, 10,
#         10, 10, 10, 10, 11, 11, 10,  4,  5, 11, 13,  1,  9, 10, 10,  7,  8, 11,
#         10, 13, 11,  1,  8, 13, 11,  2, 11, 10,  2, 10, 10,  7,  5,  2, 11, 12,
#         13,  5,  3, 11,  6,  3, 10, 10,  9, 10, 10, 13, 10, 13, 10, 12, 12,  2,
#         13, 10, 10, 13, 10,  6,  0, 10, 10,  0, 10,  4, 10,  1, 12,  5, 10, 10,
#         10, 10,  2, 13])
# Shape of X [N, C, H, W]: torch.Size([256, 1, 32, 32])
# Shape of y: torch.Size([256]) torch.int64
# tensor([11,  2, 11,  2,  9, 10, 13,  2,  1, 13, 12,  3, 10,  9,  0, 10, 10,  2,
#          5, 10,  1, 10, 13,  6,  5, 10, 10, 10,  2,  2, 10,  6, 11, 10,  5, 11,
#          1,  5,  7,  7, 10, 10, 13, 10, 10,  5,  6,  9, 11, 10, 13, 10,  1,  7,
#          5,  3, 10, 10, 10, 13,  2,  4, 10,  4, 11,  4,  6,  5, 13,  1,  5,  5,
#         11, 13,  4,  9,  5, 13,  4, 10,  8,  5,  2,  4, 10,  7, 10, 12,  5,  1,
#         10,  5, 13,  7,  1, 11,  8, 13,  6,  5, 10,  2, 12, 10,  9,  2,  1, 10,
#          5, 10, 13,  1,  6,  4,  1,  8,  8, 13, 10, 13,  5, 10, 10,  5,  8, 10,
#          5, 11,  6, 10, 13,  3,  3, 10,  1,  5, 11,  5,  4,  1,  1,  5, 13,  9,
#          9, 13,  2, 10,  0, 11,  5,  9,  3,  0,  4,  4, 10,  5, 10, 13,  3,  2,
#          7,  6,  2, 13, 11,  4, 13, 11,  5,  2,  1, 12, 10, 10, 10,  5, 10, 10,
#         11,  5,  1, 10,  4, 11,  2,  3, 11,  6,  2,  6, 13,  3, 10,  2, 11, 13,
#          6, 10, 11,  1,  2,  2,  2,  9,  2,  5,  4, 10, 11, 10,  4, 10, 11,  7,
#         10, 10, 13, 10, 11, 10, 10,  9,  4,  6, 10,  8,  2, 11, 11, 10,  5, 10,
#         13, 10, 12, 10,  8,  4,  0, 12,  4, 12, 11, 11,  8,  8,  7,  8,  9, 10,
#         13, 10, 12,  9])
# Shape of X [N, C, H, W]: torch.Size([256, 1, 32, 32])
# Shape of y: torch.Size([256]) torch.int64
# tensor([ 5, 10, 10,  2, 11,  3, 10, 13, 10,  2,  3, 10,  1,  9,  0,  2, 10, 12,
#          2,  2,  8, 10, 10, 11, 10, 10, 10,  8, 10, 10, 10,  7, 10, 13,  2,  5,
#          4,  2, 10,  1,  9,  7, 13,  6,  9, 10, 10, 10, 10, 11,  0,  7,  9,  9,
#         10, 10, 11, 11,  8, 10,  2,  0, 10, 10, 10, 13,  5, 11, 10, 11,  2,  4,
#          2,  5, 10,  3, 11,  3, 12, 13,  6, 10,  2, 10, 10, 11, 12,  9, 10,  5,
#          1, 10, 13, 10, 11, 11,  5,  4, 11, 10, 10, 13, 11, 11,  3, 13, 10,  5,
#          3, 11,  8,  2, 10, 10,  2,  2,  9,  2, 10,  2,  5,  8,  2, 10,  1, 11,
#          4, 10, 10,  5, 10, 10,  4,  1,  8,  6, 11, 12,  5,  3,  6, 10, 13, 13,
#          5, 11,  9,  2, 11,  2,  5, 13,  5, 13,  1,  5,  1, 10, 10,  8,  6, 13,
#         11,  6,  5,  5, 10,  9, 11, 10, 12,  5,  5,  5, 10,  2,  3, 12,  4, 10,
#         10,  5, 13,  1, 11,  6,  2,  9, 10,  5, 10,  2,  4,  0,  5,  0, 10,  0,
#         10,  5,  2,  7,  9,  7,  8,  3, 11, 13,  2,  5, 13,  7,  2,  2,  3,  7,
#          5, 11, 10,  9, 11, 11,  9,  9,  4,  5,  5,  2,  9, 10,  9,  2,  5, 10,
#         10,  5, 10,  6, 10,  2, 11,  5, 11, 10, 10,  5,  4,  5,  4,  5, 12,  6,
#         13, 11, 10, 11])
# Shape of X [N, C, H, W]: torch.Size([256, 1, 32, 32])
# Shape of y: torch.Size([256]) torch.int64
# tensor([10,  2,  8, 13,  9, 13,  5,  7, 10, 10,  0, 10,  5,  8,  1,  5,  5,  4,
#          4, 10,  5, 10, 12, 11, 11,  9,  2,  4, 11, 10,  5,  4, 10, 10, 13,  4,
#          5,  4,  0, 10,  5, 13,  6, 12,  5,  5, 10,  0, 13,  9, 10, 13, 12, 13,
#         12, 13, 13, 11,  2, 13, 11, 11,  5,  3,  8,  8,  2,  9, 10,  0, 11, 10,
#         11,  6, 13, 10, 11,  2, 10, 10,  2, 11,  2, 10,  2, 12, 11,  5, 10,  2,
#         13,  4,  6,  9, 10, 10,  7,  3,  9,  0,  3,  5, 11, 13, 13,  3,  1,  2,
#          2, 13, 11, 10,  8, 10,  4,  1, 10, 12,  5,  2,  5,  2, 10,  0,  0,  4,
#         13, 10,  4,  5,  5, 13,  7, 13,  8, 11, 11, 10, 10, 10,  2, 13,  3, 10,
#         11, 10, 10,  0,  5,  2,  6,  7,  7, 12,  0,  2,  8,  5, 10,  2,  2, 12,
#          1, 11,  2, 10, 11,  0,  2,  6, 10, 10, 10,  4, 11, 12, 10, 10,  5, 13,
#          6, 13,  4,  2,  7,  1,  1,  2,  2, 12,  0, 11,  4,  2,  5, 10,  2,  7,
#         13,  0, 10, 10, 10, 13, 11, 12, 10,  4,  2,  9, 10,  5,  7, 10, 13,  2,
#          7,  1,  8, 13,  2, 11,  9,  3,  5,  9, 10, 10,  5, 10, 10, 10,  2,  2,
#          9, 13, 10,  5, 10,  6,  4, 12,  9,  8, 13, 13, 13, 10, 10, 10,  5, 10,
#          6, 13, 10, 12])
# Shape of X [N, C, H, W]: torch.Size([256, 1, 32, 32])
# Shape of y: torch.Size([256]) torch.int64
# tensor([13, 11, 13,  2,  0,  2,  5, 10,  9, 11,  0,  1, 12,  8,  6,  2, 10,  5,
#          3,  5,  5, 11, 10,  6,  2, 10, 11, 13,  8,  7, 13,  1,  2, 13, 11, 10,
#         12,  2,  9, 13, 11, 12,  0,  5,  8,  1,  4, 12,  5,  5,  5,  8,  5,  5,
#          9,  5,  4, 10,  2,  6,  5,  5,  3, 11, 10, 10,  1,  5,  6,  2,  1,  6,
#          4,  5, 10,  9,  8, 10,  8,  4, 11,  9, 10,  6, 13,  3, 13,  0, 13,  0,
#          2, 13,  5, 13,  5, 12, 10,  2,  5,  2, 12, 10, 10, 10, 10, 12,  2,  9,
#         10, 10,  6, 10,  9,  2,  2,  2,  7, 13, 10, 10, 11,  5,  7, 13,  2, 11,
#         10,  2, 10,  1,  6, 10, 10, 13, 10,  5, 10, 11, 13,  4,  3, 11, 11, 13,
#         11, 11, 10,  4, 10,  1,  2,  5, 10,  7, 13, 10, 10, 13,  4, 13,  2,  5,
#          4,  9, 11,  2, 13,  5,  6, 11, 13, 10,  5,  7,  3,  2,  2, 11, 10, 10,
#          2, 10, 10, 12,  3, 13,  9,  5,  2,  9,  3,  1, 11,  5, 12,  2, 10, 10,
#         10,  1,  4,  2, 10,  7, 10, 10,  6, 13, 10,  4, 11, 10, 10,  8,  2, 10,
#         11, 10,  4,  1,  5, 10,  8, 11,  2, 11, 11, 10,  6, 11, 10,  6, 12, 10,
#         11, 13,  5,  5, 12, 10, 11, 11, 12, 10, 10,  5, 12, 10,  5,  2, 10, 10,
#          3, 13,  2, 10])
# Shape of X [N, C, H, W]: torch.Size([256, 1, 32, 32])
# Shape of y: torch.Size([256]) torch.int64
# tensor([ 4,  5,  0, 11, 11,  5, 10,  4, 10,  2,  5, 10, 10,  0,  5,  1,  5, 11,
#         10,  5, 13, 11,  3,  7,  5, 11,  5, 13, 11,  9, 13, 10,  3, 13, 10,  2,
#          1, 13,  6,  5,  6,  8,  5, 10,  5,  2, 11,  1,  2, 13, 10, 11,  5,  1,
#          2,  2,  9,  4,  6, 10, 10, 10,  2,  5,  2,  0, 11, 13, 13,  1,  3,  2,
#         10, 10, 13, 10, 13,  2,  4,  2,  0, 10, 10, 10,  2,  4,  4,  8,  0, 12,
#         10, 13, 10, 11,  2, 10, 13,  8,  1, 12, 13,  0,  7,  9,  2,  3,  7,  2,
#         10,  2, 10,  2,  5,  3,  6, 11, 10,  9, 10, 13, 12, 10,  2,  6,  5,  5,
#          9, 10,  5, 10,  3,  5, 10,  2,  9,  8, 10,  0, 11,  5, 10,  2,  9,  2,
#         10, 10,  8, 11,  1, 10,  2,  4,  5,  2,  2,  5, 11, 10, 10,  5, 10, 12,
#          3,  0, 10,  3, 10, 11, 10,  5,  3,  3,  2, 12,  0, 10,  9,  2, 13,  9,
#         10,  1, 10, 12,  5,  5,  2, 11, 10, 13, 11,  0,  3,  7,  5,  8,  8, 12,
#          5,  7,  1,  0,  0,  0,  3, 10, 13, 10, 11,  2, 10,  2,  5,  4, 10,  8,
#          6,  7, 12, 12,  1,  0,  9,  4,  1,  9,  5,  3, 12,  7, 10,  5,  1,  2,
#          5,  5,  6, 13,  6, 12,  1,  3,  9, 10,  0,  0,  7, 10,  5, 11, 10,  7,
#         10, 10,  8, 10])
# Shape of X [N, C, H, W]: torch.Size([256, 1, 32, 32])
# Shape of y: torch.Size([256]) torch.int64
# tensor([12, 11, 10,  3, 10,  5,  2,  1,  5, 10, 12, 10,  2,  5,  2, 10,  5,  7,
#         13, 13,  6, 11,  2,  5, 10, 11,  5, 13, 10, 11,  5,  7, 10,  5,  6, 10,
#          5, 12,  2,  5,  5,  6, 11, 12, 10,  2,  5,  5,  2, 11,  8,  5, 12, 13,
#          6,  5, 13, 11, 11,  2,  9,  5, 11,  1,  5, 10, 10,  4,  8,  2, 10, 10,
#          2,  5, 10,  7,  4,  4,  0,  2, 10,  3,  5, 12, 10, 11,  5, 13, 12, 10,
#         11,  8,  2, 13, 13,  2,  5, 13,  5, 10, 12,  2, 13,  4,  8,  1, 11, 12,
#         10, 10, 12,  1,  5, 10,  9, 11,  6,  6,  2,  3,  2, 13, 13, 12, 11, 10,
#          6,  7,  6, 12,  9, 10, 10, 11,  3,  5,  5,  6,  1,  2,  4,  6, 10, 11,
#         11, 10,  2, 10, 10, 13, 12,  7, 10,  5,  5,  5,  8, 12,  4, 10,  0,  6,
#         10, 10, 10, 10,  4,  7, 11,  9, 10,  4,  4, 11, 10, 10, 10, 11,  6,  3,
#          5, 10,  9,  5, 10,  5,  1,  4,  9, 11,  5,  7,  0,  3, 12, 10, 11, 10,
#          3,  0, 10, 10,  2, 13,  8,  5,  1, 13, 13,  8,  4, 13,  7,  7, 11,  3,
#          6,  3,  4, 10, 13, 10,  7,  2,  3,  3, 10,  4, 13,  2, 10, 10,  9, 12,
#          2,  5, 12, 10, 13,  5,  8,  5,  1, 10,  6,  3, 10, 10, 11,  8,  8,  2,
#         10, 11,  6,  9])
# Shape of X [N, C, H, W]: torch.Size([26, 1, 32, 32])
# Shape of y: torch.Size([26]) torch.int64
# tensor([ 3,  5, 10, 13, 10, 10, 11,  9, 13,  1, 10, 11, 10, 10, 10,  3,  2,  6,
#         10,  3, 13,  2,  5, 10,  5,  2])
# /tmp/ipykernel_72821/1873154058.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_i = torch.tensor(self.X[idx].reshape((1, self.X.shape[1], self.X.shape[2])), dtype=torch.float32)

# %%
from torch import nn

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
import torch.nn.functional as F

# Define model
# class NeuralNetwork(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.conv1 = nn.Conv2d(1, 6, 5)
#         self.pool = nn.MaxPool2d(2, 2)
#         self.conv2 = nn.Conv2d(6, 16, 5)
#         self.fc1 = nn.Linear(16 * 5 * 5, 120)
#         self.fc2 = nn.Linear(120, 84)
#         self.fc3 = nn.Linear(84, len(labels_map.keys()))
#         # self.flatten = nn.Flatten()
#         # self.linear_relu_stack = nn.Sequential(
#         #     # nn.Conv2d(1, 6, 5),
#         #     nn.Linear(num_mfcc*num_time_steps, 512),
#         #     nn.ReLU(),
#         #     nn.Linear(512, 512),
#         #     nn.ReLU(),
#         #     nn.Linear(512, len(labels_map.keys()))
#         # )

#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))
#         x = self.pool(F.relu(self.conv2(x)))
#         x = torch.flatten(x, 1) # flatten all dimensions except batch
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = self.fc3(x)
#         return x
#         # x = self.flatten(x)
#         # logits = self.linear_relu_stack(x)
#         # return logits

import torch
import torch.nn as nn
import torch.nn.functional as F

r_in = 1.0
r_conv = 1.0
r_hidden = 0.52

class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.dropout0 = nn.Dropout(1-r_in)
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.dropout1 = nn.Dropout(1 - r_conv)
        # self.conv2 = nn.Conv2d(6, 6, 5)
        # self.dropout2 = nn.Dropout(1 - r_hidden)
        self.conv3 = nn.Conv2d(6, 16, 5)
        self.dropout2 = nn.Dropout(1 - r_conv)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.dropout3 = nn.Dropout(1 - r_hidden)
        self.fc2 = nn.Linear(120, 84)
        self.dropout4 = nn.Dropout(1 - r_hidden)
        # self.fc3 = nn.Linear(84, 84)
        # self.dropout5 = nn.Dropout(1 - r_hidden)
        # self.fc4 = nn.Linear(84, 42)
        # self.dropout6 = nn.Dropout(1 - r_hidden)
        self.fc3 = nn.Linear(84, len(labels_map.keys()))

    def forward(self, input):
        x = F.relu(self.conv1(self.dropout0(input)))
        
        # x = F.max_pool2d(x, (2, 2))
        # x = F.relu(self.conv2(x))
        
        x = self.dropout1(x)
        x = F.max_pool2d(x, (2, 2))
        x = F.relu(self.conv3(x))

        x = self.dropout2(x)
        x = F.max_pool2d(x, 2)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        
        x = self.dropout3(x)
        x = F.relu(self.fc2(x))
        
        x = self.dropout4(x)
        output = self.fc3(x)
        # c1 = F.relu(self.conv1(input))
        # s2 = F.max_pool2d(c1, (2, 2))
        # c3 = F.relu(self.conv2(s2))
        # s4 = F.max_pool2d(c3, 2)
        # s4 = torch.flatten(s4, 1)
        # f5 = F.relu(self.fc1(s4))
        # f6 = F.relu(self.fc2(f5))
        # output = self.fc3(f6)
        return output


net = Net()
print(net)

model = Net().to(device)
print(model)
# Out:
# Using cpu device
# Net(
#   (dropout0): Dropout(p=0.0, inplace=False)
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (dropout1): Dropout(p=0.0, inplace=False)
#   (conv3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (dropout3): Dropout(p=0.48, inplace=False)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (dropout4): Dropout(p=0.48, inplace=False)
#   (fc3): Linear(in_features=84, out_features=14, bias=True)
# )
# Net(
#   (dropout0): Dropout(p=0.0, inplace=False)
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (dropout1): Dropout(p=0.0, inplace=False)
#   (conv3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (dropout3): Dropout(p=0.48, inplace=False)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (dropout4): Dropout(p=0.48, inplace=False)
#   (fc3): Linear(in_features=84, out_features=14, bias=True)
# )

# %%
train_dataloader

# %%
import torch.optim as optim

# criterion = nn.CrossEntropyLoss()
# optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# for epoch in range(2):  # loop over the dataset multiple times

#     running_loss = 0.0
#     for i, data in enumerate(train_dataloader, 0):
#         # get the inputs; data is a list of [inputs, labels]
#         inputs, labels = data

#         # zero the parameter gradients
#         optimizer.zero_grad()

#         # forward + backward + optimize
#         outputs = model(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()

#         # print statistics
#         running_loss += loss.item()
#         if i % 2000 == 1999:    # print every 2000 mini-batches
#             print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
#             running_loss = 0.0

# print('Finished Training')
import matplotlib.pyplot as plt

loss_fn = nn.CrossEntropyLoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)
optimizer = torch.optim.SGD(model.parameters(), lr=5e-3, momentum=0.1)

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    


def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return 1-correct

train_error = []
test_error = []

# %%
epochs = 60000
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test_error.append(test(test_dataloader, model, loss_fn))
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.657687  [  256/ 2330]
# /tmp/ipykernel_72821/1873154058.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_i = torch.tensor(self.X[idx].reshape((1, self.X.shape[1], self.X.shape[2])), dtype=torch.float32)
# Test Error:
#  Accuracy: 3.8%, Avg loss: 2.649824
#
# Epoch 2
# -------------------------------
# loss: 2.651929  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.649552
#
# Epoch 3
# -------------------------------
# loss: 2.653257  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.648995
#
# Epoch 4
# -------------------------------
# loss: 2.656646  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.641501
#
# Epoch 5
# -------------------------------
# loss: 2.641059  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.638654
#
# Epoch 6
# -------------------------------
# loss: 2.637204  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.633676
#
# Epoch 7
# -------------------------------
# loss: 2.638360  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.632561
#
# Epoch 8
# -------------------------------
# loss: 2.630610  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.631480
#
# Epoch 9
# -------------------------------
# loss: 2.629571  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.625238
#
# Epoch 10
# -------------------------------
# loss: 2.627741  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.619749
#
# Epoch 11
# -------------------------------
# loss: 2.630465  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.618394
#
# Epoch 12
# -------------------------------
# loss: 2.625535  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.615584
#
# Epoch 13
# -------------------------------
# loss: 2.618773  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.616616
#
# Epoch 14
# -------------------------------
# loss: 2.614779  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.607028
#
# Epoch 15
# -------------------------------
# loss: 2.612325  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.606610
#
# Epoch 16
# -------------------------------
# loss: 2.609645  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.607067
#
# Epoch 17
# -------------------------------
# loss: 2.610456  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.599517
#
# Epoch 18
# -------------------------------
# loss: 2.604510  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.596281
#
# Epoch 19
# -------------------------------
# loss: 2.603692  [  256/ 2330]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 2.595816
#
# Epoch 20
# -------------------------------
# loss: 2.601964  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.592675
#
# Epoch 21
# -------------------------------
# loss: 2.601124  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.591134
#
# Epoch 22
# -------------------------------
# loss: 2.609776  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.583718
#
# Epoch 23
# -------------------------------
# loss: 2.591542  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.577430
#
# Epoch 24
# -------------------------------
# loss: 2.586669  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.578302
#
# Epoch 25
# -------------------------------
# loss: 2.580791  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.581784
#
# Epoch 26
# -------------------------------
# loss: 2.595602  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.574719
#
# Epoch 27
# -------------------------------
# loss: 2.587847  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.573890
#
# Epoch 28
# -------------------------------
# loss: 2.602321  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.574040
#
# Epoch 29
# -------------------------------
# loss: 2.594467  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.568294
#
# Epoch 30
# -------------------------------
# loss: 2.570639  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.570388
#
# Epoch 31
# -------------------------------
# loss: 2.588218  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.573166
#
# Epoch 32
# -------------------------------
# loss: 2.574355  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.568470
#
# Epoch 33
# -------------------------------
# loss: 2.581670  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.555600
#
# Epoch 34
# -------------------------------
# loss: 2.567887  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.564157
#
# Epoch 35
# -------------------------------
# loss: 2.570770  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.558956
#
# Epoch 36
# -------------------------------
# loss: 2.557248  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.561245
#
# Epoch 37
# -------------------------------
# loss: 2.566247  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.556342
#
# Epoch 38
# -------------------------------
# loss: 2.573518  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.549627
#
# Epoch 39
# -------------------------------
# loss: 2.545125  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.550075
#
# Epoch 40
# -------------------------------
# loss: 2.557578  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.541431
#
# Epoch 41
# -------------------------------
# loss: 2.554250  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.537377
#
# Epoch 42
# -------------------------------
# loss: 2.568416  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.535988
#
# Epoch 43
# -------------------------------
# loss: 2.566321  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.533655
#
# Epoch 44
# -------------------------------
# loss: 2.535999  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.539198
#
# Epoch 45
# -------------------------------
# loss: 2.525916  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.540130
#
# Epoch 46
# -------------------------------
# loss: 2.529727  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.528290
#
# Epoch 47
# -------------------------------
# loss: 2.558922  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.527713
#
# Epoch 48
# -------------------------------
# loss: 2.529795  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.531731
#
# Epoch 49
# -------------------------------
# loss: 2.550528  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.516700
#
# Epoch 50
# -------------------------------
# loss: 2.524991  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.521763
#
# Epoch 51
# -------------------------------
# loss: 2.541609  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.514166
#
# Epoch 52
# -------------------------------
# loss: 2.543691  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.514974
#
# Epoch 53
# -------------------------------
# loss: 2.542154  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.522101
#
# Epoch 54
# -------------------------------
# loss: 2.517244  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.511642
#
# Epoch 55
# -------------------------------
# loss: 2.542246  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.522034
#
# Epoch 56
# -------------------------------
# loss: 2.524328  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.502061
#
# Epoch 57
# -------------------------------
# loss: 2.541498  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.514738
#
# Epoch 58
# -------------------------------
# loss: 2.504681  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.512786
#
# Epoch 59
# -------------------------------
# loss: 2.508812  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.490241
#
# Epoch 60
# -------------------------------
# loss: 2.529423  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.510942
#
# Epoch 61
# -------------------------------
# loss: 2.512704  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.506969
#
# Epoch 62
# -------------------------------
# loss: 2.542859  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.484473
#
# Epoch 63
# -------------------------------
# loss: 2.509429  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.489412
#
# Epoch 64
# -------------------------------
# loss: 2.526379  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.485727
#
# Epoch 65
# -------------------------------
# loss: 2.509802  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.488950
#
# Epoch 66
# -------------------------------
# loss: 2.501065  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.502051
#
# Epoch 67
# -------------------------------
# loss: 2.510916  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.483516
#
# Epoch 68
# -------------------------------
# loss: 2.501112  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.503715
#
# Epoch 69
# -------------------------------
# loss: 2.492272  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.481443
#
# Epoch 70
# -------------------------------
# loss: 2.489597  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.486301
#
# Epoch 71
# -------------------------------
# loss: 2.508931  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.479790
#
# Epoch 72
# -------------------------------
# loss: 2.513494  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.492697
#
# Epoch 73
# -------------------------------
# loss: 2.505702  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.477780
#
# Epoch 74
# -------------------------------
# loss: 2.515391  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.484911
#
# Epoch 75
# -------------------------------
# loss: 2.492720  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.483298
#
# Epoch 76
# -------------------------------
# loss: 2.485069  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.488870
#
# Epoch 77
# -------------------------------
# loss: 2.478571  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.472852
#
# Epoch 78
# -------------------------------
# loss: 2.521283  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.483796
#
# Epoch 79
# -------------------------------
# loss: 2.496208  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.470985
#
# Epoch 80
# -------------------------------
# loss: 2.495920  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.465420
#
# Epoch 81
# -------------------------------
# loss: 2.487710  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.456772
#
# Epoch 82
# -------------------------------
# loss: 2.503872  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.449990
#
# Epoch 83
# -------------------------------
# loss: 2.498435  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.467996
#
# Epoch 84
# -------------------------------
# loss: 2.473932  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.460554
#
# Epoch 85
# -------------------------------
# loss: 2.480411  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.466181
#
# Epoch 86
# -------------------------------
# loss: 2.475976  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.446856
#
# Epoch 87
# -------------------------------
# loss: 2.483967  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.458940
#
# Epoch 88
# -------------------------------
# loss: 2.527777  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.460619
#
# Epoch 89
# -------------------------------
# loss: 2.480672  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.439692
#
# Epoch 90
# -------------------------------
# loss: 2.499487  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.467454
#
# Epoch 91
# -------------------------------
# loss: 2.519804  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.445113
#
# Epoch 92
# -------------------------------
# loss: 2.447145  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.447915
#
# Epoch 93
# -------------------------------
# loss: 2.512605  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.444656
#
# Epoch 94
# -------------------------------
# loss: 2.462033  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.457038
#
# Epoch 95
# -------------------------------
# loss: 2.481296  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.459668
#
# Epoch 96
# -------------------------------
# loss: 2.465356  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.443069
#
# Epoch 97
# -------------------------------
# loss: 2.498479  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.454673
#
# Epoch 98
# -------------------------------
# loss: 2.462320  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.426329
#
# Epoch 99
# -------------------------------
# loss: 2.510915  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.464006
#
# Epoch 100
# -------------------------------
# loss: 2.491810  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.443383
#
# Epoch 101
# -------------------------------
# loss: 2.512786  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.447810
#
# Epoch 102
# -------------------------------
# loss: 2.469414  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.471839
#
# Epoch 103
# -------------------------------
# loss: 2.505613  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.446987
#
# Epoch 104
# -------------------------------
# loss: 2.453157  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.427888
#
# Epoch 105
# -------------------------------
# loss: 2.455221  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.434352
#
# Epoch 106
# -------------------------------
# loss: 2.451041  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.428630
#
# Epoch 107
# -------------------------------
# loss: 2.461009  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.429667
#
# Epoch 108
# -------------------------------
# loss: 2.469849  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.434526
#
# Epoch 109
# -------------------------------
# loss: 2.511631  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.436409
#
# Epoch 110
# -------------------------------
# loss: 2.476801  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.426489
#
# Epoch 111
# -------------------------------
# loss: 2.434466  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.468551
#
# Epoch 112
# -------------------------------
# loss: 2.443549  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.440450
#
# Epoch 113
# -------------------------------
# loss: 2.481548  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.435718
#
# Epoch 114
# -------------------------------
# loss: 2.456852  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.423438
#
# Epoch 115
# -------------------------------
# loss: 2.448542  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.451675
#
# Epoch 116
# -------------------------------
# loss: 2.442734  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.443557
#
# Epoch 117
# -------------------------------
# loss: 2.446774  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.411312
#
# Epoch 118
# -------------------------------
# loss: 2.464610  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.441535
#
# Epoch 119
# -------------------------------
# loss: 2.439789  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.444358
#
# Epoch 120
# -------------------------------
# loss: 2.462963  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.429557
#
# Epoch 121
# -------------------------------
# loss: 2.454988  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.416578
#
# Epoch 122
# -------------------------------
# loss: 2.421406  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.441708
#
# Epoch 123
# -------------------------------
# loss: 2.434206  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.424660
#
# Epoch 124
# -------------------------------
# loss: 2.459863  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.430786
#
# Epoch 125
# -------------------------------
# loss: 2.454894  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.435356
#
# Epoch 126
# -------------------------------
# loss: 2.480401  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.416778
#
# Epoch 127
# -------------------------------
# loss: 2.456947  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.426453
#
# Epoch 128
# -------------------------------
# loss: 2.451203  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.420019
#
# Epoch 129
# -------------------------------
# loss: 2.445751  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.408583
#
# Epoch 130
# -------------------------------
# loss: 2.481215  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.431363
#
# Epoch 131
# -------------------------------
# loss: 2.466236  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.415843
#
# Epoch 132
# -------------------------------
# loss: 2.496745  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.431061
#
# Epoch 133
# -------------------------------
# loss: 2.455303  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.432301
#
# Epoch 134
# -------------------------------
# loss: 2.425082  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.438040
#
# Epoch 135
# -------------------------------
# loss: 2.443171  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.430263
#
# Epoch 136
# -------------------------------
# loss: 2.464053  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.417374
#
# Epoch 137
# -------------------------------
# loss: 2.437117  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.403161
#
# Epoch 138
# -------------------------------
# loss: 2.406780  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.428965
#
# Epoch 139
# -------------------------------
# loss: 2.475096  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.434031
#
# Epoch 140
# -------------------------------
# loss: 2.427935  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.411396
#
# Epoch 141
# -------------------------------
# loss: 2.441512  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.390441
#
# Epoch 142
# -------------------------------
# loss: 2.450992  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.432813
#
# Epoch 143
# -------------------------------
# loss: 2.428908  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.393838
#
# Epoch 144
# -------------------------------
# loss: 2.468280  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.389695
#
# Epoch 145
# -------------------------------
# loss: 2.393496  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.417044
#
# Epoch 146
# -------------------------------
# loss: 2.415718  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.392017
#
# Epoch 147
# -------------------------------
# loss: 2.426789  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.404504
#
# Epoch 148
# -------------------------------
# loss: 2.456052  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.410536
#
# Epoch 149
# -------------------------------
# loss: 2.435151  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.392158
#
# Epoch 150
# -------------------------------
# loss: 2.440178  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.399552
#
# Epoch 151
# -------------------------------
# loss: 2.451868  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.394556
#
# Epoch 152
# -------------------------------
# loss: 2.470094  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.416726
#
# Epoch 153
# -------------------------------
# loss: 2.433762  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.444505
#
# Epoch 154
# -------------------------------
# loss: 2.448051  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.413796
#
# Epoch 155
# -------------------------------
# loss: 2.418958  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.392577
#
# Epoch 156
# -------------------------------
# loss: 2.394661  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.411387
#
# Epoch 157
# -------------------------------
# loss: 2.446027  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.418002
#
# Epoch 158
# -------------------------------
# loss: 2.470114  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.413935
#
# Epoch 159
# -------------------------------
# loss: 2.442863  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.391854
#
# Epoch 160
# -------------------------------
# loss: 2.467959  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.404784
#
# Epoch 161
# -------------------------------
# loss: 2.409087  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.401139
#
# Epoch 162
# -------------------------------
# loss: 2.462407  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.413571
#
# Epoch 163
# -------------------------------
# loss: 2.413998  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.397383
#
# Epoch 164
# -------------------------------
# loss: 2.419013  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.394237
#
# Epoch 165
# -------------------------------
# loss: 2.401462  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.420737
#
# Epoch 166
# -------------------------------
# loss: 2.420394  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.438344
#
# Epoch 167
# -------------------------------
# loss: 2.440801  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.405375
#
# Epoch 168
# -------------------------------
# loss: 2.449042  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.412201
#
# Epoch 169
# -------------------------------
# loss: 2.399302  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.413082
#
# Epoch 170
# -------------------------------
# loss: 2.427074  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.383558
#
# Epoch 171
# -------------------------------
# loss: 2.434196  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.406785
#
# Epoch 172
# -------------------------------
# loss: 2.404613  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.381984
#
# Epoch 173
# -------------------------------
# loss: 2.468460  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.403233
#
# Epoch 174
# -------------------------------
# loss: 2.403066  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.396148
#
# Epoch 175
# -------------------------------
# loss: 2.466272  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.412592
#
# Epoch 176
# -------------------------------
# loss: 2.414524  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.383502
#
# Epoch 177
# -------------------------------
# loss: 2.409706  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.348622
#
# Epoch 178
# -------------------------------
# loss: 2.430032  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.395337
#
# Epoch 179
# -------------------------------
# loss: 2.526652  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.393571
#
# Epoch 180
# -------------------------------
# loss: 2.420564  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.391559
#
# Epoch 181
# -------------------------------
# loss: 2.368579  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.415675
#
# Epoch 182
# -------------------------------
# loss: 2.448063  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.386548
#
# Epoch 183
# -------------------------------
# loss: 2.419829  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.405667
#
# Epoch 184
# -------------------------------
# loss: 2.475295  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.405615
#
# Epoch 185
# -------------------------------
# loss: 2.422552  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.391298
#
# Epoch 186
# -------------------------------
# loss: 2.387986  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.406579
#
# Epoch 187
# -------------------------------
# loss: 2.467560  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.393406
#
# Epoch 188
# -------------------------------
# loss: 2.482732  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.408474
#
# Epoch 189
# -------------------------------
# loss: 2.404875  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.386031
#
# Epoch 190
# -------------------------------
# loss: 2.387890  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.413999
#
# Epoch 191
# -------------------------------
# loss: 2.427345  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.383479
#
# Epoch 192
# -------------------------------
# loss: 2.431862  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.379823
#
# Epoch 193
# -------------------------------
# loss: 2.478200  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.425026
#
# Epoch 194
# -------------------------------
# loss: 2.461436  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.401344
#
# Epoch 195
# -------------------------------
# loss: 2.456055  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.401179
#
# Epoch 196
# -------------------------------
# loss: 2.410783  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.392577
#
# Epoch 197
# -------------------------------
# loss: 2.482483  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.399869
#
# Epoch 198
# -------------------------------
# loss: 2.384063  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.395627
#
# Epoch 199
# -------------------------------
# loss: 2.448261  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.367867
#
# Epoch 200
# -------------------------------
# loss: 2.450788  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.388220
#
# Epoch 201
# -------------------------------
# loss: 2.430386  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.393254
#
# Epoch 202
# -------------------------------
# loss: 2.418402  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.432192
#
# Epoch 203
# -------------------------------
# loss: 2.449115  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.391870
#
# Epoch 204
# -------------------------------
# loss: 2.414635  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.422593
#
# Epoch 205
# -------------------------------
# loss: 2.455721  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.417095
#
# Epoch 206
# -------------------------------
# loss: 2.385939  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.402279
#
# Epoch 207
# -------------------------------
# loss: 2.395933  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.422562
#
# Epoch 208
# -------------------------------
# loss: 2.476176  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.354026
#
# Epoch 209
# -------------------------------
# loss: 2.373705  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.417606
#
# Epoch 210
# -------------------------------
# loss: 2.451689  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.390241
#
# Epoch 211
# -------------------------------
# loss: 2.398761  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.425820
#
# Epoch 212
# -------------------------------
# loss: 2.414296  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.404195
#
# Epoch 213
# -------------------------------
# loss: 2.407688  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.363824
#
# Epoch 214
# -------------------------------
# loss: 2.481151  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.390511
#
# Epoch 215
# -------------------------------
# loss: 2.409604  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.387316
#
# Epoch 216
# -------------------------------
# loss: 2.395871  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.398161
#
# Epoch 217
# -------------------------------
# loss: 2.374758  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.416802
#
# Epoch 218
# -------------------------------
# loss: 2.479135  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.406327
#
# Epoch 219
# -------------------------------
# loss: 2.402323  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.380604
#
# Epoch 220
# -------------------------------
# loss: 2.436391  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.395733
#
# Epoch 221
# -------------------------------
# loss: 2.448041  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.388290
#
# Epoch 222
# -------------------------------
# loss: 2.414519  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.399706
#
# Epoch 223
# -------------------------------
# loss: 2.392160  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.421870
#
# Epoch 224
# -------------------------------
# loss: 2.432266  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.397000
#
# Epoch 225
# -------------------------------
# loss: 2.449144  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.402754
#
# Epoch 226
# -------------------------------
# loss: 2.466893  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.373627
#
# Epoch 227
# -------------------------------
# loss: 2.447765  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.413468
#
# Epoch 228
# -------------------------------
# loss: 2.398854  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.400502
#
# Epoch 229
# -------------------------------
# loss: 2.435947  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.406127
#
# Epoch 230
# -------------------------------
# loss: 2.492887  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.393232
#
# Epoch 231
# -------------------------------
# loss: 2.443657  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.361212
#
# Epoch 232
# -------------------------------
# loss: 2.418840  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.386161
#
# Epoch 233
# -------------------------------
# loss: 2.507958  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.381439
#
# Epoch 234
# -------------------------------
# loss: 2.458867  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.382048
#
# Epoch 235
# -------------------------------
# loss: 2.412813  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.407497
#
# Epoch 236
# -------------------------------
# loss: 2.394053  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.391640
#
# Epoch 237
# -------------------------------
# loss: 2.412329  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.402337
#
# Epoch 238
# -------------------------------
# loss: 2.477569  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.411651
#
# Epoch 239
# -------------------------------
# loss: 2.375947  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.359157
#
# Epoch 240
# -------------------------------
# loss: 2.396709  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.375969
#
# Epoch 241
# -------------------------------
# loss: 2.435729  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.404660
#
# Epoch 242
# -------------------------------
# loss: 2.456555  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.409647
#
# Epoch 243
# -------------------------------
# loss: 2.389684  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.394825
#
# Epoch 244
# -------------------------------
# loss: 2.487950  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.359332
#
# Epoch 245
# -------------------------------
# loss: 2.416129  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.420786
#
# Epoch 246
# -------------------------------
# loss: 2.441237  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.382442
#
# Epoch 247
# -------------------------------
# loss: 2.454824  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.354413
#
# Epoch 248
# -------------------------------
# loss: 2.498303  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.406393
#
# Epoch 249
# -------------------------------
# loss: 2.413272  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.394207
#
# Epoch 250
# -------------------------------
# loss: 2.464114  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.386029
#
# Epoch 251
# -------------------------------
# loss: 2.382691  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.402680
#
# Epoch 252
# -------------------------------
# loss: 2.450541  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.407725
#
# Epoch 253
# -------------------------------
# loss: 2.417404  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.404385
#
# Epoch 254
# -------------------------------
# loss: 2.452124  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.407661
#
# Epoch 255
# -------------------------------
# loss: 2.349389  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.375374
#
# Epoch 256
# -------------------------------
# loss: 2.416771  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.386622
#
# Epoch 257
# -------------------------------
# loss: 2.376824  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.369863
#
# Epoch 258
# -------------------------------
# loss: 2.464012  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.365763
#
# Epoch 259
# -------------------------------
# loss: 2.456802  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.397230
#
# Epoch 260
# -------------------------------
# loss: 2.431120  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.381135
#
# Epoch 261
# -------------------------------
# loss: 2.458925  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.388093
#
# Epoch 262
# -------------------------------
# loss: 2.381251  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.388851
#
# Epoch 263
# -------------------------------
# loss: 2.427540  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.362499
#
# Epoch 264
# -------------------------------
# loss: 2.399799  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.400470
#
# Epoch 265
# -------------------------------
# loss: 2.417435  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.365503
#
# Epoch 266
# -------------------------------
# loss: 2.447038  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.416448
#
# Epoch 267
# -------------------------------
# loss: 2.479804  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.403593
#
# Epoch 268
# -------------------------------
# loss: 2.453221  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.431235
#
# Epoch 269
# -------------------------------
# loss: 2.439339  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.398551
#
# Epoch 270
# -------------------------------
# loss: 2.473891  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.374139
#
# Epoch 271
# -------------------------------
# loss: 2.420740  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.419433
#
# Epoch 272
# -------------------------------
# loss: 2.384889  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.393148
#
# Epoch 273
# -------------------------------
# loss: 2.435370  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.405032
#
# Epoch 274
# -------------------------------
# loss: 2.384443  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.382878
#
# Epoch 275
# -------------------------------
# loss: 2.417779  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.398229
#
# Epoch 276
# -------------------------------
# loss: 2.496695  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.414777
#
# Epoch 277
# -------------------------------
# loss: 2.422209  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.415948
#
# Epoch 278
# -------------------------------
# loss: 2.475698  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.403748
#
# Epoch 279
# -------------------------------
# loss: 2.480285  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.403372
#
# Epoch 280
# -------------------------------
# loss: 2.414628  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.406929
#
# Epoch 281
# -------------------------------
# loss: 2.445389  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.409144
#
# Epoch 282
# -------------------------------
# loss: 2.482782  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.391935
#
# Epoch 283
# -------------------------------
# loss: 2.387182  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.379225
#
# Epoch 284
# -------------------------------
# loss: 2.436071  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.376998
#
# Epoch 285
# -------------------------------
# loss: 2.445838  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.404620
#
# Epoch 286
# -------------------------------
# loss: 2.426934  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.409334
#
# Epoch 287
# -------------------------------
# loss: 2.476777  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.400996
#
# Epoch 288
# -------------------------------
# loss: 2.450676  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.403587
#
# Epoch 289
# -------------------------------
# loss: 2.424139  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.377908
#
# Epoch 290
# -------------------------------
# loss: 2.392816  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.382308
#
# Epoch 291
# -------------------------------
# loss: 2.442034  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.384599
#
# Epoch 292
# -------------------------------
# loss: 2.400702  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.397085
#
# Epoch 293
# -------------------------------
# loss: 2.470258  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.404675
#
# Epoch 294
# -------------------------------
# loss: 2.364150  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.385916
#
# Epoch 295
# -------------------------------
# loss: 2.481007  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.377786
#
# Epoch 296
# -------------------------------
# loss: 2.479529  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.401295
#
# Epoch 297
# -------------------------------
# loss: 2.423635  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.398277
#
# Epoch 298
# -------------------------------
# loss: 2.427292  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.408058
#
# Epoch 299
# -------------------------------
# loss: 2.448049  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.391635
#
# Epoch 300
# -------------------------------
# loss: 2.374224  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.413013
#
# Epoch 301
# -------------------------------
# loss: 2.382471  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.384943
#
# Epoch 302
# -------------------------------
# loss: 2.441894  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.425478
#
# Epoch 303
# -------------------------------
# loss: 2.435183  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.414332
#
# Epoch 304
# -------------------------------
# loss: 2.391335  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.419466
#
# Epoch 305
# -------------------------------
# loss: 2.381889  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.372881
#
# Epoch 306
# -------------------------------
# loss: 2.461692  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.398009
#
# Epoch 307
# -------------------------------
# loss: 2.458205  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.392292
#
# Epoch 308
# -------------------------------
# loss: 2.480089  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.397639
#
# Epoch 309
# -------------------------------
# loss: 2.418561  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.389650
#
# Epoch 310
# -------------------------------
# loss: 2.405768  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.391947
#
# Epoch 311
# -------------------------------
# loss: 2.438710  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.389497
#
# Epoch 312
# -------------------------------
# loss: 2.439747  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.418867
#
# Epoch 313
# -------------------------------
# loss: 2.401089  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.390114
#
# Epoch 314
# -------------------------------
# loss: 2.336998  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.400889
#
# Epoch 315
# -------------------------------
# loss: 2.409609  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.429642
#
# Epoch 316
# -------------------------------
# loss: 2.419905  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.432451
#
# Epoch 317
# -------------------------------
# loss: 2.492059  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.393635
#
# Epoch 318
# -------------------------------
# loss: 2.368881  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.404759
#
# Epoch 319
# -------------------------------
# loss: 2.434178  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.404570
#
# Epoch 320
# -------------------------------
# loss: 2.492420  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.403854
#
# Epoch 321
# -------------------------------
# loss: 2.434187  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.403406
#
# Epoch 322
# -------------------------------
# loss: 2.481093  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.414250
#
# Epoch 323
# -------------------------------
# loss: 2.447007  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.404642
#
# Epoch 324
# -------------------------------
# loss: 2.397549  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.372303
#
# Epoch 325
# -------------------------------
# loss: 2.375724  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.399484
#
# Epoch 326
# -------------------------------
# loss: 2.386385  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.392274
#
# Epoch 327
# -------------------------------
# loss: 2.438703  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.380282
#
# Epoch 328
# -------------------------------
# loss: 2.468011  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.402081
#
# Epoch 329
# -------------------------------
# loss: 2.440037  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.405402
#
# Epoch 330
# -------------------------------
# loss: 2.395208  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.423170
#
# Epoch 331
# -------------------------------
# loss: 2.429253  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.397210
#
# Epoch 332
# -------------------------------
# loss: 2.433190  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.419550
#
# Epoch 333
# -------------------------------
# loss: 2.372595  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.401341
#
# Epoch 334
# -------------------------------
# loss: 2.452181  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.414581
#
# Epoch 335
# -------------------------------
# loss: 2.407806  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.415412
#
# Epoch 336
# -------------------------------
# loss: 2.433597  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.381357
#
# Epoch 337
# -------------------------------
# loss: 2.428285  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.421497
#
# Epoch 338
# -------------------------------
# loss: 2.433786  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.392733
#
# Epoch 339
# -------------------------------
# loss: 2.368006  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.405669
#
# Epoch 340
# -------------------------------
# loss: 2.389953  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.399296
#
# Epoch 341
# -------------------------------
# loss: 2.407395  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.403397
#
# Epoch 342
# -------------------------------
# loss: 2.427735  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.405075
#
# Epoch 343
# -------------------------------
# loss: 2.442569  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.386156
#
# Epoch 344
# -------------------------------
# loss: 2.402949  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.399108
#
# Epoch 345
# -------------------------------
# loss: 2.371636  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.382093
#
# Epoch 346
# -------------------------------
# loss: 2.470757  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.398660
#
# Epoch 347
# -------------------------------
# loss: 2.371712  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.402197
#
# Epoch 348
# -------------------------------
# loss: 2.432740  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.414544
#
# Epoch 349
# -------------------------------
# loss: 2.444262  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.388599
#
# Epoch 350
# -------------------------------
# loss: 2.450829  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.394566
#
# Epoch 351
# -------------------------------
# loss: 2.389618  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.416232
#
# Epoch 352
# -------------------------------
# loss: 2.383923  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.403324
#
# Epoch 353
# -------------------------------
# loss: 2.427362  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.380164
#
# Epoch 354
# -------------------------------
# loss: 2.426389  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.409017
#
# Epoch 355
# -------------------------------
# loss: 2.391715  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.378815
#
# Epoch 356
# -------------------------------
# loss: 2.470162  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.411630
#
# Epoch 357
# -------------------------------
# loss: 2.414696  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.402515
#
# Epoch 358
# -------------------------------
# loss: 2.515321  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.380452
#
# Epoch 359
# -------------------------------
# loss: 2.472481  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.416374
#
# Epoch 360
# -------------------------------
# loss: 2.450652  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.399438
#
# Epoch 361
# -------------------------------
# loss: 2.424155  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.409711
#
# Epoch 362
# -------------------------------
# loss: 2.488430  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.406735
#
# Epoch 363
# -------------------------------
# loss: 2.448201  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.385832
#
# Epoch 364
# -------------------------------
# loss: 2.427310  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.410612
#
# Epoch 365
# -------------------------------
# loss: 2.442657  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.391194
#
# Epoch 366
# -------------------------------
# loss: 2.496615  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.394847
#
# Epoch 367
# -------------------------------
# loss: 2.462412  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.369910
#
# Epoch 368
# -------------------------------
# loss: 2.391479  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.395911
#
# Epoch 369
# -------------------------------
# loss: 2.401831  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.406574
#
# Epoch 370
# -------------------------------
# loss: 2.468416  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.381902
#
# Epoch 371
# -------------------------------
# loss: 2.492447  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.410690
#
# Epoch 372
# -------------------------------
# loss: 2.449014  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.402235
#
# Epoch 373
# -------------------------------
# loss: 2.395721  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.398700
#
# Epoch 374
# -------------------------------
# loss: 2.506670  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.372571
#
# Epoch 375
# -------------------------------
# loss: 2.413887  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.395139
#
# Epoch 376
# -------------------------------
# loss: 2.424315  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.371876
#
# Epoch 377
# -------------------------------
# loss: 2.371404  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.425530
#
# Epoch 378
# -------------------------------
# loss: 2.447776  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.399838
#
# Epoch 379
# -------------------------------
# loss: 2.508270  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.425902
#
# Epoch 380
# -------------------------------
# loss: 2.311642  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.379398
#
# Epoch 381
# -------------------------------
# loss: 2.392950  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.396443
#
# Epoch 382
# -------------------------------
# loss: 2.458517  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.429681
#
# Epoch 383
# -------------------------------
# loss: 2.535065  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.411142
#
# Epoch 384
# -------------------------------
# loss: 2.411795  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.358753
#
# Epoch 385
# -------------------------------
# loss: 2.413327  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.429211
#
# Epoch 386
# -------------------------------
# loss: 2.512203  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.359804
#
# Epoch 387
# -------------------------------
# loss: 2.429127  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.380050
#
# Epoch 388
# -------------------------------
# loss: 2.431553  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.406039
#
# Epoch 389
# -------------------------------
# loss: 2.378107  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.364238
#
# Epoch 390
# -------------------------------
# loss: 2.458714  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.426301
#
# Epoch 391
# -------------------------------
# loss: 2.463476  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.421692
#
# Epoch 392
# -------------------------------
# loss: 2.366639  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.369669
#
# Epoch 393
# -------------------------------
# loss: 2.415397  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.413985
#
# Epoch 394
# -------------------------------
# loss: 2.385645  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.409604
#
# Epoch 395
# -------------------------------
# loss: 2.424451  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.409422
#
# Epoch 396
# -------------------------------
# loss: 2.411787  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.389331
#
# Epoch 397
# -------------------------------
# loss: 2.405473  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.394304
#
# Epoch 398
# -------------------------------
# loss: 2.445839  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.385556
#
# Epoch 399
# -------------------------------
# loss: 2.422206  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.398164
#
# Epoch 400
# -------------------------------
# loss: 2.416720  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.408970
#
# Epoch 401
# -------------------------------
# loss: 2.379196  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.377532
#
# Epoch 402
# -------------------------------
# loss: 2.392363  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.388771
#
# Epoch 403
# -------------------------------
# loss: 2.419881  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.412474
#
# Epoch 404
# -------------------------------
# loss: 2.419503  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.382996
#
# Epoch 405
# -------------------------------
# loss: 2.419860  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.377837
#
# Epoch 406
# -------------------------------
# loss: 2.411444  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.376435
#
# Epoch 407
# -------------------------------
# loss: 2.458109  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.395916
#
# Epoch 408
# -------------------------------
# loss: 2.487482  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.421787
#
# Epoch 409
# -------------------------------
# loss: 2.471282  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.396927
#
# Epoch 410
# -------------------------------
# loss: 2.349961  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.406532
#
# Epoch 411
# -------------------------------
# loss: 2.491488  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.375405
#
# Epoch 412
# -------------------------------
# loss: 2.436671  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.396688
#
# Epoch 413
# -------------------------------
# loss: 2.412540  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.364313
#
# Epoch 414
# -------------------------------
# loss: 2.458088  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.394038
#
# Epoch 415
# -------------------------------
# loss: 2.395063  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.393606
#
# Epoch 416
# -------------------------------
# loss: 2.365294  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.395812
#
# Epoch 417
# -------------------------------
# loss: 2.358472  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.415585
#
# Epoch 418
# -------------------------------
# loss: 2.452990  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.384853
#
# Epoch 419
# -------------------------------
# loss: 2.392854  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.416591
#
# Epoch 420
# -------------------------------
# loss: 2.456258  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.402664
#
# Epoch 421
# -------------------------------
# loss: 2.362200  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.406179
#
# Epoch 422
# -------------------------------
# loss: 2.374870  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.417945
#
# Epoch 423
# -------------------------------
# loss: 2.399120  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.418511
#
# Epoch 424
# -------------------------------
# loss: 2.400250  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.400488
#
# Epoch 425
# -------------------------------
# loss: 2.415098  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.380211
#
# Epoch 426
# -------------------------------
# loss: 2.395779  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.386667
#
# Epoch 427
# -------------------------------
# loss: 2.441036  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.408219
#
# Epoch 428
# -------------------------------
# loss: 2.437037  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.402890
#
# Epoch 429
# -------------------------------
# loss: 2.347407  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.386050
#
# Epoch 430
# -------------------------------
# loss: 2.448738  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.405272
#
# Epoch 431
# -------------------------------
# loss: 2.432037  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.408621
#
# Epoch 432
# -------------------------------
# loss: 2.384229  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.386288
#
# Epoch 433
# -------------------------------
# loss: 2.392606  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.405776
#
# Epoch 434
# -------------------------------
# loss: 2.427242  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.417105
#
# Epoch 435
# -------------------------------
# loss: 2.474264  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.374548
#
# Epoch 436
# -------------------------------
# loss: 2.447345  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.387214
#
# Epoch 437
# -------------------------------
# loss: 2.453810  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.392917
#
# Epoch 438
# -------------------------------
# loss: 2.535987  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.379837
#
# Epoch 439
# -------------------------------
# loss: 2.388721  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.407113
#
# Epoch 440
# -------------------------------
# loss: 2.437431  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.396800
#
# Epoch 441
# -------------------------------
# loss: 2.370709  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.372360
#
# Epoch 442
# -------------------------------
# loss: 2.521522  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.384183
#
# Epoch 443
# -------------------------------
# loss: 2.466292  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.379366
#
# Epoch 444
# -------------------------------
# loss: 2.438808  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.378776
#
# Epoch 445
# -------------------------------
# loss: 2.374150  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.395997
#
# Epoch 446
# -------------------------------
# loss: 2.382323  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.424512
#
# Epoch 447
# -------------------------------
# loss: 2.473951  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.400769
#
# Epoch 448
# -------------------------------
# loss: 2.388918  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.405142
#
# Epoch 449
# -------------------------------
# loss: 2.374246  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.382981
#
# Epoch 450
# -------------------------------
# loss: 2.448400  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.391273
#
# Epoch 451
# -------------------------------
# loss: 2.401075  [  256/ 2330]
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.393563
#
# Epoch 452
# -------------------------------
# loss: 2.460585  [  256/ 2330]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 for t in range(epochs):
#       3     print(f"Epoch {t+1}\n-------------------------------")
# ----> 4     train(train_dataloader, model, loss_fn, optimizer)
#       5     test_error.append(test(test_dataloader, model, loss_fn))
#       6 print("Done!")
#
# Cell In[8], line 38, in train(dataloader, model, loss_fn, optimizer)
#      36 size = len(dataloader.dataset)
#      37 model.train()
# ---> 38 for batch, (X, y) in enumerate(dataloader):
#      39     X, y = X.to(device), y.to(device)
#      41     # Compute prediction error
#
# File ~/projects/coursework/winter2026/ecen471/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File ~/projects/coursework/winter2026/ecen471/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:801, in _SingleProcessDataLoaderIter._next_data(self)
#     799 def _next_data(self):
#     800     index = self._next_index()  # may raise StopIteration
# --> 801     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802     if self._pin_memory:
#     803         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/projects/coursework/winter2026/ecen471/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50 if self.auto_collation:
#      51     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 52         data = self.dataset.__getitems__(possibly_batched_index)
#      53     else:
#      54         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File ~/projects/coursework/winter2026/ecen471/.venv/lib/python3.12/site-packages/torch/utils/data/dataset.py:443, in Subset.__getitems__(self, indices)
#     441     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     442 else:
# --> 443     return [self.dataset[self.indices[idx]] for idx in indices]
#
# Cell In[3], line 13, in InstrumentDataset.__getitem__(self, idx)
#      12 def __getitem__(self, idx):
# ---> 13     X_i = torch.tensor(self.X[idx].reshape((1, self.X.shape[1], self.X.shape[2])), dtype=torch.float32)
#      14     y_i = torch.tensor(self.y[idx], dtype=torch.long)
#      15     return X_i, y_i
#
# KeyboardInterrupt:

# %%
import numpy as np
plt.plot(np.array(test_error))
# plt.ylim([0.0, 0.02])

# %%
map = {v:k for k, v in labels_map.items()}

count = 0
for X, y in train_dataloader:    
    for i in range(len(y)):
        count += 1
        pred = model(X)
        pred_index = torch.argmax(pred[i,:])
        true_index = y[i]

        pred = map[int(pred_index)]
        truth = map[int(true_index)]
        if not pred == truth:
            print(f"{pred} | {truth}")

print(count)
# Out:
# Cello | Contrabass
# Viola | Violin
# Oboe | Alto Saxophone
# Contrabass | Cello
# Cello | Alto Saxophone
# Clarinet in Bb | Flute
# French Horn | Bass Tuba
# Flute | Trumpet in C
# Clarinet in Bb | Flute
# 2330

# %%
map = {v:k for k, v in labels_map.items()}

count = 0
for X, y in test_dataloader:    
    for i in range(len(y)):
        count += 1
        pred = model(X)
        pred_index = torch.argmax(pred[i,:])
        true_index = y[i]

        pred = map[int(pred_index)]
        truth = map[int(true_index)]
        if not pred == truth:
            print(f"{pred} | {truth}")

print(count)
# Out:
# Cello | Viola
# Cello | Bass Tuba
# Violin | Viola
# Viola | Accordion
# Flute | Bassoon
# Clarinet in Bb | Oboe
# Alto Saxophone | Flute
# Trumpet in C | Flute
# Contrabass | Clarinet in Bb
# Accordion | Trombone
# Flute | Clarinet in Bb
# Bass Tuba | French Horn
# Viola | Violin
# Clarinet in Bb | Flute
# Trumpet in C | Alto Saxophone
# Alto Saxophone | Clarinet in Bb
# Bass Tuba | Bassoon
# Flute | Clarinet in Bb
# Clarinet in Bb | Flute
# French Horn | Trombone
# Flute | Cello
# Cello | Contrabass
# Oboe | Flute
# Violin | Accordion
# Viola | Violin
# Oboe | Alto Saxophone
# Trumpet in C | Alto Saxophone
# French Horn | Trombone
# Viola | Bassoon
# Clarinet in Bb | Oboe
# Bassoon | French Horn
# Accordion | Oboe
# 583

# %%
import matplotlib.pyplot as plt
# Display image and label.
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[2].squeeze()
label = train_labels[2]
plt.imshow(img, cmap="gray")
plt.show()
print(f"Label: {label}")
# Out:
# Feature batch shape: torch.Size([256, 1, 32, 32])
# Labels batch shape: torch.Size([256])
# Label: 2

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

from torch.utils.data import Dataset

class AudioDataset(DataSet):
    pass

train_dataloader = DataLoader(training_data, batch_size=64)
test_dataloader = DataLoader(test_data, batch_size=64)

class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(20, 64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.module(x)
    
model = MLP()

learning_rate = 1e-3
batch_size = 64
epochs = 5

# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       5 from torchvision.transforms import ToTensor
#       7 from torch.utils.data import Dataset
# ----> 9 class AudioDataset(DataSet):
#      10     pass
#      12 train_dataloader = DataLoader(training_data, batch_size=64)
#
# NameError: name 'DataSet' is not defined

# %% [markdown]
# I got the dataset from kaggle [here](https://www.kaggle.com/datasets/thedevastator/tinysol-isolated-musical-notes-from-14-musical-i).

# %% [markdown]
# I decided to reduce the dimensionality of the model for our use case
#
# https://reference.wolfram.com/language/ref/netencoder/Audio.html
#
# Using the tutorial above, I settled on using the AudioMFCC encoder, which has a corresponding function in a Python library
#
# https://docs.pytorch.org/audio/master/generated/torchaudio.transforms.MFCC.html

# %% [markdown]
# I couldn't get torchaudio working, so intead I am using a different library
# [text](https://python-speech-features.readthedocs.io/en/latest/#)

# %% [markdown]
# Here is a pytorch version of dropout
# [link](https://codesignal.com/learn/courses/improving-neural-networks-with-pytorch/lessons/adding-dropout-to-neural-networks-in-pytorch)

# %%
print(f"Model structure: {model}\n\n")

for name, param in model.named_parameters():
    print(f"Layer: {name} | Size: {param.size()} | Values : {param[:2]} \n")

# %%
from python_speech_features import mfcc
from python_speech_features import logfbank
import scipy.io.wavfile as wav

nfft = 4096

(rate,sig) = wav.read("Brass/Bass_Tuba/ordinario/BTb-ord-A1-ff-N-T19d.wav")
(rate,sig) = wav.read("Brass/Horn/ordinario/Hn-ord-A1-mf-N-N.wav")

mfcc_feat = mfcc(sig,rate, nfft=nfft, winlen=50e-3)
print(mfcc_feat[mfcc_feat.shape[0]//2,:])

nfft = 4096
(rate,sig) = wav.read("Brass/Horn/ordinario/Hn-ord-A1-mf-N-N.wav")
mfcc_feat = mfcc(sig,rate, nfft=nfft, winlen=50e-3 )
# fbank_feat = logfbank(sig,rate, nfft=nfft)

print(mfcc_feat[mfcc_feat.shape[0]//2,:])

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

def plot_mfcc(audio_path, ax, title):
    # Load the audio file
    y, sr = librosa.load(audio_path)

    # Extract MFCC features
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20, n_fft=1800)

    # Plot MFCCs
    # plt.figure(figsize=(10, 4))
    librosa.display.specshow(mfccs, x_axis='time', cmap='viridis', ax = ax)
    # ax.colorbar(format='%+2.0f dB')
    ax.set_title(title)
    ax.set_xlabel('Time')
    ax.set_ylabel('MFCC Coefficient')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Example usage
audio_file_path1 = "Winds/Bassoon/ordinario/Bn-ord-D#3-pp-N-N.wav"
# audio_file_path2 = "Brass/Bass_Tuba/ordinario/BTb-ord-D#3-mf-N-T25u.wav"
# audio_file_path1 = "Brass/Horn/ordinario/Hn-ord-A1-mf-N-N.wav"
audio_file_path2 = "Brass/Trombone/ordinario/Tbn-ord-D#3-ff-N-N.wav"
# audio_file_path1 = "Strings/Viola/ordinario/Va-ord-A#3-ff-3c-N.wav"
# audio_file_path2 = "Strings/Viola/ordinario/Va-ord-G5-ff-3c-N.wav"
plot_mfcc(audio_file_path1, ax1, "Basson playing D#3")
plot_mfcc(audio_file_path2, ax2, "Trombone playing D#3")

# %% [markdown]
# I found this [tutorial](https://www.geeksforgeeks.org/machine-learning/classification-using-sklearn-multi-layer-perceptron/) helpful

# %%
from sklearn.neural_network import MLPClassifier

MLPClassifier()

# %% [markdown]
# This [tutorial](https://www.geeksforgeeks.org/deep-learning/training-neural-networks-with-dropout-for-effective-regularization/)
#  goes over training with dropout with tensorflow
