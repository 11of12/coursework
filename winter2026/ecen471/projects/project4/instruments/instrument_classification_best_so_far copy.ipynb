# %% [markdown]
# # Separate the Training and Test Data

# %%
import torch
import pickle

# %%
from torch.utils.data import Dataset, random_split
import numpy as np
def normalize_data(X):
        X = np.array(X)
        num_feature_types = X.shape[1]
        new_X = np.zeros_like(X)
        min_max_values = np.zeros((X.shape[1], 2))

        for i in range(num_feature_types):
            new_X[:, i] = (X[:, i] - np.min(X[:, i])) / (np.max(X[:, i]) - np.min(X[:, i]))
            min_max_values[i, 0] = np.min(X[:, i])
            min_max_values[i, 1] = np.max(X[:, i])
        
        min_max_training_values = min_max_values

        return new_X


class InstrumentDataset(Dataset):
    def __init__(self, X, y, labels):
        self.X = X
        self.y = y
        self.labels = labels

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        X_i = torch.tensor(self.X[idx].reshape((1, self.X.shape[1], self.X.shape[2])), dtype=torch.float32)
        y_i = torch.tensor(self.y[idx], dtype=torch.long)
        return X_i, y_i

data = pickle.load(open('processed_data.pkl', 'rb'))
# X = normalize_data(data["X"])
X = data["X"]
y = data["y"]
labels_map = data["labels_map"]

num_mfcc = X.shape[1]
num_time_steps = X.shape[2]

generator = torch.Generator().manual_seed(42)
dataset = InstrumentDataset(X=X, y=y, labels=labels_map.keys())    

num_training_points = round(0.8*y.shape[0])
num_validation_points = round(0.2*y.shape[0])
training_dataset, validation_dataset = random_split(dataset, lengths=[num_training_points, num_validation_points], generator=generator)

# %%
from torch.utils.data import DataLoader
batch_size = 512
train_dataloader = DataLoader(training_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=True)

# %%
for X, y in train_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    print(y)
# Out:
# Shape of X [N, C, H, W]: torch.Size([512, 1, 32, 32])
# Shape of y: torch.Size([512]) torch.int64
# tensor([ 4,  3, 10, 13, 12,  5,  3, 11, 11,  1,  4, 11,  8,  7, 10, 11, 12,  3,
#          4, 11, 12, 12, 10,  9, 12,  9, 11, 11,  7,  6,  5,  7, 12, 11, 11, 10,
#         11, 11, 11,  3, 10,  3,  5, 13,  1, 11,  5, 10, 12, 10, 10,  0, 11, 11,
#          0,  6,  3,  3, 12, 11, 13,  7,  7, 12, 11,  7,  2,  8,  1,  3,  7,  8,
#         11, 11,  7,  9,  2,  6, 11,  0, 10, 11,  7,  4,  4,  8, 11,  8,  3, 12,
#         11,  4,  3,  4, 11,  2,  8,  8, 12,  7, 11, 10, 10, 10, 11, 11, 13,  3,
#          2,  7,  2, 11,  1, 13, 10,  3, 11,  5, 12, 11,  5, 10,  6,  5, 11,  4,
#          9, 13,  3,  6, 10, 12,  2, 12, 12, 11,  5,  3, 11,  0, 10, 11,  7,  5,
#         11,  7, 11, 11,  3, 12, 11,  4,  1,  4,  5, 12,  7,  6,  3,  7,  3, 10,
#          7, 12,  3,  7, 12,  3,  3, 11, 12, 12,  3, 12,  2, 12, 11,  4, 11, 12,
#         12,  9, 11,  1, 11, 11,  2,  6,  9, 11, 12,  5,  5,  1,  9,  3,  3,  3,
#         12,  2,  3,  0, 10,  0,  3, 11,  4,  9, 11, 10,  7, 13,  4,  1,  5,  7,
#         10, 12, 11,  6,  7, 11, 10,  2,  7, 13, 11, 12,  6, 12, 10,  6,  9,  3,
#         11,  3, 12, 10, 11,  7, 10, 11,  1,  4,  3, 11,  3, 11, 12, 12, 10,  3,
#         10,  6, 10, 12, 12,  5,  1, 10, 11, 12,  0, 12,  7,  7, 10,  3, 11, 12,
#         11,  1, 12,  0,  7,  7,  6, 13,  1,  0, 11, 12, 11, 11, 12,  5,  4, 12,
#         12, 12,  2, 11,  5, 11,  1, 13,  3,  6, 11,  7,  7, 11, 11,  3, 10, 11,
#          2, 12, 12,  6,  7,  3,  6,  7, 11, 10, 13, 11, 12, 11, 10, 10, 11,  6,
#          3,  4,  5, 12,  7, 12,  8,  6,  7, 11, 11,  9, 11, 10, 10,  6, 11,  3,
#         10, 11,  3, 11, 11,  1,  2, 11, 11, 11,  0,  3, 12,  4,  5,  8,  3,  3,
#         12, 11,  7, 12,  4,  9,  7,  3,  7,  8,  2,  3, 10, 13, 10, 11, 12, 10,
#          4, 11,  0,  9, 11,  7, 11, 12, 11, 12, 12, 11,  4,  4,  6,  4,  8,  6,
#          4,  5, 10, 10,  3, 10,  8,  4,  2, 11, 11, 10,  6,  2,  3, 11,  5, 10,
#          0, 11, 11,  6,  9,  3,  8,  8, 11,  7,  4,  3, 11,  0,  2, 10,  3,  2,
#          5,  7,  7, 11, 12, 10,  2,  9,  2,  3,  2,  1,  3,  6, 11, 12,  8, 11,
#         10, 12, 11,  0,  7, 11,  6,  4, 13,  7, 13, 11,  6,  3, 11,  2,  6,  6,
#          3,  7, 11,  6, 11,  6,  6, 10, 12,  7, 13, 10,  1,  1,  1,  6, 11,  4,
#         11, 11, 11,  3, 11,  7, 12, 10, 11,  3, 11, 12, 12, 11,  8,  7,  3, 11,
#          6, 12, 11, 11, 12, 11,  3,  3])
# Shape of X [N, C, H, W]: torch.Size([512, 1, 32, 32])
# Shape of y: torch.Size([512]) torch.int64
# tensor([ 7,  3, 11,  5, 10, 10, 11, 12, 10, 10, 11, 12,  5,  7, 11, 11,  6,  7,
#          8,  4,  2,  5,  7,  3,  1, 11, 11,  9,  3, 11, 11, 11,  3,  0,  7,  3,
#          7, 11,  0, 13,  5,  6,  7,  5,  6, 11,  8, 11,  5, 10, 11,  2,  5,  8,
#         11, 13,  7, 12, 11,  3,  9,  7, 11,  4,  7, 11,  7,  3,  3,  9,  2, 12,
#         11, 12,  6,  9, 10, 10,  1,  2,  3, 12, 10, 12, 12, 11,  3,  9, 11, 11,
#          7, 10,  9,  7,  1,  8,  4,  2,  4,  6,  4,  9, 12,  9,  2,  6, 11,  9,
#          7,  2,  4, 11, 10,  9,  5, 12,  7,  8,  2, 11,  1,  8,  3,  9, 12, 11,
#          9, 10, 11, 12,  7, 12,  7, 12,  6,  3,  3,  2, 13, 11, 10,  6,  3,  8,
#         12,  7,  1,  4, 13,  9,  3,  0, 11, 11, 11, 11, 11,  3, 11, 11, 11,  7,
#         11, 12,  3,  8, 10,  5,  1, 12, 11, 11,  3,  6,  5,  5,  7, 11,  3, 13,
#          3,  3,  5,  9, 12, 13, 12, 11, 11, 10,  3, 11, 12,  7,  7,  3,  7, 11,
#          5, 11,  5, 12, 12,  6, 11, 12,  5,  3, 12, 10, 12, 13,  4, 11, 12, 13,
#          5, 10, 12,  9,  9,  7, 11,  7,  6,  2,  8,  9,  3,  4,  3, 11, 11, 11,
#         11,  8,  1, 12,  7,  4,  0,  3,  8, 10, 11, 12,  4,  3,  1, 10,  6,  7,
#          5, 13,  7,  8,  8,  6,  0, 11,  3, 11,  8,  6, 11,  2,  3, 10, 10, 13,
#          5,  1, 11,  7, 11, 10, 12,  3, 12,  5,  5, 11,  0,  9, 11,  3,  6,  3,
#          3,  0, 10,  0,  4, 11, 11,  7, 13,  3, 13, 12,  3,  8,  6, 10,  7,  4,
#         10, 12, 11,  0,  3, 10,  3, 11, 10,  7,  4, 11,  7, 11, 12,  2,  3, 11,
#         10, 11,  3,  0,  4,  3,  6, 11,  6, 12, 11,  3, 10,  8,  3,  3,  8,  8,
#         10,  2, 10, 11,  7, 10, 10, 12,  3, 10, 10,  7,  5,  0, 12, 12, 12,  3,
#         11, 12, 10,  6, 11, 10,  0, 12,  3, 11, 11, 11,  7,  8, 12, 10,  7,  2,
#          1,  0,  5,  1,  4,  7, 11, 11, 11, 11,  7,  3,  7, 11, 10, 11, 11, 11,
#         10,  9,  3,  7,  4, 11, 11, 10,  8, 10,  7,  7,  8, 10,  3,  0, 12,  6,
#         11,  9,  0,  8, 10, 10,  2, 12, 11,  8, 12,  4, 11, 10,  3, 11, 12,  4,
#          6, 12, 12,  2, 12, 12,  5, 11,  3,  2, 11,  6,  9, 12,  5,  2,  3,  4,
#         11, 11, 11, 11, 11, 10,  6, 13,  7,  9,  3,  3,  8, 10,  7, 11,  0, 11,
#          3, 12, 11,  3, 13,  7,  7,  9,  1,  5, 11,  3, 13,  3,  5, 11,  6,  3,
#         10,  4,  7,  9,  3, 12, 11, 13, 12, 13, 11,  5,  7, 12, 12, 12,  0, 12,
#         10, 11,  3,  7,  4,  4, 10, 12])
# Shape of X [N, C, H, W]: torch.Size([512, 1, 32, 32])
# Shape of y: torch.Size([512]) torch.int64
# tensor([11,  7,  7,  3,  7, 11, 10,  7, 12, 11, 12, 11,  3,  1, 12, 11,  3, 13,
#          3,  3, 11, 11, 11, 11,  8,  9,  5,  7,  7,  3,  8, 12, 11, 11,  7, 12,
#          3,  3, 10,  2, 11, 12,  3,  6,  3,  2,  7,  3,  0, 12, 10, 10, 12,  9,
#         11, 11, 11, 12, 10, 10,  5,  2, 12, 11, 10,  8,  7,  3,  6,  9, 11,  7,
#          2,  6,  5, 10,  3,  5,  0, 13,  2, 11, 12,  3, 11, 11,  0,  0, 11, 11,
#          3,  6,  7,  1,  5,  5, 10,  6,  7, 10,  3, 10, 11,  3,  2, 11,  7, 12,
#         11,  7, 10, 13,  9,  5, 11, 11, 11, 10, 11, 11, 11, 11, 11, 12, 11, 10,
#         11, 11,  4,  3, 10,  0,  3,  7, 11,  7,  8, 12,  2,  2, 11,  2, 13, 11,
#         11,  0,  0,  8, 11, 13, 12,  5, 10, 11,  0,  6, 11, 11,  0,  2, 11,  9,
#         10,  2,  2, 10, 11,  5,  9, 11, 11,  0,  7,  4,  7, 13,  6,  1,  1, 11,
#         13, 11,  7,  7,  1, 12, 10, 11, 11,  7, 11,  4,  0,  7,  8, 11, 11,  9,
#         13,  3,  3, 11, 11,  3, 10, 11, 12, 11,  1,  5, 11, 10, 12,  7,  7, 12,
#          3, 11,  6, 11, 11, 11, 12, 11,  7, 11, 11,  3,  5,  7, 11,  1,  1, 12,
#         12, 12,  9, 10, 11,  3, 12,  3,  5, 11, 11,  8,  9, 11,  9,  2,  3,  6,
#          7, 12,  6, 11,  9, 11,  9,  9,  0, 11,  4,  7, 12,  2, 12,  9,  8, 10,
#         10, 13, 10, 12, 10,  2,  2,  0,  2,  2, 11,  9,  7,  9,  1,  7, 10,  2,
#          1, 11,  3, 13,  3, 11,  5, 11, 11, 11, 10,  9,  2, 12,  8, 11, 10,  3,
#         10, 13, 11,  6, 11, 11,  1, 11,  3,  6, 12,  5, 11, 11,  7,  2, 11,  6,
#         12,  3,  4, 10,  1, 13, 11,  5,  7, 12, 11,  2, 11, 11,  7,  5,  9, 10,
#          4, 11, 11, 10,  2,  7,  7,  3, 10, 11, 12,  5,  8, 11,  3,  7, 12,  3,
#          8,  8,  7,  4,  5,  0,  3,  5, 11, 11, 11,  7, 11,  3, 13, 12,  3, 11,
#         12,  3, 11,  0, 10, 11, 11,  3,  9,  2,  7,  6,  5, 12, 10, 11, 10,  3,
#         12,  2, 11, 12, 10,  9, 11,  4, 10,  1,  9,  9,  7, 12,  3,  8,  2,  3,
#         11,  9, 11, 13, 10,  4,  1,  4,  4, 11,  5, 11, 11, 12, 11,  9,  9, 10,
#         12, 10,  5,  2, 11, 11,  8, 10,  0, 10,  3, 11,  9, 12,  7, 11, 11, 11,
#         11, 10,  2, 10,  2, 11,  1, 10, 10, 10,  7,  9,  0,  9,  7, 11, 12,  6,
#         10, 11,  7,  3,  1,  9,  2, 11,  7,  7,  5,  0,  9,  4,  0,  4, 11, 11,
#         11,  5, 12, 12,  8,  3, 10,  6, 10,  7, 10, 10, 12, 11, 11, 12,  5, 12,
#          5, 10,  7,  5, 12,  7, 11,  6])
# Shape of X [N, C, H, W]: torch.Size([512, 1, 32, 32])
# Shape of y: torch.Size([512]) torch.int64
# tensor([ 8, 10, 10,  5,  0, 10, 11, 11, 13, 10,  3, 12, 11,  2, 11, 11,  8,  0,
#          8,  1, 12,  1,  4,  7,  5,  3,  7,  7,  5,  3, 10, 11, 10, 11,  3,  7,
#          7,  9,  3,  4,  6, 11, 13,  0,  3,  6,  7,  0, 12,  3, 11, 10,  9, 10,
#         10, 11, 11,  9,  1,  3, 11,  7, 10,  8, 11,  7, 11, 11, 11, 13, 11,  8,
#         11, 12,  9,  3, 13, 12,  2,  2,  8, 12,  3,  3,  7,  9, 12,  3,  3,  3,
#         12, 11,  1, 12, 11,  3,  4,  1, 10, 12, 12, 11, 10,  3,  4, 13, 12,  6,
#         12,  4,  3, 11, 11,  8, 12, 10, 12,  4,  3,  7, 11, 10, 10,  1, 11,  3,
#          8,  7,  3, 11,  0,  8,  1,  7, 11,  3, 12, 11,  7, 12,  9, 10, 13,  6,
#         13, 10,  9, 13, 12,  0,  2, 11, 11, 12,  7, 11,  6, 13,  7,  7, 11, 12,
#          3,  6,  3,  6,  3, 11,  3,  8, 11, 11,  5,  7, 12, 12,  9,  3,  3,  4,
#          7,  7, 12,  6, 10, 11, 12,  0, 10,  3, 11,  7,  4,  4, 11, 13,  3, 12,
#          9,  6,  5,  6,  2, 11, 10,  7, 10, 11, 10, 11,  1, 11,  9, 10,  3,  7,
#         11, 11,  2, 10,  3, 11,  8,  3, 10, 12,  7,  3, 12, 12, 11, 12,  7,  2,
#          7, 11, 13, 11,  2,  8, 11, 11,  5, 11, 12,  9,  4, 12,  0,  7,  8, 10,
#         11,  8, 11, 11,  9,  1,  2,  6, 11, 11, 11, 10, 11,  1,  7, 11,  7,  0,
#          4, 11, 12,  8, 10, 11,  3,  0, 11,  6, 10,  7,  8, 12, 11, 10, 13, 10,
#         10, 10,  7,  6, 11, 11,  2, 11, 11,  0,  7, 12, 12,  0,  5,  7, 12, 11,
#          7,  5,  3, 10, 11,  5, 11, 10,  3,  8,  9,  1,  3,  8,  3, 12,  5,  4,
#          8, 11,  7,  1, 11, 11,  5,  7,  6, 11,  3,  6, 12,  9, 11, 10,  3, 11,
#         10,  1,  6,  3,  5, 11, 12,  2,  8,  3, 11, 11, 10,  8, 12, 13, 11, 12,
#         10,  2,  6,  7, 10,  4, 11, 12, 10, 12, 11, 11,  2, 13, 11,  6, 11,  2,
#          8, 11, 12, 12, 10, 10,  3,  3,  7,  8,  7,  3,  9, 12,  9,  6, 11,  3,
#         12,  9,  3,  2, 12,  9, 12,  7, 11,  6,  9, 11, 11,  3,  1,  7, 11, 11,
#          2,  7,  9, 11, 10,  5, 10, 10, 11,  9,  0,  0,  7,  3, 12,  7, 11, 12,
#          9,  3, 11, 10,  5, 11, 10,  4,  0,  7, 11, 10, 11, 10, 13,  0,  1,  6,
#         12,  3,  3,  7, 11, 10, 11,  8, 12,  3,  3, 12,  7,  1, 11,  9, 12,  1,
#          6,  2,  9,  3,  0,  4,  1, 11, 11,  0,  7,  1,  3, 10, 11, 11, 13, 12,
#          1,  3, 11,  6,  9, 11,  1,  1, 12,  0,  4, 10,  2, 11, 11,  8, 12, 12,
#          7,  0, 12,  7, 10, 11,  8, 11])
# Shape of X [N, C, H, W]: torch.Size([282, 1, 32, 32])
# Shape of y: torch.Size([282]) torch.int64
# tensor([ 4, 10, 13, 11, 11, 10,  7, 12, 13, 11,  7,  6, 13,  1, 11, 10, 11, 12,
#         11,  8, 12, 11,  7,  8,  2, 11,  6, 13,  9,  7, 10, 11, 11,  4,  3, 11,
#         10, 10,  7, 11, 13, 11,  5,  8, 11,  4, 11, 13,  2, 10, 10,  7,  7, 11,
#         10,  8,  8,  7,  3,  6, 11,  0,  1,  7, 10,  3,  6, 11,  3, 11,  5,  7,
#         10, 11, 10, 11,  3, 10, 10,  7, 10, 11, 12, 11, 12,  5, 11,  3, 11,  6,
#         12, 11,  7, 11, 11,  7,  9, 11, 11, 10,  7,  8, 11,  5, 11, 12, 12, 11,
#          6,  0,  3, 11, 12,  3,  2,  1, 13,  5, 11, 12, 12,  7,  9, 12,  9, 11,
#         12,  5, 11,  3,  7,  6, 13, 12, 11,  7, 12, 10,  7, 11, 12,  7, 13,  7,
#         12,  5,  5,  5,  1, 11, 11, 11, 10,  7, 10,  7,  0,  3,  4,  6,  9,  8,
#          0,  3, 12,  3,  1,  4,  1, 10,  6,  3, 10, 11,  1, 11,  1, 11, 11, 11,
#         11,  9, 11,  7,  9,  5, 11,  3,  7, 11, 10,  7,  1, 11, 11,  3,  4, 11,
#          7,  5,  6, 12,  8,  6, 13,  5, 13, 11,  1,  1, 10,  4,  9, 11,  3,  6,
#          8,  7,  1, 11, 10, 12,  3, 13,  0, 11, 10, 10,  8,  6,  9,  0,  3,  3,
#          3, 12, 11,  8, 11,  6,  1,  7, 11,  3,  3, 11,  4, 10, 12,  8, 11,  7,
#         12, 11,  3, 10, 11,  4, 10,  5, 10, 11,  3,  5,  3,  4,  5,  3,  7, 12,
#          7,  3,  8, 11, 11, 10, 12,  2,  7,  2,  5,  0])

# %%
from torch import nn

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
import torch.nn.functional as F

# Define model
# class NeuralNetwork(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.conv1 = nn.Conv2d(1, 6, 5)
#         self.pool = nn.MaxPool2d(2, 2)
#         self.conv2 = nn.Conv2d(6, 16, 5)
#         self.fc1 = nn.Linear(16 * 5 * 5, 120)
#         self.fc2 = nn.Linear(120, 84)
#         self.fc3 = nn.Linear(84, len(labels_map.keys()))
#         # self.flatten = nn.Flatten()
#         # self.linear_relu_stack = nn.Sequential(
#         #     # nn.Conv2d(1, 6, 5),
#         #     nn.Linear(num_mfcc*num_time_steps, 512),
#         #     nn.ReLU(),
#         #     nn.Linear(512, 512),
#         #     nn.ReLU(),
#         #     nn.Linear(512, len(labels_map.keys()))
#         # )

#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))
#         x = self.pool(F.relu(self.conv2(x)))
#         x = torch.flatten(x, 1) # flatten all dimensions except batch
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = self.fc3(x)
#         return x
#         # x = self.flatten(x)
#         # logits = self.linear_relu_stack(x)
#         # return logits

import torch
import torch.nn as nn
import torch.nn.functional as F

r_in = 0.85
r_conv = 1.0
r_conv2 = 1.0
r_hidden = 0.58

class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.dropout0 = nn.Dropout(1-r_in)
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.dropout1 = nn.Dropout(1 - r_conv)
        # self.conv2 = nn.Conv2d(6, 6, 5)
        # self.dropout2 = nn.Dropout(1 - r_hidden)
        self.conv3 = nn.Conv2d(6, 16, 5)
        self.dropout2 = nn.Dropout(1 - r_conv2)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.dropout3 = nn.Dropout(1 - r_hidden)
        self.fc2 = nn.Linear(120, 84)
        self.dropout4 = nn.Dropout(1 - r_hidden)
        # self.fc3 = nn.Linear(84, 84)
        # self.dropout5 = nn.Dropout(1 - r_hidden)
        # self.fc4 = nn.Linear(84, 42)
        # self.dropout6 = nn.Dropout(1 - r_hidden)
        self.fc3 = nn.Linear(84, len(labels_map.keys()))

    def forward(self, input):
        x = F.relu(self.conv1(self.dropout0(input)))
        
        # x = F.max_pool2d(x, (2, 2))
        # x = F.relu(self.conv2(x))
        
        x = self.dropout1(x)
        x = F.max_pool2d(x, (2, 2))
        x = F.relu(self.conv3(x))

        x = self.dropout2(x)
        x = F.max_pool2d(x, 2)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        
        x = self.dropout3(x)
        x = F.relu(self.fc2(x))
        
        x = self.dropout4(x)
        output = self.fc3(x)
        # c1 = F.relu(self.conv1(input))
        # s2 = F.max_pool2d(c1, (2, 2))
        # c3 = F.relu(self.conv2(s2))
        # s4 = F.max_pool2d(c3, 2)
        # s4 = torch.flatten(s4, 1)
        # f5 = F.relu(self.fc1(s4))
        # f6 = F.relu(self.fc2(f5))
        # output = self.fc3(f6)
        return output


net = Net()
print(net)

model = Net().to(device)
print(model)
# Out:
# Using cpu device
# Net(
#   (dropout0): Dropout(p=0.15000000000000002, inplace=False)
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (dropout1): Dropout(p=0.0, inplace=False)
#   (conv3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (dropout3): Dropout(p=0.42000000000000004, inplace=False)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (dropout4): Dropout(p=0.42000000000000004, inplace=False)
#   (fc3): Linear(in_features=84, out_features=14, bias=True)
# )
# Net(
#   (dropout0): Dropout(p=0.15000000000000002, inplace=False)
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (dropout1): Dropout(p=0.0, inplace=False)
#   (conv3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (dropout2): Dropout(p=0.0, inplace=False)
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (dropout3): Dropout(p=0.42000000000000004, inplace=False)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (dropout4): Dropout(p=0.42000000000000004, inplace=False)
#   (fc3): Linear(in_features=84, out_features=14, bias=True)
# )

# %%
train_dataloader

# %%
import torch.optim as optim

# criterion = nn.CrossEntropyLoss()
# optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# for epoch in range(2):  # loop over the dataset multiple times

#     running_loss = 0.0
#     for i, data in enumerate(train_dataloader, 0):
#         # get the inputs; data is a list of [inputs, labels]
#         inputs, labels = data

#         # zero the parameter gradients
#         optimizer.zero_grad()

#         # forward + backward + optimize
#         outputs = model(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()

#         # print statistics
#         running_loss += loss.item()
#         if i % 2000 == 1999:    # print every 2000 mini-batches
#             print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
#             running_loss = 0.0

# print('Finished Training')
import matplotlib.pyplot as plt

loss_fn = nn.CrossEntropyLoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3, momentum=0.4)

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    train_loss, correct = 0, 0
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        train_loss += loss_fn(pred, y).item()
        correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    train_loss /= len(dataloader)
    correct /= size
    return 1 - correct


def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            # with torch.no_grad():
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    # return 1-correct
    return test_loss, correct

train_error = []
test_error = []
train_accuracy = []
test_accuracy = []

# %%
epochs = 60000
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    _train_error, _train_accuracy = test(train_dataloader, model, loss_fn)
    _test_error, _test_accuracy = test(test_dataloader, model, loss_fn)
    
    test_error.append(_test_error)
    train_error.append(_train_error)
    test_accuracy.append(_test_accuracy)
    train_accuracy.append(_train_accuracy)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 3.430370  [  512/ 2330]
# Test Error:
#  Accuracy: 16.6%, Avg loss: 2.568064
#
# Test Error:
#  Accuracy: 18.7%, Avg loss: 2.529938
#
# Epoch 2
# -------------------------------
# loss: 2.696236  [  512/ 2330]
# Test Error:
#  Accuracy: 20.4%, Avg loss: 2.494388
#
# Test Error:
#  Accuracy: 23.3%, Avg loss: 2.465058
#
# Epoch 3
# -------------------------------
# loss: 2.585929  [  512/ 2330]
# Test Error:
#  Accuracy: 23.3%, Avg loss: 2.428377
#
# Test Error:
#  Accuracy: 28.0%, Avg loss: 2.394405
#
# Epoch 4
# -------------------------------
# loss: 2.569046  [  512/ 2330]
# Test Error:
#  Accuracy: 24.2%, Avg loss: 2.379708
#
# Test Error:
#  Accuracy: 29.2%, Avg loss: 2.366710
#
# Epoch 5
# -------------------------------
# loss: 2.498146  [  512/ 2330]
# Test Error:
#  Accuracy: 24.2%, Avg loss: 2.346536
#
# Test Error:
#  Accuracy: 28.8%, Avg loss: 2.317129
#
# Epoch 6
# -------------------------------
# loss: 2.480585  [  512/ 2330]
# Test Error:
#  Accuracy: 25.4%, Avg loss: 2.328061
#
# Test Error:
#  Accuracy: 29.7%, Avg loss: 2.308171
#
# Epoch 7
# -------------------------------
# loss: 2.447619  [  512/ 2330]
# Test Error:
#  Accuracy: 25.4%, Avg loss: 2.282057
#
# Test Error:
#  Accuracy: 29.0%, Avg loss: 2.288624
#
# Epoch 8
# -------------------------------
# loss: 2.467599  [  512/ 2330]
# Test Error:
#  Accuracy: 25.6%, Avg loss: 2.260671
#
# Test Error:
#  Accuracy: 29.7%, Avg loss: 2.285651
#
# Epoch 9
# -------------------------------
# loss: 2.380658  [  512/ 2330]
# Test Error:
#  Accuracy: 26.8%, Avg loss: 2.251737
#
# Test Error:
#  Accuracy: 30.2%, Avg loss: 2.182214
#
# Epoch 10
# -------------------------------
# loss: 2.407198  [  512/ 2330]
# Test Error:
#  Accuracy: 26.4%, Avg loss: 2.227089
#
# Test Error:
#  Accuracy: 30.0%, Avg loss: 2.201195
#
# Epoch 11
# -------------------------------
# loss: 2.311913  [  512/ 2330]
# Test Error:
#  Accuracy: 27.6%, Avg loss: 2.208935
#
# Test Error:
#  Accuracy: 29.8%, Avg loss: 2.172740
#
# Epoch 12
# -------------------------------
# loss: 2.326913  [  512/ 2330]
# Test Error:
#  Accuracy: 29.5%, Avg loss: 2.203409
#
# Test Error:
#  Accuracy: 32.4%, Avg loss: 2.164161
#
# Epoch 13
# -------------------------------
# loss: 2.283462  [  512/ 2330]
# Test Error:
#  Accuracy: 29.0%, Avg loss: 2.181197
#
# Test Error:
#  Accuracy: 31.6%, Avg loss: 2.177533
#
# Epoch 14
# -------------------------------
# loss: 2.291297  [  512/ 2330]
# Test Error:
#  Accuracy: 29.9%, Avg loss: 2.164110
#
# Test Error:
#  Accuracy: 32.2%, Avg loss: 2.161552
#
# Epoch 15
# -------------------------------
# loss: 2.312283  [  512/ 2330]
# Test Error:
#  Accuracy: 29.4%, Avg loss: 2.140271
#
# Test Error:
#  Accuracy: 32.4%, Avg loss: 2.128166
#
# Epoch 16
# -------------------------------
# loss: 2.294570  [  512/ 2330]
# Test Error:
#  Accuracy: 30.2%, Avg loss: 2.127209
#
# Test Error:
#  Accuracy: 32.6%, Avg loss: 2.055656
#
# Epoch 17
# -------------------------------
# loss: 2.272083  [  512/ 2330]
# Test Error:
#  Accuracy: 32.7%, Avg loss: 2.104156
#
# Test Error:
#  Accuracy: 34.1%, Avg loss: 2.115898
#
# Epoch 18
# -------------------------------
# loss: 2.236904  [  512/ 2330]
# Test Error:
#  Accuracy: 33.1%, Avg loss: 2.091983
#
# Test Error:
#  Accuracy: 35.3%, Avg loss: 2.075869
#
# Epoch 19
# -------------------------------
# loss: 2.201239  [  512/ 2330]
# Test Error:
#  Accuracy: 33.9%, Avg loss: 2.082584
#
# Test Error:
#  Accuracy: 36.0%, Avg loss: 2.089561
#
# Epoch 20
# -------------------------------
# loss: 2.124319  [  512/ 2330]
# Test Error:
#  Accuracy: 34.3%, Avg loss: 2.063114
#
# Test Error:
#  Accuracy: 36.7%, Avg loss: 2.020991
#
# Epoch 21
# -------------------------------
# loss: 2.202869  [  512/ 2330]
# Test Error:
#  Accuracy: 33.9%, Avg loss: 2.038746
#
# Test Error:
#  Accuracy: 36.9%, Avg loss: 2.022166
#
# Epoch 22
# -------------------------------
# loss: 2.174548  [  512/ 2330]
# Test Error:
#  Accuracy: 35.0%, Avg loss: 2.038392
#
# Test Error:
#  Accuracy: 37.4%, Avg loss: 2.071518
#
# Epoch 23
# -------------------------------
# loss: 2.244500  [  512/ 2330]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 2.001469
#
# Test Error:
#  Accuracy: 36.4%, Avg loss: 1.903945
#
# Epoch 24
# -------------------------------
# loss: 2.193246  [  512/ 2330]
# Test Error:
#  Accuracy: 35.2%, Avg loss: 2.008659
#
# Test Error:
#  Accuracy: 37.9%, Avg loss: 1.924675
#
# Epoch 25
# -------------------------------
# loss: 2.204300  [  512/ 2330]
# Test Error:
#  Accuracy: 39.3%, Avg loss: 2.007575
#
# Test Error:
#  Accuracy: 40.1%, Avg loss: 1.957022
#
# Epoch 26
# -------------------------------
# loss: 2.161950  [  512/ 2330]
# Test Error:
#  Accuracy: 38.3%, Avg loss: 1.975363
#
# Test Error:
#  Accuracy: 40.0%, Avg loss: 1.951265
#
# Epoch 27
# -------------------------------
# loss: 2.083789  [  512/ 2330]
# Test Error:
#  Accuracy: 40.6%, Avg loss: 1.968740
#
# Test Error:
#  Accuracy: 41.9%, Avg loss: 1.911845
#
# Epoch 28
# -------------------------------
# loss: 2.091734  [  512/ 2330]
# Test Error:
#  Accuracy: 40.9%, Avg loss: 1.950308
#
# Test Error:
#  Accuracy: 42.2%, Avg loss: 1.904372
#
# Epoch 29
# -------------------------------
# loss: 2.106991  [  512/ 2330]
# Test Error:
#  Accuracy: 44.5%, Avg loss: 1.960366
#
# Test Error:
#  Accuracy: 44.6%, Avg loss: 1.922683
#
# Epoch 30
# -------------------------------
# loss: 2.093572  [  512/ 2330]
# Test Error:
#  Accuracy: 43.5%, Avg loss: 1.942617
#
# Test Error:
#  Accuracy: 44.1%, Avg loss: 1.968862
#
# Epoch 31
# -------------------------------
# loss: 2.037528  [  512/ 2330]
# Test Error:
#  Accuracy: 42.0%, Avg loss: 1.918836
#
# Test Error:
#  Accuracy: 44.3%, Avg loss: 1.931688
#
# Epoch 32
# -------------------------------
# loss: 2.113100  [  512/ 2330]
# Test Error:
#  Accuracy: 45.4%, Avg loss: 1.897167
#
# Test Error:
#  Accuracy: 46.3%, Avg loss: 1.861036
#
# Epoch 33
# -------------------------------
# loss: 2.065533  [  512/ 2330]
# Test Error:
#  Accuracy: 45.0%, Avg loss: 1.881894
#
# Test Error:
#  Accuracy: 46.5%, Avg loss: 1.890049
#
# Epoch 34
# -------------------------------
# loss: 2.018132  [  512/ 2330]
# Test Error:
#  Accuracy: 44.7%, Avg loss: 1.857760
#
# Test Error:
#  Accuracy: 47.2%, Avg loss: 1.776695
#
# Epoch 35
# -------------------------------
# loss: 2.020593  [  512/ 2330]
# Test Error:
#  Accuracy: 48.5%, Avg loss: 1.857762
#
# Test Error:
#  Accuracy: 50.3%, Avg loss: 1.853748
#
# Epoch 36
# -------------------------------
# loss: 2.031771  [  512/ 2330]
# Test Error:
#  Accuracy: 48.5%, Avg loss: 1.846821
#
# Test Error:
#  Accuracy: 50.1%, Avg loss: 1.848284
#
# Epoch 37
# -------------------------------
# loss: 2.012496  [  512/ 2330]
# Test Error:
#  Accuracy: 50.9%, Avg loss: 1.838469
#
# Test Error:
#  Accuracy: 50.9%, Avg loss: 1.709603
#
# Epoch 38
# -------------------------------
# loss: 1.971755  [  512/ 2330]
# Test Error:
#  Accuracy: 50.9%, Avg loss: 1.820197
#
# Test Error:
#  Accuracy: 52.0%, Avg loss: 1.807290
#
# Epoch 39
# -------------------------------
# loss: 1.929282  [  512/ 2330]
# Test Error:
#  Accuracy: 50.5%, Avg loss: 1.808110
#
# Test Error:
#  Accuracy: 52.0%, Avg loss: 1.756549
#
# Epoch 40
# -------------------------------
# loss: 2.033775  [  512/ 2330]
# Test Error:
#  Accuracy: 52.0%, Avg loss: 1.810445
#
# Test Error:
#  Accuracy: 53.2%, Avg loss: 1.782411
#
# Epoch 41
# -------------------------------
# loss: 2.023299  [  512/ 2330]
# Test Error:
#  Accuracy: 52.5%, Avg loss: 1.777326
#
# Test Error:
#  Accuracy: 53.5%, Avg loss: 1.784153
#
# Epoch 42
# -------------------------------
# loss: 1.931351  [  512/ 2330]
# Test Error:
#  Accuracy: 50.9%, Avg loss: 1.752640
#
# Test Error:
#  Accuracy: 52.1%, Avg loss: 1.694999
#
# Epoch 43
# -------------------------------
# loss: 1.912735  [  512/ 2330]
# Test Error:
#  Accuracy: 53.6%, Avg loss: 1.759356
#
# Test Error:
#  Accuracy: 53.5%, Avg loss: 1.759339
#
# Epoch 44
# -------------------------------
# loss: 1.912674  [  512/ 2330]
# Test Error:
#  Accuracy: 54.5%, Avg loss: 1.750514
#
# Test Error:
#  Accuracy: 55.1%, Avg loss: 1.675155
#
# Epoch 45
# -------------------------------
# loss: 1.901365  [  512/ 2330]
# Test Error:
#  Accuracy: 55.9%, Avg loss: 1.739589
#
# Test Error:
#  Accuracy: 54.7%, Avg loss: 1.750134
#
# Epoch 46
# -------------------------------
# loss: 1.882003  [  512/ 2330]
# Test Error:
#  Accuracy: 55.2%, Avg loss: 1.713595
#
# Test Error:
#  Accuracy: 54.5%, Avg loss: 1.685488
#
# Epoch 47
# -------------------------------
# loss: 1.818668  [  512/ 2330]
# Test Error:
#  Accuracy: 56.8%, Avg loss: 1.706069
#
# Test Error:
#  Accuracy: 55.6%, Avg loss: 1.707280
#
# Epoch 48
# -------------------------------
# loss: 1.813119  [  512/ 2330]
# Test Error:
#  Accuracy: 58.6%, Avg loss: 1.704772
#
# Test Error:
#  Accuracy: 56.6%, Avg loss: 1.661006
#
# Epoch 49
# -------------------------------
# loss: 1.884538  [  512/ 2330]
# Test Error:
#  Accuracy: 59.3%, Avg loss: 1.694006
#
# Test Error:
#  Accuracy: 57.3%, Avg loss: 1.719197
#
# Epoch 50
# -------------------------------
# loss: 1.847578  [  512/ 2330]
# Test Error:
#  Accuracy: 58.4%, Avg loss: 1.688971
#
# Test Error:
#  Accuracy: 56.8%, Avg loss: 1.626028
#
# Epoch 51
# -------------------------------
# loss: 1.891873  [  512/ 2330]
# Test Error:
#  Accuracy: 58.7%, Avg loss: 1.643304
#
# Test Error:
#  Accuracy: 57.3%, Avg loss: 1.642872
#
# Epoch 52
# -------------------------------
# loss: 1.862232  [  512/ 2330]
# Test Error:
#  Accuracy: 59.2%, Avg loss: 1.637237
#
# Test Error:
#  Accuracy: 56.9%, Avg loss: 1.568832
#
# Epoch 53
# -------------------------------
# loss: 1.875790  [  512/ 2330]
# Test Error:
#  Accuracy: 60.7%, Avg loss: 1.632276
#
# Test Error:
#  Accuracy: 58.5%, Avg loss: 1.491882
#
# Epoch 54
# -------------------------------
# loss: 1.779546  [  512/ 2330]
# Test Error:
#  Accuracy: 60.7%, Avg loss: 1.613081
#
# Test Error:
#  Accuracy: 58.5%, Avg loss: 1.605946
#
# Epoch 55
# -------------------------------
# loss: 1.749345  [  512/ 2330]
# Test Error:
#  Accuracy: 62.4%, Avg loss: 1.594658
#
# Test Error:
#  Accuracy: 60.4%, Avg loss: 1.580673
#
# Epoch 56
# -------------------------------
# loss: 1.755815  [  512/ 2330]
# Test Error:
#  Accuracy: 61.8%, Avg loss: 1.564988
#
# Test Error:
#  Accuracy: 60.5%, Avg loss: 1.518098
#
# Epoch 57
# -------------------------------
# loss: 1.848737  [  512/ 2330]
# Test Error:
#  Accuracy: 61.8%, Avg loss: 1.565295
#
# Test Error:
#  Accuracy: 59.9%, Avg loss: 1.540252
#
# Epoch 58
# -------------------------------
# loss: 1.795102  [  512/ 2330]
# Test Error:
#  Accuracy: 62.9%, Avg loss: 1.557452
#
# Test Error:
#  Accuracy: 61.1%, Avg loss: 1.511211
#
# Epoch 59
# -------------------------------
# loss: 1.757992  [  512/ 2330]
# Test Error:
#  Accuracy: 64.2%, Avg loss: 1.560473
#
# Test Error:
#  Accuracy: 62.1%, Avg loss: 1.556328
#
# Epoch 60
# -------------------------------
# loss: 1.788855  [  512/ 2330]
# Test Error:
#  Accuracy: 62.8%, Avg loss: 1.521115
#
# Test Error:
#  Accuracy: 60.9%, Avg loss: 1.509519
#
# Epoch 61
# -------------------------------
# loss: 1.709996  [  512/ 2330]
# Test Error:
#  Accuracy: 63.1%, Avg loss: 1.507259
#
# Test Error:
#  Accuracy: 62.1%, Avg loss: 1.425280
#
# Epoch 62
# -------------------------------
# loss: 1.721901  [  512/ 2330]
# Test Error:
#  Accuracy: 63.4%, Avg loss: 1.498411
#
# Test Error:
#  Accuracy: 60.7%, Avg loss: 1.500106
#
# Epoch 63
# -------------------------------
# loss: 1.758432  [  512/ 2330]
# Test Error:
#  Accuracy: 64.6%, Avg loss: 1.479723
#
# Test Error:
#  Accuracy: 62.4%, Avg loss: 1.428008
#
# Epoch 64
# -------------------------------
# loss: 1.719714  [  512/ 2330]
# Test Error:
#  Accuracy: 65.0%, Avg loss: 1.481543
#
# Test Error:
#  Accuracy: 63.6%, Avg loss: 1.470714
#
# Epoch 65
# -------------------------------
# loss: 1.639532  [  512/ 2330]
# Test Error:
#  Accuracy: 65.5%, Avg loss: 1.466307
#
# Test Error:
#  Accuracy: 63.5%, Avg loss: 1.470586
#
# Epoch 66
# -------------------------------
# loss: 1.705959  [  512/ 2330]
# Test Error:
#  Accuracy: 66.0%, Avg loss: 1.438556
#
# Test Error:
#  Accuracy: 62.6%, Avg loss: 1.413607
#
# Epoch 67
# -------------------------------
# loss: 1.730269  [  512/ 2330]
# Test Error:
#  Accuracy: 66.1%, Avg loss: 1.424177
#
# Test Error:
#  Accuracy: 62.8%, Avg loss: 1.451799
#
# Epoch 68
# -------------------------------
# loss: 1.631459  [  512/ 2330]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 1.417825
#
# Test Error:
#  Accuracy: 64.5%, Avg loss: 1.486917
#
# Epoch 69
# -------------------------------
# loss: 1.624723  [  512/ 2330]
# Test Error:
#  Accuracy: 67.1%, Avg loss: 1.420074
#
# Test Error:
#  Accuracy: 65.4%, Avg loss: 1.400505
#
# Epoch 70
# -------------------------------
# loss: 1.627104  [  512/ 2330]
# Test Error:
#  Accuracy: 67.8%, Avg loss: 1.393868
#
# Test Error:
#  Accuracy: 64.8%, Avg loss: 1.274502
#
# Epoch 71
# -------------------------------
# loss: 1.549591  [  512/ 2330]
# Test Error:
#  Accuracy: 67.7%, Avg loss: 1.374115
#
# Test Error:
#  Accuracy: 64.3%, Avg loss: 1.424688
#
# Epoch 72
# -------------------------------
# loss: 1.588563  [  512/ 2330]
# Test Error:
#  Accuracy: 68.5%, Avg loss: 1.378117
#
# Test Error:
#  Accuracy: 66.0%, Avg loss: 1.383485
#
# Epoch 73
# -------------------------------
# loss: 1.604331  [  512/ 2330]
# Test Error:
#  Accuracy: 68.5%, Avg loss: 1.352972
#
# Test Error:
#  Accuracy: 66.2%, Avg loss: 1.360295
#
# Epoch 74
# -------------------------------
# loss: 1.527909  [  512/ 2330]
# Test Error:
#  Accuracy: 68.7%, Avg loss: 1.340556
#
# Test Error:
#  Accuracy: 66.2%, Avg loss: 1.248824
#
# Epoch 75
# -------------------------------
# loss: 1.620970  [  512/ 2330]
# Test Error:
#  Accuracy: 69.3%, Avg loss: 1.329214
#
# Test Error:
#  Accuracy: 66.2%, Avg loss: 1.323243
#
# Epoch 76
# -------------------------------
# loss: 1.546820  [  512/ 2330]
# Test Error:
#  Accuracy: 68.8%, Avg loss: 1.321317
#
# Test Error:
#  Accuracy: 65.9%, Avg loss: 1.301238
#
# Epoch 77
# -------------------------------
# loss: 1.520679  [  512/ 2330]
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.295655
#
# Test Error:
#  Accuracy: 66.4%, Avg loss: 1.319854
#
# Epoch 78
# -------------------------------
# loss: 1.549337  [  512/ 2330]
# Test Error:
#  Accuracy: 70.1%, Avg loss: 1.302569
#
# Test Error:
#  Accuracy: 68.4%, Avg loss: 1.339655
#
# Epoch 79
# -------------------------------
# loss: 1.517637  [  512/ 2330]
# Test Error:
#  Accuracy: 70.2%, Avg loss: 1.273675
#
# Test Error:
#  Accuracy: 68.1%, Avg loss: 1.258616
#
# Epoch 80
# -------------------------------
# loss: 1.515799  [  512/ 2330]
# Test Error:
#  Accuracy: 70.6%, Avg loss: 1.267945
#
# Test Error:
#  Accuracy: 69.0%, Avg loss: 1.222228
#
# Epoch 81
# -------------------------------
# loss: 1.524699  [  512/ 2330]
# Test Error:
#  Accuracy: 70.3%, Avg loss: 1.256440
#
# Test Error:
#  Accuracy: 68.8%, Avg loss: 1.189494
#
# Epoch 82
# -------------------------------
# loss: 1.467190  [  512/ 2330]
# Test Error:
#  Accuracy: 71.1%, Avg loss: 1.251168
#
# Test Error:
#  Accuracy: 70.3%, Avg loss: 1.187185
#
# Epoch 83
# -------------------------------
# loss: 1.481414  [  512/ 2330]
# Test Error:
#  Accuracy: 70.9%, Avg loss: 1.224908
#
# Test Error:
#  Accuracy: 70.5%, Avg loss: 1.228081
#
# Epoch 84
# -------------------------------
# loss: 1.502514  [  512/ 2330]
# Test Error:
#  Accuracy: 71.3%, Avg loss: 1.234473
#
# Test Error:
#  Accuracy: 70.3%, Avg loss: 1.189120
#
# Epoch 85
# -------------------------------
# loss: 1.389831  [  512/ 2330]
# Test Error:
#  Accuracy: 71.0%, Avg loss: 1.200753
#
# Test Error:
#  Accuracy: 69.3%, Avg loss: 1.224530
#
# Epoch 86
# -------------------------------
# loss: 1.498472  [  512/ 2330]
# Test Error:
#  Accuracy: 71.6%, Avg loss: 1.198865
#
# Test Error:
#  Accuracy: 69.6%, Avg loss: 1.150540
#
# Epoch 87
# -------------------------------
# loss: 1.487104  [  512/ 2330]
# Test Error:
#  Accuracy: 71.8%, Avg loss: 1.189962
#
# Test Error:
#  Accuracy: 69.8%, Avg loss: 1.145371
#
# Epoch 88
# -------------------------------
# loss: 1.512927  [  512/ 2330]
# Test Error:
#  Accuracy: 71.5%, Avg loss: 1.174694
#
# Test Error:
#  Accuracy: 69.6%, Avg loss: 1.166625
#
# Epoch 89
# -------------------------------
# loss: 1.388473  [  512/ 2330]
# Test Error:
#  Accuracy: 71.5%, Avg loss: 1.150727
#
# Test Error:
#  Accuracy: 68.6%, Avg loss: 1.117730
#
# Epoch 90
# -------------------------------
# loss: 1.469740  [  512/ 2330]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 1.145109
#
# Test Error:
#  Accuracy: 71.2%, Avg loss: 1.144409
#
# Epoch 91
# -------------------------------
# loss: 1.465353  [  512/ 2330]
# Test Error:
#  Accuracy: 72.9%, Avg loss: 1.136051
#
# Test Error:
#  Accuracy: 70.5%, Avg loss: 1.108346
#
# Epoch 92
# -------------------------------
# loss: 1.380120  [  512/ 2330]
# Test Error:
#  Accuracy: 73.2%, Avg loss: 1.124469
#
# Test Error:
#  Accuracy: 71.4%, Avg loss: 1.065752
#
# Epoch 93
# -------------------------------
# loss: 1.421179  [  512/ 2330]
# Test Error:
#  Accuracy: 73.9%, Avg loss: 1.118916
#
# Test Error:
#  Accuracy: 71.7%, Avg loss: 1.061893
#
# Epoch 94
# -------------------------------
# loss: 1.382986  [  512/ 2330]
# Test Error:
#  Accuracy: 73.5%, Avg loss: 1.119590
#
# Test Error:
#  Accuracy: 70.7%, Avg loss: 1.101945
#
# Epoch 95
# -------------------------------
# loss: 1.378380  [  512/ 2330]
# Test Error:
#  Accuracy: 74.1%, Avg loss: 1.085425
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 1.094473
#
# Epoch 96
# -------------------------------
# loss: 1.455749  [  512/ 2330]
# Test Error:
#  Accuracy: 74.4%, Avg loss: 1.080859
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 1.072454
#
# Epoch 97
# -------------------------------
# loss: 1.314784  [  512/ 2330]
# Test Error:
#  Accuracy: 74.3%, Avg loss: 1.091281
#
# Test Error:
#  Accuracy: 72.0%, Avg loss: 1.057144
#
# Epoch 98
# -------------------------------
# loss: 1.343473  [  512/ 2330]
# Test Error:
#  Accuracy: 74.5%, Avg loss: 1.065638
#
# Test Error:
#  Accuracy: 72.6%, Avg loss: 1.027192
#
# Epoch 99
# -------------------------------
# loss: 1.282556  [  512/ 2330]
# Test Error:
#  Accuracy: 74.7%, Avg loss: 1.045821
#
# Test Error:
#  Accuracy: 71.9%, Avg loss: 1.058066
#
# Epoch 100
# -------------------------------
# loss: 1.312130  [  512/ 2330]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 1.043938
#
# Test Error:
#  Accuracy: 73.4%, Avg loss: 1.123296
#
# Epoch 101
# -------------------------------
# loss: 1.377941  [  512/ 2330]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 1.042370
#
# Test Error:
#  Accuracy: 72.0%, Avg loss: 1.093000
#
# Epoch 102
# -------------------------------
# loss: 1.366279  [  512/ 2330]
# Test Error:
#  Accuracy: 75.7%, Avg loss: 1.032261
#
# Test Error:
#  Accuracy: 73.8%, Avg loss: 1.051561
#
# Epoch 103
# -------------------------------
# loss: 1.295760  [  512/ 2330]
# Test Error:
#  Accuracy: 75.9%, Avg loss: 1.016200
#
# Test Error:
#  Accuracy: 72.9%, Avg loss: 1.018138
#
# Epoch 104
# -------------------------------
# loss: 1.280790  [  512/ 2330]
# Test Error:
#  Accuracy: 75.7%, Avg loss: 1.000882
#
# Test Error:
#  Accuracy: 73.1%, Avg loss: 0.995965
#
# Epoch 105
# -------------------------------
# loss: 1.294517  [  512/ 2330]
# Test Error:
#  Accuracy: 76.3%, Avg loss: 1.003849
#
# Test Error:
#  Accuracy: 73.6%, Avg loss: 0.976144
#
# Epoch 106
# -------------------------------
# loss: 1.310065  [  512/ 2330]
# Test Error:
#  Accuracy: 76.7%, Avg loss: 0.985588
#
# Test Error:
#  Accuracy: 74.4%, Avg loss: 1.022586
#
# Epoch 107
# -------------------------------
# loss: 1.390606  [  512/ 2330]
# Test Error:
#  Accuracy: 76.7%, Avg loss: 0.971562
#
# Test Error:
#  Accuracy: 74.3%, Avg loss: 0.938471
#
# Epoch 108
# -------------------------------
# loss: 1.201667  [  512/ 2330]
# Test Error:
#  Accuracy: 76.7%, Avg loss: 0.967044
#
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.967855
#
# Epoch 109
# -------------------------------
# loss: 1.201069  [  512/ 2330]
# Test Error:
#  Accuracy: 76.5%, Avg loss: 0.965923
#
# Test Error:
#  Accuracy: 73.8%, Avg loss: 0.926825
#
# Epoch 110
# -------------------------------
# loss: 1.211579  [  512/ 2330]
# Test Error:
#  Accuracy: 77.2%, Avg loss: 0.948370
#
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.929614
#
# Epoch 111
# -------------------------------
# loss: 1.183528  [  512/ 2330]
# Test Error:
#  Accuracy: 77.3%, Avg loss: 0.936823
#
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.934399
#
# Epoch 112
# -------------------------------
# loss: 1.223123  [  512/ 2330]
# Test Error:
#  Accuracy: 77.6%, Avg loss: 0.934427
#
# Test Error:
#  Accuracy: 75.6%, Avg loss: 0.918304
#
# Epoch 113
# -------------------------------
# loss: 1.227152  [  512/ 2330]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.918587
#
# Test Error:
#  Accuracy: 75.8%, Avg loss: 0.891027
#
# Epoch 114
# -------------------------------
# loss: 1.179328  [  512/ 2330]
# Test Error:
#  Accuracy: 77.9%, Avg loss: 0.914535
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 0.900029
#
# Epoch 115
# -------------------------------
# loss: 1.177828  [  512/ 2330]
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.917672
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 0.871927
#
# Epoch 116
# -------------------------------
# loss: 1.251431  [  512/ 2330]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.893144
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 0.903779
#
# Epoch 117
# -------------------------------
# loss: 1.169824  [  512/ 2330]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.908109
#
# Test Error:
#  Accuracy: 75.6%, Avg loss: 0.935983
#
# Epoch 118
# -------------------------------
# loss: 1.160389  [  512/ 2330]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.888481
#
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.954402
#
# Epoch 119
# -------------------------------
# loss: 1.222604  [  512/ 2330]
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.877240
#
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.837706
#
# Epoch 120
# -------------------------------
# loss: 1.183231  [  512/ 2330]
# Test Error:
#  Accuracy: 79.2%, Avg loss: 0.865965
#
# Test Error:
#  Accuracy: 77.2%, Avg loss: 0.877012
#
# Epoch 121
# -------------------------------
# loss: 1.166018  [  512/ 2330]
# Test Error:
#  Accuracy: 79.3%, Avg loss: 0.856016
#
# Test Error:
#  Accuracy: 77.9%, Avg loss: 0.899010
#
# Epoch 122
# -------------------------------
# loss: 1.227317  [  512/ 2330]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.859685
#
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.816464
#
# Epoch 123
# -------------------------------
# loss: 1.202736  [  512/ 2330]
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.858721
#
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.838104
#
# Epoch 124
# -------------------------------
# loss: 1.182641  [  512/ 2330]
# Test Error:
#  Accuracy: 80.3%, Avg loss: 0.840881
#
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.825585
#
# Epoch 125
# -------------------------------
# loss: 1.112755  [  512/ 2330]
# Test Error:
#  Accuracy: 80.3%, Avg loss: 0.835293
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.849437
#
# Epoch 126
# -------------------------------
# loss: 1.149979  [  512/ 2330]
# Test Error:
#  Accuracy: 80.7%, Avg loss: 0.824973
#
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.890169
#
# Epoch 127
# -------------------------------
# loss: 1.091387  [  512/ 2330]
# Test Error:
#  Accuracy: 81.1%, Avg loss: 0.822260
#
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.808887
#
# Epoch 128
# -------------------------------
# loss: 1.069501  [  512/ 2330]
# Test Error:
#  Accuracy: 80.8%, Avg loss: 0.813399
#
# Test Error:
#  Accuracy: 79.4%, Avg loss: 0.798126
#
# Epoch 129
# -------------------------------
# loss: 1.069903  [  512/ 2330]
# Test Error:
#  Accuracy: 80.9%, Avg loss: 0.796583
#
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.815352
#
# Epoch 130
# -------------------------------
# loss: 1.152637  [  512/ 2330]
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.801932
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.740702
#
# Epoch 131
# -------------------------------
# loss: 1.091257  [  512/ 2330]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.793469
#
# Test Error:
#  Accuracy: 80.1%, Avg loss: 0.778158
#
# Epoch 132
# -------------------------------
# loss: 1.119725  [  512/ 2330]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.787654
#
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.842106
#
# Epoch 133
# -------------------------------
# loss: 1.179567  [  512/ 2330]
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.772721
#
# Test Error:
#  Accuracy: 80.4%, Avg loss: 0.809499
#
# Epoch 134
# -------------------------------
# loss: 1.006932  [  512/ 2330]
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.782961
#
# Test Error:
#  Accuracy: 79.9%, Avg loss: 0.817849
#
# Epoch 135
# -------------------------------
# loss: 1.102668  [  512/ 2330]
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.761325
#
# Test Error:
#  Accuracy: 81.5%, Avg loss: 0.800682
#
# Epoch 136
# -------------------------------
# loss: 1.078820  [  512/ 2330]
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.758645
#
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.722736
#
# Epoch 137
# -------------------------------
# loss: 1.095795  [  512/ 2330]
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.755974
#
# Test Error:
#  Accuracy: 80.6%, Avg loss: 0.761203
#
# Epoch 138
# -------------------------------
# loss: 1.064979  [  512/ 2330]
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.744595
#
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.774423
#
# Epoch 139
# -------------------------------
# loss: 1.103786  [  512/ 2330]
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.742333
#
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.759433
#
# Epoch 140
# -------------------------------
# loss: 0.955593  [  512/ 2330]
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.742489
#
# Test Error:
#  Accuracy: 81.1%, Avg loss: 0.732829
#
# Epoch 141
# -------------------------------
# loss: 1.070592  [  512/ 2330]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.727497
#
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.740711
#
# Epoch 142
# -------------------------------
# loss: 1.042925  [  512/ 2330]
# Test Error:
#  Accuracy: 83.5%, Avg loss: 0.732394
#
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.784201
#
# Epoch 143
# -------------------------------
# loss: 1.040309  [  512/ 2330]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.717668
#
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.672728
#
# Epoch 144
# -------------------------------
# loss: 1.056749  [  512/ 2330]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.721188
#
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.680314
#
# Epoch 145
# -------------------------------
# loss: 1.007288  [  512/ 2330]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.712861
#
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.752589
#
# Epoch 146
# -------------------------------
# loss: 0.930900  [  512/ 2330]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.693698
#
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.676916
#
# Epoch 147
# -------------------------------
# loss: 0.979355  [  512/ 2330]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.695100
#
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.721563
#
# Epoch 148
# -------------------------------
# loss: 1.028530  [  512/ 2330]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.702256
#
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.702853
#
# Epoch 149
# -------------------------------
# loss: 0.989442  [  512/ 2330]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.684440
#
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.667737
#
# Epoch 150
# -------------------------------
# loss: 1.067710  [  512/ 2330]
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.682865
#
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.698289
#
# Epoch 151
# -------------------------------
# loss: 0.993371  [  512/ 2330]
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.678667
#
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.756378
#
# Epoch 152
# -------------------------------
# loss: 0.979628  [  512/ 2330]
# Test Error:
#  Accuracy: 84.1%, Avg loss: 0.684194
#
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.711123
#
# Epoch 153
# -------------------------------
# loss: 1.006739  [  512/ 2330]
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.673719
#
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.657255
#
# Epoch 154
# -------------------------------
# loss: 1.015427  [  512/ 2330]
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.662499
#
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.657506
#
# Epoch 155
# -------------------------------
# loss: 0.932190  [  512/ 2330]
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.662772
#
# Test Error:
#  Accuracy: 83.4%, Avg loss: 0.683430
#
# Epoch 156
# -------------------------------
# loss: 1.065317  [  512/ 2330]
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.659628
#
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.657448
#
# Epoch 157
# -------------------------------
# loss: 0.990158  [  512/ 2330]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.648825
#
# Test Error:
#  Accuracy: 83.5%, Avg loss: 0.594639
#
# Epoch 158
# -------------------------------
# loss: 0.963062  [  512/ 2330]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.639139
#
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.657930
#
# Epoch 159
# -------------------------------
# loss: 0.863304  [  512/ 2330]
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.643319
#
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.680287
#
# Epoch 160
# -------------------------------
# loss: 0.933209  [  512/ 2330]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.638182
#
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.676854
#
# Epoch 161
# -------------------------------
# loss: 0.882528  [  512/ 2330]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.641140
#
# Test Error:
#  Accuracy: 83.4%, Avg loss: 0.676697
#
# Epoch 162
# -------------------------------
# loss: 0.934155  [  512/ 2330]
# Test Error:
#  Accuracy: 84.8%, Avg loss: 0.634377
#
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.697548
#
# Epoch 163
# -------------------------------
# loss: 0.991709  [  512/ 2330]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.637483
#
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.642617
#
# Epoch 164
# -------------------------------
# loss: 0.965689  [  512/ 2330]
# Test Error:
#  Accuracy: 84.5%, Avg loss: 0.630757
#
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.644814
#
# Epoch 165
# -------------------------------
# loss: 0.955858  [  512/ 2330]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.626373
#
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.645973
#
# Epoch 166
# -------------------------------
# loss: 0.875190  [  512/ 2330]
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.620413
#
# Test Error:
#  Accuracy: 83.4%, Avg loss: 0.635977
#
# Epoch 167
# -------------------------------
# loss: 0.988285  [  512/ 2330]
# Test Error:
#  Accuracy: 84.8%, Avg loss: 0.615657
#
# Test Error:
#  Accuracy: 83.5%, Avg loss: 0.620111
#
# Epoch 168
# -------------------------------
# loss: 0.873483  [  512/ 2330]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.606065
#
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.658647
#
# Epoch 169
# -------------------------------
# loss: 0.995427  [  512/ 2330]
# Test Error:
#  Accuracy: 84.8%, Avg loss: 0.601230
#
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.628614
#
# Epoch 170
# -------------------------------
# loss: 0.929844  [  512/ 2330]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.608367
#
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.613144
#
# Epoch 171
# -------------------------------
# loss: 0.984423  [  512/ 2330]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.598215
#
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.589594
#
# Epoch 172
# -------------------------------
# loss: 0.953809  [  512/ 2330]
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.588545
#
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.593924
#
# Epoch 173
# -------------------------------
# loss: 0.858596  [  512/ 2330]
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.573597
#
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.577398
#
# Epoch 174
# -------------------------------
# loss: 0.913412  [  512/ 2330]
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.578764
#
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.589517
#
# Epoch 175
# -------------------------------
# loss: 0.917141  [  512/ 2330]
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.581354
#
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.612095
#
# Epoch 176
# -------------------------------
# loss: 0.894309  [  512/ 2330]
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.579618
#
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.577302
#
# Epoch 177
# -------------------------------
# loss: 0.899985  [  512/ 2330]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.577923
#
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.571992
#
# Epoch 178
# -------------------------------
# loss: 0.900208  [  512/ 2330]
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.568413
#
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.589157
#
# Epoch 179
# -------------------------------
# loss: 0.857169  [  512/ 2330]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.562050
#
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.539941
#
# Epoch 180
# -------------------------------
# loss: 0.915091  [  512/ 2330]
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.553372
#
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.580058
#
# Epoch 181
# -------------------------------
# loss: 0.857236  [  512/ 2330]
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.558150
#
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.605134
#
# Epoch 182
# -------------------------------
# loss: 0.874335  [  512/ 2330]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.555410
#
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.546473
#
# Epoch 183
# -------------------------------
# loss: 0.945658  [  512/ 2330]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.556859
#
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.554695
#
# Epoch 184
# -------------------------------
# loss: 0.833436  [  512/ 2330]
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.551959
#
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.566432
#
# Epoch 185
# -------------------------------
# loss: 0.826681  [  512/ 2330]
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.548876
#
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.544329
#
# Epoch 186
# -------------------------------
# loss: 0.857537  [  512/ 2330]
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.542507
#
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.570636
#
# Epoch 187
# -------------------------------
# loss: 0.809261  [  512/ 2330]
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.543100
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.548796
#
# Epoch 188
# -------------------------------
# loss: 0.888739  [  512/ 2330]
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.540820
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.498158
#
# Epoch 189
# -------------------------------
# loss: 0.898422  [  512/ 2330]
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.541705
#
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.503671
#
# Epoch 190
# -------------------------------
# loss: 0.864310  [  512/ 2330]
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.532906
#
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.564635
#
# Epoch 191
# -------------------------------
# loss: 0.847364  [  512/ 2330]
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.534622
#
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.532623
#
# Epoch 192
# -------------------------------
# loss: 0.836567  [  512/ 2330]
# Test Error:
#  Accuracy: 86.3%, Avg loss: 0.529403
#
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.557340
#
# Epoch 193
# -------------------------------
# loss: 0.846414  [  512/ 2330]
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.525690
#
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.527253
#
# Epoch 194
# -------------------------------
# loss: 0.815649  [  512/ 2330]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.523879
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.567416
#
# Epoch 195
# -------------------------------
# loss: 0.792133  [  512/ 2330]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.514221
#
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.506459
#
# Epoch 196
# -------------------------------
# loss: 0.804755  [  512/ 2330]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.515416
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.524661
#
# Epoch 197
# -------------------------------
# loss: 0.867303  [  512/ 2330]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.518848
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.486498
#
# Epoch 198
# -------------------------------
# loss: 0.822214  [  512/ 2330]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.513599
#
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.525226
#
# Epoch 199
# -------------------------------
# loss: 0.866015  [  512/ 2330]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.510319
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.550802
#
# Epoch 200
# -------------------------------
# loss: 0.869439  [  512/ 2330]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.509363
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.496486
#
# Epoch 201
# -------------------------------
# loss: 0.873951  [  512/ 2330]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.505589
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.543651
#
# Epoch 202
# -------------------------------
# loss: 0.802173  [  512/ 2330]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.492260
#
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.472279
#
# Epoch 203
# -------------------------------
# loss: 0.753014  [  512/ 2330]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.491002
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.509261
#
# Epoch 204
# -------------------------------
# loss: 0.781257  [  512/ 2330]
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.492561
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.576632
#
# Epoch 205
# -------------------------------
# loss: 0.818182  [  512/ 2330]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.486660
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.489091
#
# Epoch 206
# -------------------------------
# loss: 0.840893  [  512/ 2330]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.486025
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.456402
#
# Epoch 207
# -------------------------------
# loss: 0.763197  [  512/ 2330]
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.479717
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.523802
#
# Epoch 208
# -------------------------------
# loss: 0.776239  [  512/ 2330]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.477152
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.487845
#
# Epoch 209
# -------------------------------
# loss: 0.745189  [  512/ 2330]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.479662
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.551024
#
# Epoch 210
# -------------------------------
# loss: 0.803969  [  512/ 2330]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.472262
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.503121
#
# Epoch 211
# -------------------------------
# loss: 0.690580  [  512/ 2330]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.477277
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.443489
#
# Epoch 212
# -------------------------------
# loss: 0.733306  [  512/ 2330]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.471312
#
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.549591
#
# Epoch 213
# -------------------------------
# loss: 0.786811  [  512/ 2330]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.472717
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.424449
#
# Epoch 214
# -------------------------------
# loss: 0.763473  [  512/ 2330]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.467459
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.490503
#
# Epoch 215
# -------------------------------
# loss: 0.776205  [  512/ 2330]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.460078
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.496811
#
# Epoch 216
# -------------------------------
# loss: 0.740777  [  512/ 2330]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.461129
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.476856
#
# Epoch 217
# -------------------------------
# loss: 0.774063  [  512/ 2330]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.460693
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.394511
#
# Epoch 218
# -------------------------------
# loss: 0.722681  [  512/ 2330]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.454922
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.509700
#
# Epoch 219
# -------------------------------
# loss: 0.704492  [  512/ 2330]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.453698
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.457715
#
# Epoch 220
# -------------------------------
# loss: 0.812695  [  512/ 2330]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.455172
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.428039
#
# Epoch 221
# -------------------------------
# loss: 0.736944  [  512/ 2330]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.451610
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.454283
#
# Epoch 222
# -------------------------------
# loss: 0.727658  [  512/ 2330]
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.449797
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.468271
#
# Epoch 223
# -------------------------------
# loss: 0.743858  [  512/ 2330]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.438997
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.505010
#
# Epoch 224
# -------------------------------
# loss: 0.783855  [  512/ 2330]
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.447584
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.491691
#
# Epoch 225
# -------------------------------
# loss: 0.708384  [  512/ 2330]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.441008
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.456338
#
# Epoch 226
# -------------------------------
# loss: 0.761624  [  512/ 2330]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.440331
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.455191
#
# Epoch 227
# -------------------------------
# loss: 0.700791  [  512/ 2330]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.437760
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.427072
#
# Epoch 228
# -------------------------------
# loss: 0.740387  [  512/ 2330]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.436169
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.446916
#
# Epoch 229
# -------------------------------
# loss: 0.715797  [  512/ 2330]
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.438152
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.445899
#
# Epoch 230
# -------------------------------
# loss: 0.686395  [  512/ 2330]
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.428760
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.425974
#
# Epoch 231
# -------------------------------
# loss: 0.724842  [  512/ 2330]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.431606
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.402884
#
# Epoch 232
# -------------------------------
# loss: 0.811134  [  512/ 2330]
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.426050
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.443423
#
# Epoch 233
# -------------------------------
# loss: 0.737918  [  512/ 2330]
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.420948
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.412952
#
# Epoch 234
# -------------------------------
# loss: 0.734504  [  512/ 2330]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.419107
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.396698
#
# Epoch 235
# -------------------------------
# loss: 0.697643  [  512/ 2330]
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.418691
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.473117
#
# Epoch 236
# -------------------------------
# loss: 0.711951  [  512/ 2330]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.413399
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.433574
#
# Epoch 237
# -------------------------------
# loss: 0.718291  [  512/ 2330]
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.417546
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.400452
#
# Epoch 238
# -------------------------------
# loss: 0.714923  [  512/ 2330]
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.411938
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.443328
#
# Epoch 239
# -------------------------------
# loss: 0.657844  [  512/ 2330]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.411824
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.434614
#
# Epoch 240
# -------------------------------
# loss: 0.745122  [  512/ 2330]
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.408646
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.451081
#
# Epoch 241
# -------------------------------
# loss: 0.718410  [  512/ 2330]
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.409087
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.376123
#
# Epoch 242
# -------------------------------
# loss: 0.718315  [  512/ 2330]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.409634
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.380358
#
# Epoch 243
# -------------------------------
# loss: 0.663110  [  512/ 2330]
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.403821
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.444260
#
# Epoch 244
# -------------------------------
# loss: 0.760072  [  512/ 2330]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.405956
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.429369
#
# Epoch 245
# -------------------------------
# loss: 0.687211  [  512/ 2330]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.400510
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.404149
#
# Epoch 246
# -------------------------------
# loss: 0.668430  [  512/ 2330]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.396231
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.401484
#
# Epoch 247
# -------------------------------
# loss: 0.704782  [  512/ 2330]
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.395165
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.417197
#
# Epoch 248
# -------------------------------
# loss: 0.635659  [  512/ 2330]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.392221
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.377225
#
# Epoch 249
# -------------------------------
# loss: 0.660281  [  512/ 2330]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.393191
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.433502
#
# Epoch 250
# -------------------------------
# loss: 0.662408  [  512/ 2330]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.386881
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.383550
#
# Epoch 251
# -------------------------------
# loss: 0.753080  [  512/ 2330]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.394921
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.418781
#
# Epoch 252
# -------------------------------
# loss: 0.676009  [  512/ 2330]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.387339
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.399552
#
# Epoch 253
# -------------------------------
# loss: 0.698532  [  512/ 2330]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.384662
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.382574
#
# Epoch 254
# -------------------------------
# loss: 0.693949  [  512/ 2330]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.382591
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.412142
#
# Epoch 255
# -------------------------------
# loss: 0.754816  [  512/ 2330]
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.384886
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.401703
#
# Epoch 256
# -------------------------------
# loss: 0.619383  [  512/ 2330]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.377035
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.358148
#
# Epoch 257
# -------------------------------
# loss: 0.700939  [  512/ 2330]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.379835
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.395932
#
# Epoch 258
# -------------------------------
# loss: 0.606200  [  512/ 2330]
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.376482
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.386910
#
# Epoch 259
# -------------------------------
# loss: 0.658284  [  512/ 2330]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.372232
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.407258
#
# Epoch 260
# -------------------------------
# loss: 0.627499  [  512/ 2330]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.372582
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.334411
#
# Epoch 261
# -------------------------------
# loss: 0.618763  [  512/ 2330]
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.373986
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.361259
#
# Epoch 262
# -------------------------------
# loss: 0.611580  [  512/ 2330]
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.365594
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.390338
#
# Epoch 263
# -------------------------------
# loss: 0.602694  [  512/ 2330]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.367233
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.324400
#
# Epoch 264
# -------------------------------
# loss: 0.607847  [  512/ 2330]
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.358162
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.410126
#
# Epoch 265
# -------------------------------
# loss: 0.659969  [  512/ 2330]
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.359459
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.362491
#
# Epoch 266
# -------------------------------
# loss: 0.656879  [  512/ 2330]
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.360856
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.361667
#
# Epoch 267
# -------------------------------
# loss: 0.696860  [  512/ 2330]
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.359328
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.327053
#
# Epoch 268
# -------------------------------
# loss: 0.622225  [  512/ 2330]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.357754
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.354720
#
# Epoch 269
# -------------------------------
# loss: 0.628089  [  512/ 2330]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.359577
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.326070
#
# Epoch 270
# -------------------------------
# loss: 0.688605  [  512/ 2330]
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.360142
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.311903
#
# Epoch 271
# -------------------------------
# loss: 0.607955  [  512/ 2330]
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.357718
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.406547
#
# Epoch 272
# -------------------------------
# loss: 0.642471  [  512/ 2330]
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.350005
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.404835
#
# Epoch 273
# -------------------------------
# loss: 0.678299  [  512/ 2330]
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.348176
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.360928
#
# Epoch 274
# -------------------------------
# ...
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000010
#
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.032926
#
# Epoch 21632
# -------------------------------
# loss: 0.004378  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.028460
#
# Epoch 21633
# -------------------------------
# loss: 0.011439  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.026707
#
# Epoch 21634
# -------------------------------
# loss: 0.009280  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.024301
#
# Epoch 21635
# -------------------------------
# loss: 0.009911  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.023953
#
# Epoch 21636
# -------------------------------
# loss: 0.002126  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.032458
#
# Epoch 21637
# -------------------------------
# loss: 0.004696  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.026442
#
# Epoch 21638
# -------------------------------
# loss: 0.006849  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.027230
#
# Epoch 21639
# -------------------------------
# loss: 0.002510  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.029240
#
# Epoch 21640
# -------------------------------
# loss: 0.004865  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.026171
#
# Epoch 21641
# -------------------------------
# loss: 0.003828  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.025878
#
# Epoch 21642
# -------------------------------
# loss: 0.002284  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.027227
#
# Epoch 21643
# -------------------------------
# loss: 0.004347  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.059437
#
# Epoch 21644
# -------------------------------
# loss: 0.005584  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.028370
#
# Epoch 21645
# -------------------------------
# loss: 0.006934  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.028442
#
# Epoch 21646
# -------------------------------
# loss: 0.005879  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.075262
#
# Epoch 21647
# -------------------------------
# loss: 0.006743  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.029889
#
# Epoch 21648
# -------------------------------
# loss: 0.006454  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.108054
#
# Epoch 21649
# -------------------------------
# loss: 0.003728  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.025870
#
# Epoch 21650
# -------------------------------
# loss: 0.016449  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.025204
#
# Epoch 21651
# -------------------------------
# loss: 0.002100  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.074600
#
# Epoch 21652
# -------------------------------
# loss: 0.006657  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000011
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.027366
#
# Epoch 21653
# -------------------------------
# loss: 0.001585  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000015
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.056592
#
# Epoch 21654
# -------------------------------
# loss: 0.001101  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000016
#
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.034171
#
# Epoch 21655
# -------------------------------
# loss: 0.009241  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000017
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.105903
#
# Epoch 21656
# -------------------------------
# loss: 0.022681  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000016
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.023539
#
# Epoch 21657
# -------------------------------
# loss: 0.006698  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000015
#
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.116059
#
# Epoch 21658
# -------------------------------
# loss: 0.000746  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000014
#
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.090727
#
# Epoch 21659
# -------------------------------
# loss: 0.003328  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000012
#
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.028036
#
# Epoch 21660
# -------------------------------
# loss: 0.011212  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000012
#
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.115371
#
# Epoch 21661
# -------------------------------
# loss: 0.010866  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000014
#
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.029450
#
# Epoch 21662
# -------------------------------
# loss: 0.004342  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000014
#
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.028968
#
# Epoch 21663
# -------------------------------
# loss: 0.004066  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000013
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.082471
#
# Epoch 21664
# -------------------------------
# loss: 0.003069  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000012
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.027837
#
# Epoch 21665
# -------------------------------
# loss: 0.005336  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000015
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.054678
#
# Epoch 21666
# -------------------------------
# loss: 0.012769  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000012
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.037300
#
# Epoch 21667
# -------------------------------
# loss: 0.012578  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000015
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.028423
#
# Epoch 21668
# -------------------------------
# loss: 0.002991  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000018
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.028744
#
# Epoch 21669
# -------------------------------
# loss: 0.003276  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000017
#
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.029386
#
# Epoch 21670
# -------------------------------
# loss: 0.007467  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000014
#
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.029469
#
# Epoch 21671
# -------------------------------
# loss: 0.001656  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000014
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.039764
#
# Epoch 21672
# -------------------------------
# loss: 0.002312  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000011
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.028153
#
# Epoch 21673
# -------------------------------
# loss: 0.011332  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000011
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.057278
#
# Epoch 21674
# -------------------------------
# loss: 0.004689  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000023
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.182885
#
# Epoch 21675
# -------------------------------
# loss: 0.002268  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000020
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.031728
#
# Epoch 21676
# -------------------------------
# loss: 0.001815  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000020
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.117678
#
# Epoch 21677
# -------------------------------
# loss: 0.007936  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000012
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.114702
#
# Epoch 21678
# -------------------------------
# loss: 0.003313  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000011
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.027372
#
# Epoch 21679
# -------------------------------
# loss: 0.003593  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000010
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.025985
#
# Epoch 21680
# -------------------------------
# loss: 0.005400  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000011
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.111033
#
# Epoch 21681
# -------------------------------
# loss: 0.005383  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.024920
#
# Epoch 21682
# -------------------------------
# loss: 0.001304  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.026749
#
# Epoch 21683
# -------------------------------
# loss: 0.002104  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.066935
#
# Epoch 21684
# -------------------------------
# loss: 0.016313  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.027529
#
# Epoch 21685
# -------------------------------
# loss: 0.001275  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.027176
#
# Epoch 21686
# -------------------------------
# loss: 0.013565  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.082634
#
# Epoch 21687
# -------------------------------
# loss: 0.003585  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.060242
#
# Epoch 21688
# -------------------------------
# loss: 0.001261  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.028386
#
# Epoch 21689
# -------------------------------
# loss: 0.002994  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.054826
#
# Epoch 21690
# -------------------------------
# loss: 0.006871  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.114693
#
# Epoch 21691
# -------------------------------
# loss: 0.001204  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.026211
#
# Epoch 21692
# -------------------------------
# loss: 0.012799  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.026942
#
# Epoch 21693
# -------------------------------
# loss: 0.009197  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.038819
#
# Epoch 21694
# -------------------------------
# loss: 0.005862  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.075292
#
# Epoch 21695
# -------------------------------
# loss: 0.005250  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.029259
#
# Epoch 21696
# -------------------------------
# loss: 0.001275  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.028865
#
# Epoch 21697
# -------------------------------
# loss: 0.007266  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.071856
#
# Epoch 21698
# -------------------------------
# loss: 0.006561  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.028578
#
# Epoch 21699
# -------------------------------
# loss: 0.004876  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.031303
#
# Epoch 21700
# -------------------------------
# loss: 0.006012  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.070419
#
# Epoch 21701
# -------------------------------
# loss: 0.003639  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.038195
#
# Epoch 21702
# -------------------------------
# loss: 0.003577  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000010
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.028776
#
# Epoch 21703
# -------------------------------
# loss: 0.036948  [  512/ 2330]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.026633
#
# Epoch 21704
# -------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 4
#       2 for t in range(epochs):
#       3     print(f"Epoch {t+1}\n-------------------------------")
# ----> 4     train(train_dataloader, model, loss_fn, optimizer)
#       5     _train_error, _train_accuracy = test(train_dataloader, model, loss_fn)
#       6     _test_error, _test_accuracy = test(test_dataloader, model, loss_fn)
#
# Cell In[32], line 39, in train(dataloader, model, loss_fn, optimizer)
#      37 model.train()
#      38 train_loss, correct = 0, 0
# ---> 39 for batch, (X, y) in enumerate(dataloader):
#      40     X, y = X.to(device), y.to(device)
#      42     # Compute prediction error
#
# File ~/projects/coursework/winter2026/ecen471/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File ~/projects/coursework/winter2026/ecen471/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:801, in _SingleProcessDataLoaderIter._next_data(self)
#     799 def _next_data(self):
#     800     index = self._next_index()  # may raise StopIteration
# --> 801     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802     if self._pin_memory:
#     803         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/projects/coursework/winter2026/ecen471/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50 if self.auto_collation:
#      51     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 52         data = self.dataset.__getitems__(possibly_batched_index)
#      53     else:
#      54         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File ~/projects/coursework/winter2026/ecen471/.venv/lib/python3.12/site-packages/torch/utils/data/dataset.py:443, in Subset.__getitems__(self, indices)
#     441     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     442 else:
# --> 443     return [self.dataset[self.indices[idx]] for idx in indices]
#
# Cell In[27], line 30, in InstrumentDataset.__getitem__(self, idx)
#      28 def __getitem__(self, idx):
#      29     X_i = torch.tensor(self.X[idx].reshape((1, self.X.shape[1], self.X.shape[2])), dtype=torch.float32)
# ---> 30     y_i = torch.tensor(self.y[idx], dtype=torch.long)
#      31     return X_i, y_i
#
# KeyboardInterrupt:

# %%
import numpy as np
plt.plot(np.array(train_error[0:]), alpha=0.5)
plt.plot(np.array(test_error[0:]), alpha=0.5)
# plt.xlim([0.0, 60000])
# plt.xlim([1000, 1500])
plt.ylim([0.0, 3.0])

data = pickle.load(open("./04-06/model_metadata.pkl", "rb"))

# plt.plot(data["_test_error"], alpha=0.5)
# plt.plot(data["_train_error"], alpha=0.5)

# %%
import numpy as np
plt.plot(np.array(train_error[0:]))
plt.plot(np.array(test_error[0:]))
# plt.ylim([0.0, 0.03])

# %%
torch.save(model.state_dict(), 'model_weights_attempt2.pth')


import pickle

data = {
    "_X": X,
    "_y": y,
    "_labels_map": labels_map,
    "_train_error": train_error,
    "_test_error": test_error,
}

pickle.dump(data, open('model_metadata_attempt2.pkl', 'wb'))

# %%
map = {v:k for k, v in labels_map.items()}

count1 = 0
count2 = 0
for X, y in train_dataloader:    
    for i in range(len(y)):
        count1 += 1
        pred = model(X)
        pred_index = torch.argmax(pred[i,:])
        true_index = y[i]

        pred = map[int(pred_index)]
        truth = map[int(true_index)]
        if not pred == truth:
            count2 += 1
            print(f"{pred} | {truth}")

print(count2/count1)

# %%
map = {v:k for k, v in labels_map.items()}

count1 = 0
count2 = 0
for X, y in test_dataloader:    
    for i in range(len(y)):
        count1 += 1
        pred = model(X)
        pred_index = torch.argmax(pred[i,:])
        true_index = y[i]

        pred = map[int(pred_index)]
        truth = map[int(true_index)]
        if not pred == truth:
            count2 += 1
            print(f"{pred} | {truth}")

print(count2/count1)

# %%
import matplotlib.pyplot as plt
# Display image and label.
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze()
label = train_labels[0]
plt.imshow(img, cmap="gray")
plt.show()
print(f"Label: {label}")

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

from torch.utils.data import Dataset

class AudioDataset(DataSet):
    pass

train_dataloader = DataLoader(training_data, batch_size=64)
test_dataloader = DataLoader(test_data, batch_size=64)

class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(20, 64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.module(x)
    
model = MLP()

learning_rate = 1e-3
batch_size = 64
epochs = 5

# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")

# %% [markdown]
# I got the dataset from kaggle [here](https://www.kaggle.com/datasets/thedevastator/tinysol-isolated-musical-notes-from-14-musical-i).

# %% [markdown]
# I decided to reduce the dimensionality of the model for our use case
#
# https://reference.wolfram.com/language/ref/netencoder/Audio.html
#
# Using the tutorial above, I settled on using the AudioMFCC encoder, which has a corresponding function in a Python library
#
# https://docs.pytorch.org/audio/master/generated/torchaudio.transforms.MFCC.html

# %% [markdown]
# I couldn't get torchaudio working, so intead I am using a different library
# [text](https://python-speech-features.readthedocs.io/en/latest/#)

# %% [markdown]
# Here is a pytorch version of dropout
# [link](https://codesignal.com/learn/courses/improving-neural-networks-with-pytorch/lessons/adding-dropout-to-neural-networks-in-pytorch)

# %%
print(f"Model structure: {model}\n\n")

for name, param in model.named_parameters():
    print(f"Layer: {name} | Size: {param.size()} | Values : {param[:2]} \n")

# %%
from python_speech_features import mfcc
from python_speech_features import logfbank
import scipy.io.wavfile as wav

nfft = 4096

(rate,sig) = wav.read("Brass/Bass_Tuba/ordinario/BTb-ord-A1-ff-N-T19d.wav")
(rate,sig) = wav.read("Brass/Horn/ordinario/Hn-ord-A1-mf-N-N.wav")

mfcc_feat = mfcc(sig,rate, nfft=nfft, winlen=50e-3)
print(mfcc_feat[mfcc_feat.shape[0]//2,:])

nfft = 4096
(rate,sig) = wav.read("Brass/Horn/ordinario/Hn-ord-A1-mf-N-N.wav")
mfcc_feat = mfcc(sig,rate, nfft=nfft, winlen=50e-3 )
# fbank_feat = logfbank(sig,rate, nfft=nfft)

print(mfcc_feat[mfcc_feat.shape[0]//2,:])

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

def plot_mfcc(audio_path, ax, title):
    # Load the audio file
    y, sr = librosa.load(audio_path)

    # Extract MFCC features
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20, n_fft=1800)

    # Plot MFCCs
    # plt.figure(figsize=(10, 4))
    librosa.display.specshow(mfccs, x_axis='time', cmap='viridis', ax = ax)
    # ax.colorbar(format='%+2.0f dB')
    ax.set_title(title)
    ax.set_xlabel('Time')
    ax.set_ylabel('MFCC Coefficient')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Example usage
audio_file_path1 = "Winds/Bassoon/ordinario/Bn-ord-D#3-pp-N-N.wav"
# audio_file_path2 = "Brass/Bass_Tuba/ordinario/BTb-ord-D#3-mf-N-T25u.wav"
# audio_file_path1 = "Brass/Horn/ordinario/Hn-ord-A1-mf-N-N.wav"
audio_file_path2 = "Brass/Trombone/ordinario/Tbn-ord-D#3-ff-N-N.wav"
# audio_file_path1 = "Strings/Viola/ordinario/Va-ord-A#3-ff-3c-N.wav"
# audio_file_path2 = "Strings/Viola/ordinario/Va-ord-G5-ff-3c-N.wav"
plot_mfcc(audio_file_path1, ax1, "Basson playing D#3")
plot_mfcc(audio_file_path2, ax2, "Trombone playing D#3")

# %% [markdown]
# I found this [tutorial](https://www.geeksforgeeks.org/machine-learning/classification-using-sklearn-multi-layer-perceptron/) helpful

# %%
from sklearn.neural_network import MLPClassifier

MLPClassifier()

# %% [markdown]
# This [tutorial](https://www.geeksforgeeks.org/deep-learning/training-neural-networks-with-dropout-for-effective-regularization/)
#  goes over training with dropout with tensorflow
